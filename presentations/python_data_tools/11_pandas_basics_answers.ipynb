# %% [markdown]
# <img style="float: right;" src="static/small.jpg">
#
# <br>

# %% [markdown]
# ---
#
# ## Basic Pandas Exercises
#
# See also: [10 Minutes to Pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html)
#
# ---

# %%
# 1. import pandas and then import pandas under the alias pd

import pandas
import pandas as pd

# %%
# 2. Use the dir() function to inspect some the availible attributes of pd.

dir(pd)[:5]
# Out:
# ['Categorical', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex']

# %%
# 3.  Create a dataframe from the CFPB .csv using pd.read_csv(); assign to variable 'df'.

df = pd.read_csv('data/cfpb_complaints_with_fictitious_data.csv')

# %%
# 4. Use the dataframe's head() method to get the first 5 samples of df.

df.head(5)
# Out:
#   Date received           Product                            Sub-product  \
# 0     3/24/2015       Credit card                                    NaN
# 1     3/23/2015   Debt collection  Other (i.e. phone, health club, etc.)
# 2     3/23/2015       Credit card                                    NaN
# 3     3/23/2015  Credit reporting                                    NaN
# 4     3/23/2015   Debt collection                            Payday loan
#
#                                     Issue  \
# 0                                   Other
# 1     Improper contact or sharing of info
# 2                                 Rewards
# 3  Incorrect information on credit report
# 4     Improper contact or sharing of info
#
#                                Sub-issue  \
# 0                                    NaN
# 1      Contacted me after I asked not to
# 2                                    NaN
# 3                Information is not mine
# 4  Talked to a third party about my debt
#
#                         Consumer complaint narrative  \
# 0  Received Capital One charge card offer XXXX. A...
# 1  I do n't know how they got my cell number. I t...
# 2  I 'm a longtime member of Charter One Bank/RBS...
# 3  After looking at my credit report, I saw a col...
# 4  I received a call from a XXXX XXXX from XXXX @...
#
#                             Company public response  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3  Company chooses not to provide a public response
# 4                                               NaN
#
#                           Company State ZIP code       ...         \
# 0                     Capital One    OH    440XX       ...
# 1    CCS Financial Services, Inc.    AR    727XX       ...
# 2  Citizens Financial Group, Inc.    MI    482XX       ...
# 3                        Experian    FL    331XX       ...
# 4          Big Picture Loans, LLC    SC    291XX       ...
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web            3/30/2015
# 1           Consent provided           Web            3/23/2015
# 2           Consent provided           Web            3/23/2015
# 3           Consent provided           Web            3/27/2015
# 4           Consent provided           Web            3/23/2015
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0          Closed with explanation              Yes                 No
# 1          Closed with explanation              Yes                 No
# 2          Closed with explanation              Yes                Yes
# 3  Closed with non-monetary relief              Yes                 No
# 4          Closed with explanation              Yes                 No
#
#   Complaint ID  Consumer Claim  Company Offer  Amount Received
# 0      1297939          332.63         217.18           130.22
# 1      1296593           54.79          41.48            49.14
# 2      1296693          215.04         231.67           155.28
# 3      1296955            3.31           6.30             4.59
# 4      1296727           73.99          76.75            46.02
#
# [5 rows x 21 columns]

# %%
# 5. Use the dtypes attribute to see what datatypes and columns we have in dataframe 'df'.

df.dtypes
# Out:
# Date received                    object
# Product                          object
# Sub-product                      object
# Issue                            object
# Sub-issue                        object
# Consumer complaint narrative     object
# Company public response          object
# Company                          object
# State                            object
# ZIP code                         object
# Tags                             object
# Consumer consent provided?       object
# Submitted via                    object
# Date sent to company             object
# Company response to consumer     object
# Timely response?                 object
# Consumer disputed?               object
# Complaint ID                      int64
# Consumer Claim                  float64
# Company Offer                   float64
# Amount Received                 float64
# dtype: object

# %%
# 6. Use the len() function to look at the length of the dataframe.

len(df)
# Out:
# 125680

# %%
# 7. Use the dataframe's sample method to pull a random sample of 50 from the dataframe

df.sample(50)
# Out:
#        Date received                  Product  \
# 57108      5/18/2016                 Mortgage
# 26871       8/8/2015         Credit reporting
# 28134       9/4/2015          Debt collection
# 26705       8/7/2015  Bank account or service
# 35319       2/8/2016                 Mortgage
# 123739    10/20/2016                 Mortgage
# 1118       4/16/2015          Debt collection
# 61197      5/22/2015          Debt collection
# 14590      1/11/2016                 Mortgage
# 112590    10/11/2016              Credit card
# 3466       6/17/2015          Debt collection
# 4341       6/10/2015          Debt collection
# 69239     11/20/2015                 Mortgage
# 44343      7/29/2015              Credit card
# 52510     12/16/2015         Credit reporting
# 101623     8/11/2016            Consumer Loan
# 78058      4/29/2016          Debt collection
# 32940     12/25/2015            Consumer Loan
# 88429      6/30/2016            Consumer Loan
# 11078     11/14/2015          Debt collection
# 15034      2/15/2016          Debt collection
# 75981      4/20/2016          Debt collection
# 76750      4/29/2016            Consumer Loan
# 112094    11/18/2016  Bank account or service
# 14446      1/14/2016                 Mortgage
# 49396     10/30/2015         Credit reporting
# 91923      6/15/2016              Credit card
# 4139       6/24/2015              Credit card
# 113444    10/13/2016                 Mortgage
# 83010       5/8/2016         Credit reporting
# 116097     9/17/2016          Money transfers
# 17115       3/7/2016              Payday loan
# 55126       3/4/2016                 Mortgage
# 22600      6/11/2015            Consumer Loan
# 29919     10/16/2015                 Mortgage
# 9048       9/10/2015          Debt collection
# 49765      11/5/2015          Debt collection
# 54778      2/23/2016         Credit reporting
# 53707      1/27/2016                 Mortgage
# 32329     12/11/2015                 Mortgage
# 65155      8/13/2015          Debt collection
# 1995       5/19/2015          Debt collection
# 7118        8/7/2015              Credit card
# 7043        8/6/2015         Credit reporting
# 74576      3/16/2016              Credit card
# 114562      9/4/2016         Credit reporting
# 75737      4/13/2016                 Mortgage
# 94258       8/3/2016                 Mortgage
# 71662     12/21/2015         Credit reporting
# 7335       8/21/2015                 Mortgage
#
#                                    Sub-product  \
# 57108                             FHA mortgage
# 26871                                      NaN
# 28134                            I do not know
# 26705               Other bank product/service
# 35319              Conventional fixed mortgage
# 123739             Conventional fixed mortgage
# 1118     Other (i.e. phone, health club, etc.)
# 61197                              Credit card
# 14590              Conventional fixed mortgage
# 112590                                     NaN
# 3466     Other (i.e. phone, health club, etc.)
# 4341                               Credit card
# 69239   Conventional adjustable mortgage (ARM)
# 44343                                      NaN
# 52510                                      NaN
# 101623                            Vehicle loan
# 78058    Other (i.e. phone, health club, etc.)
# 32940                             Vehicle loan
# 88429                         Installment loan
# 11078                              Credit card
# 15034    Other (i.e. phone, health club, etc.)
# 75981                            I do not know
# 76750                             Vehicle loan
# 112094                        Checking account
# 14446   Conventional adjustable mortgage (ARM)
# 49396                                      NaN
# 91923                                      NaN
# 4139                                       NaN
# 113444                          Other mortgage
# 83010                                      NaN
# 116097            Domestic (US) money transfer
# 17115                              Payday loan
# 55126              Conventional fixed mortgage
# 22600                             Vehicle loan
# 29919                              VA mortgage
# 9048                  Non-federal student loan
# 49765                                  Medical
# 54778                                      NaN
# 53707              Conventional fixed mortgage
# 32329       Home equity loan or line of credit
# 65155                            I do not know
# 1995                             I do not know
# 7118                                       NaN
# 7043                                       NaN
# 74576                                      NaN
# 114562                                     NaN
# 75737              Conventional fixed mortgage
# 94258              Conventional fixed mortgage
# 71662                                      NaN
# 7335    Conventional adjustable mortgage (ARM)
#
#                                            Issue  \
# 57108   Loan servicing, payments, escrow account
# 26871     Incorrect information on credit report
# 28134                      Communication tactics
# 26705                   Deposits and withdrawals
# 35319   Loan servicing, payments, escrow account
# 123739  Loan servicing, payments, escrow account
# 1118       Cont'd attempts collect debt not owed
# 61197      Cont'd attempts collect debt not owed
# 14590   Application, originator, mortgage broker
# 112590                Closing/Cancelling account
# 3466       Cont'd attempts collect debt not owed
# 4341                       Communication tactics
# 69239   Application, originator, mortgage broker
# 44343              Credit line increase/decrease
# 52510     Incorrect information on credit report
# 101623                Managing the loan or lease
# 78058      Cont'd attempts collect debt not owed
# 32940                 Managing the loan or lease
# 88429        Problems when you are unable to pay
# 11078                      Communication tactics
# 15034       Taking/threatening an illegal action
# 75981      Cont'd attempts collect debt not owed
# 76750        Problems when you are unable to pay
# 112094   Account opening, closing, or management
# 14446             Credit decision / Underwriting
# 49396     Incorrect information on credit report
# 91923                          Billing statement
# 4139                             Sale of account
# 113444  Loan servicing, payments, escrow account
# 83010     Incorrect information on credit report
# 116097                             Fraud or scam
# 17115         Received a loan I didn't apply for
# 55126   Loan servicing, payments, escrow account
# 22600                 Managing the loan or lease
# 29919   Loan servicing, payments, escrow account
# 9048       Cont'd attempts collect debt not owed
# 49765            Disclosure verification of debt
# 54778     Incorrect information on credit report
# 53707   Loan servicing, payments, escrow account
# 32329   Application, originator, mortgage broker
# 65155       Taking/threatening an illegal action
# 1995       Cont'd attempts collect debt not owed
# 7118                          Delinquent account
# 7043      Incorrect information on credit report
# 74576                           Billing disputes
# 114562  Credit reporting company's investigation
# 75737   Loan modification,collection,foreclosure
# 94258   Loan modification,collection,foreclosure
# 71662     Incorrect information on credit report
# 7335    Loan modification,collection,foreclosure
#
#                                    Sub-issue  \
# 57108                                    NaN
# 26871                         Account status
# 28134             Frequent or repeated calls
# 26705                                    NaN
# 35319                                    NaN
# 123739                                   NaN
# 1118                           Debt was paid
# 61197                       Debt is not mine
# 14590                                    NaN
# 112590                                   NaN
# 3466                        Debt is not mine
# 4341         Threatened to take legal action
# 69239                                    NaN
# 44343                                    NaN
# 52510                         Account status
# 101623                                   NaN
# 78058                          Debt was paid
# 32940                                    NaN
# 88429                                    NaN
# 11078        Threatened to take legal action
# 15034     Seized/Attempted to seize property
# 75981                       Debt is not mine
# 76750                                    NaN
# 112094                                   NaN
# 14446                                    NaN
# 49396                Information is not mine
# 91923                                    NaN
# 4139                                     NaN
# 113444                                   NaN
# 83010                         Account status
# 116097                                   NaN
# 17115     Received a loan I didn't apply for
# 55126                                    NaN
# 22600                                    NaN
# 29919                                    NaN
# 9048                           Debt was paid
# 49765   Not given enough info to verify debt
# 54778                         Account status
# 53707                                    NaN
# 32329                                    NaN
# 65155   Sued where didn't live/sign for debt
# 1995                        Debt is not mine
# 7118                                     NaN
# 7043                           Public record
# 74576                                    NaN
# 114562     Problem with statement of dispute
# 75737                                    NaN
# 94258                                    NaN
# 71662                Information is not mine
# 7335                                     NaN
#
#                              Consumer complaint narrative  \
# 57108   My loan was originally serviced by XXXX XXXX. ...
# 26871   I have XXXX XXXX account on report that is XXX...
# 28134   Esser, James & Associates called my fathers ph...
# 26705   on XXXX XXXX 2015 at XXXX I walked in to Bank ...
# 35319   On or around XXXX XXXX, XXXX, I received a XXX...
# 123739  I refinanced a mortgage with a local bank who ...
# 1118    paid collection at XXXX XXXX/XXXX/2015 shows n...
# 61197   We received a letter addressed to my husband X...
# 14590   Approximately 18 months ago I restructured my ...
# 112590  I received a letter regarding credit card inac...
# 3466    Enhanced Recovery Corporation for XXXX XXXX XX...
# 4341    XXXX XXXX called several times from an unknown...
# 69239   DITECH is offering a misleading refinance prop...
# 44343   In year XXXX/XXXX/XXXX Citi reports to XXXX a ...
# 52510   Experian continue to maintain inaccurate accou...
# 101623  I obtained an auto loan back in 2015. I set pa...
# 78058   I payed off my debt but its still on my credit...
# 32940   I have been paying my auto loan for over two y...
# 88429   In XXXX of XXXX I took out an installment loan...
# 11078   The company Pressler and Pressler has been har...
# 15034   XXXX XXXX send me a renewal policy XX/XX/XXXX....
# 75981   For more than a month I have been receiving au...
# 76750   Honda Financial has not lived up to their prom...
# 112094  In XX/XX/2016, request to convert my CitiGold ...
# 14446   We are in disagreement with Bank of America Ho...
# 49396   does not belong to me please remove medical XX...
# 91923   On XXXX XXXX, 2015, I purchased XXXX shirts at...
# 4139    For years, I have had a XXXX Rewards Program c...
# 113444  PMI should automatically cancel when loan is u...
# 83010   My credit score randomly dropped XXXX points a...
# 116097  I made a purchase on XXXX XXXX which involved ...
# 17115   XX/XX/2012 my apartment was robbed. They stole...
# 55126   My mortgage payment was {$670.00} on both my G...
# 22600   My loan was reported to the credit bureau as p...
# 29919   Last week I began receiving collections calls ...
# 9048    This alleged debt is stale dated as it occurre...
# 49765   I have been negotiating in good faith with XXX...
# 54778   There are XXXX XXXX Mortgage accounts listed o...
# 53707   I have been experiencing on going problems wit...
# 32329   I am writing to you under a Power of Attorney ...
# 65155   M & S Recovery Solutions contact me staring th...
# 1995    Reached out to them however, never got a respo...
# 7118    I have an account with Spencer Savigs Bank whi...
# 7043    FICO ( R ) Score XXXXPowered by ExperianXXXXCr...
# 74576   A charge of XXXX was placed against my card fo...
# 114562  Experian unilaterally decided a compliant did ...
# 75737   I currently have Rushmore, ore Loan Servicing ...
# 94258   This is the second time we file a complaint ag...
# 71662   I have the credit bureaus to remove the citize...
# 7335    Hi my name is XXXX XXXX XXXX I am with.Sps ser...
#
#                                   Company public response  \
# 57108   Company has responded to the consumer and the ...
# 26871    Company chooses not to provide a public response
# 28134                                                 NaN
# 26705    Company chooses not to provide a public response
# 35319   Company believes it acted appropriately as aut...
# 123739  Company has responded to the consumer and the ...
# 1118     Company chooses not to provide a public response
# 61197                                                 NaN
# 14590                                                 NaN
# 112590                                                NaN
# 3466    Company believes it acted appropriately as aut...
# 4341                                                  NaN
# 69239                                                 NaN
# 44343    Company chooses not to provide a public response
# 52510    Company chooses not to provide a public response
# 101623  Company has responded to the consumer and the ...
# 78058   Company has responded to the consumer and the ...
# 32940    Company chooses not to provide a public response
# 88429                                                 NaN
# 11078   Company believes it acted appropriately as aut...
# 15034    Company chooses not to provide a public response
# 75981                                                 NaN
# 76750                                                 NaN
# 112094  Company has responded to the consumer and the ...
# 14446    Company chooses not to provide a public response
# 49396    Company chooses not to provide a public response
# 91923   Company has responded to the consumer and the ...
# 4139                                                  NaN
# 113444                                                NaN
# 83010   Company has responded to the consumer and the ...
# 116097                                                NaN
# 17115                                                 NaN
# 55126                                                 NaN
# 22600                                                 NaN
# 29919                                                 NaN
# 9048     Company chooses not to provide a public response
# 49765                                                 NaN
# 54778                                                 NaN
# 53707    Company chooses not to provide a public response
# 32329    Company chooses not to provide a public response
# 65155   Company believes complaint represents an oppor...
# 1995     Company chooses not to provide a public response
# 7118     Company chooses not to provide a public response
# 7043     Company chooses not to provide a public response
# 74576   Company has responded to the consumer and the ...
# 114562  Company has responded to the consumer and the ...
# 75737                                                 NaN
# 94258   Company has responded to the consumer and the ...
# 71662    Company chooses not to provide a public response
# 7335    Company believes it acted appropriately as aut...
#
#                                                Company State ZIP code  \
# 57108                                    MidFirst Bank    MD    211XX
# 26871           TransUnion Intermediate Holdings, Inc.    TX    752XX
# 28134                        Esser, James & Associates    CA    917XX
# 26705                                  Bank of America    TN    371XX
# 35319                  Select Portfolio Servicing, Inc    AZ    851XX
# 123739                           Wells Fargo & Company    AR    720XX
# 1118                     Diversified Consultants, Inc.    NM    871XX
# 61197                                      Capital One    MD    208XX
# 14590                              Nationstar Mortgage    NJ    080XX
# 112590                      TD Bank US Holding Company    CA    906XX
# 3466                                               ERC    CA    917XX
# 4341                    National Check Resolution Inc.    PA    190XX
# 69239                             Ditech Financial LLC    NV    891XX
# 44343                                         Citibank    CA    945XX
# 52510                                         Experian    TX    782XX
# 101623                           Wells Fargo & Company    TX    751XX
# 78058             FAIR COLLECTIONS & OUTSOURCING, INC.    NC    282XX
# 32940                                  Bank of America    FL    336XX
# 88429                            ACE Cash Express Inc.    TX    786XX
# 11078                         Pressler & Pressler, LLP    NY    148XX
# 15034   The Receivable Management Services Corporation    CA    926XX
# 75981                          Caine & Weiner Co. Inc.    PA    180XX
# 76750               American Honda Finance Corporation    MI    483XX
# 112094                                        Citibank    CA    917XX
# 14446                                  Bank of America    FL    328XX
# 49396           TransUnion Intermediate Holdings, Inc.    MO    631XX
# 91923                                         Citibank    DC    200XX
# 4139                      First National Bank of Omaha    MA    014XX
# 113444                            Ditech Financial LLC    CT    064XX
# 83010           TransUnion Intermediate Holdings, Inc.    VA    231XX
# 116097                                       MoneyGram    NM    875XX
# 17115                 Trident Asset Management, L.L.C.    OH    431XX
# 55126                Fifth Third Financial Corporation    TN    379XX
# 22600                        Ford Motor Credit Company    NE    680XX
# 29919                              Nationstar Mortgage    AL    362XX
# 9048                             Windham Professionals    CA    913XX
# 49765                     Peerless Credit Services Inc    PA    173XX
# 54778                                          Equifax    TX    782XX
# 53707                   Specialized Loan Servicing LLC    PA    183XX
# 32329                                  Bank of America    WA    985XX
# 65155                           M&S Recovery Solutions    DC    200XX
# 1995                                     FC HoldCo LLC    MD    207XX
# 7118                                      U.S. Bancorp    NJ    088XX
# 7043                                          Experian    MD    207XX
# 74576                                     U.S. Bancorp    DC    200XX
# 114562                                        Experian    TX    782XX
# 75737            Rushmore Loan Management Services LLC    MD    212XX
# 94258                                     U.S. Bancorp    TX    782XX
# 71662                                         Experian    NC    282XX
# 7335                   Select Portfolio Servicing, Inc    DC    200XX
#
#              ...        Consumer consent provided? Submitted via  \
# 57108        ...                  Consent provided           Web
# 26871        ...                  Consent provided           Web
# 28134        ...                  Consent provided           Web
# 26705        ...                  Consent provided           Web
# 35319        ...                  Consent provided           Web
# 123739       ...                  Consent provided           Web
# 1118         ...                  Consent provided           Web
# 61197        ...                  Consent provided           Web
# 14590        ...                  Consent provided           Web
# 112590       ...                  Consent provided           Web
# 3466         ...                  Consent provided           Web
# 4341         ...                  Consent provided           Web
# 69239        ...                  Consent provided           Web
# 44343        ...                  Consent provided           Web
# 52510        ...                  Consent provided           Web
# 101623       ...                  Consent provided           Web
# 78058        ...                  Consent provided           Web
# 32940        ...                  Consent provided           Web
# 88429        ...                  Consent provided           Web
# 11078        ...                  Consent provided           Web
# 15034        ...                  Consent provided           Web
# 75981        ...                  Consent provided           Web
# 76750        ...                  Consent provided           Web
# 112094       ...                  Consent provided           Web
# 14446        ...                  Consent provided           Web
# 49396        ...                  Consent provided           Web
# 91923        ...                  Consent provided           Web
# 4139         ...                  Consent provided           Web
# 113444       ...                  Consent provided           Web
# 83010        ...                  Consent provided           Web
# 116097       ...                  Consent provided           Web
# 17115        ...                  Consent provided           Web
# 55126        ...                  Consent provided           Web
# 22600        ...                  Consent provided           Web
# 29919        ...                  Consent provided           Web
# 9048         ...                  Consent provided           Web
# 49765        ...                  Consent provided           Web
# 54778        ...                  Consent provided           Web
# 53707        ...                  Consent provided           Web
# 32329        ...                  Consent provided           Web
# 65155        ...                  Consent provided           Web
# 1995         ...                  Consent provided           Web
# 7118         ...                  Consent provided           Web
# 7043         ...                  Consent provided           Web
# 74576        ...                  Consent provided           Web
# 114562       ...                  Consent provided           Web
# 75737        ...                  Consent provided           Web
# 94258        ...                  Consent provided           Web
# 71662        ...                  Consent provided           Web
# 7335         ...                  Consent provided           Web
#
#        Date sent to company     Company response to consumer Timely response?  \
# 57108             5/18/2016          Closed with explanation              Yes
# 26871              8/8/2015          Closed with explanation              Yes
# 28134              9/8/2015          Closed with explanation              Yes
# 26705              8/7/2015          Closed with explanation              Yes
# 35319              2/8/2016          Closed with explanation              Yes
# 123739           10/20/2016          Closed with explanation              Yes
# 1118              4/16/2015          Closed with explanation              Yes
# 61197             5/22/2015          Closed with explanation              Yes
# 14590             1/11/2016          Closed with explanation              Yes
# 112590           10/11/2016          Closed with explanation              Yes
# 3466              6/17/2015  Closed with non-monetary relief              Yes
# 4341              6/16/2015                           Closed              Yes
# 69239            11/20/2015          Closed with explanation              Yes
# 44343             7/30/2015          Closed with explanation              Yes
# 52510            12/16/2015          Closed with explanation              Yes
# 101623            8/11/2016          Closed with explanation               No
# 78058             4/29/2016          Closed with explanation              Yes
# 32940            12/25/2015  Closed with non-monetary relief              Yes
# 88429             6/30/2016          Closed with explanation              Yes
# 11078            11/14/2015          Closed with explanation              Yes
# 15034             2/15/2016  Closed with non-monetary relief              Yes
# 75981             4/20/2016          Closed with explanation              Yes
# 76750             4/29/2016      Closed with monetary relief              Yes
# 112094           11/18/2016      Closed with monetary relief              Yes
# 14446             1/14/2016          Closed with explanation              Yes
# 49396            10/30/2015          Closed with explanation              Yes
# 91923             6/15/2016      Closed with monetary relief              Yes
# 4139              6/29/2015          Closed with explanation              Yes
# 113444           10/13/2016          Closed with explanation              Yes
# 83010              5/8/2016  Closed with non-monetary relief              Yes
# 116097            9/21/2016          Closed with explanation              Yes
# 17115              3/8/2016  Closed with non-monetary relief               No
# 55126              3/4/2016          Closed with explanation              Yes
# 22600             6/11/2015          Closed with explanation              Yes
# 29919            10/16/2015          Closed with explanation              Yes
# 9048              9/17/2015  Closed with non-monetary relief              Yes
# 49765             11/5/2015          Closed with explanation               No
# 54778             2/23/2016          Closed with explanation              Yes
# 53707             1/27/2016          Closed with explanation              Yes
# 32329            12/11/2015          Closed with explanation              Yes
# 65155             8/27/2015          Closed with explanation              Yes
# 1995              5/21/2015  Closed with non-monetary relief              Yes
# 7118               8/7/2015          Closed with explanation              Yes
# 7043               8/6/2015          Closed with explanation              Yes
# 74576             3/16/2016          Closed with explanation              Yes
# 114562             9/4/2016  Closed with non-monetary relief              Yes
# 75737             4/13/2016          Closed with explanation              Yes
# 94258              8/3/2016          Closed with explanation              Yes
# 71662            12/21/2015  Closed with non-monetary relief              Yes
# 7335              8/21/2015          Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID  Consumer Claim  Company Offer  \
# 57108                 Yes      1929590       186088.48      107978.18
# 26871                  No      1509833            2.72           4.29
# 28134                  No      1552300           56.24          53.54
# 26705                  No      1508111           79.86          63.35
# 35319                 Yes      1778299       119001.57      -43404.74
# 123739                 No      2172560       145269.14      168226.87
# 1118                   No      1333776           69.68          61.16
# 61197                  No      1389659           71.77          64.46
# 14590                  No      1735152        44638.37      191273.62
# 112590                Yes      2155781          236.99         199.45
# 3466                   No      1425626           65.32          64.94
# 4341                   No      1413976           79.73          60.51
# 69239                 Yes      1665197       170679.21      174707.61
# 44343                 Yes      1495507          174.39         231.40
# 52510                  No      1706414            5.05           1.67
# 101623                 No      2059563         5559.18        5074.81
# 78058                  No      1903062           68.36          80.42
# 32940                  No      1716975         5168.42        3333.21
# 88429                  No      1992706         4650.48        3231.60
# 11078                 Yes      1655557           92.74          71.34
# 15034                  No      1787571           69.39          72.54
# 75981                  No      1888345           70.74          77.74
# 76750                  No      1901049         6549.81        3721.72
# 112094                NaN      2215118           80.64          58.40
# 14446                  No      1743600       171992.81      113252.22
# 49396                  No      1632456            4.06           7.74
# 91923                  No      1970921          330.00         162.95
# 4139                   No      1435820          255.58         146.27
# 113444                Yes      2158427       165395.04      107284.80
# 83010                  No      1915066            6.60           3.06
# 116097                 No      2117373           73.49          53.97
# 17115                  No      1820036           28.78          20.60
# 55126                  No      1817095       133336.58      111084.38
# 22600                  No      1416569         5747.63        3990.35
# 29919                  No      1610000       107135.12       78893.44
# 9048                  Yes      1559517           69.85          44.48
# 49765                  No      1642296           61.77          76.28
# 54778                  No      1801201            5.88           7.85
# 53707                  No      1759217       166764.66       50642.52
# 32329                 Yes      1693608       114771.64       85360.80
# 65155                  No      1518453           65.72          68.07
# 1995                   No      1383714           94.06          61.47
# 7118                   No      1507931          283.18         140.50
# 7043                   No      1507200            5.93           1.31
# 74576                  No      1835977          143.51         235.57
# 114562                 No      2095685            5.18           2.27
# 75737                  No      1878188        94102.06      102013.77
# 94258                 Yes      2044294       128568.00      116383.16
# 71662                  No      1711989            5.06           8.32
# 7335                   No      1529782       213047.44      100951.42
#
#         Amount Received
# 57108         128430.44
# 26871              3.57
# 28134             64.24
# 26705             42.31
# 35319          70317.17
# 123739         94565.75
# 1118              47.90
# 61197             60.27
# 14590          55133.04
# 112590           138.43
# 3466              49.90
# 4341              44.94
# 69239         -14251.51
# 44343            173.63
# 52510              1.86
# 101623          3227.94
# 78058             46.21
# 32940           1533.45
# 88429           2721.77
# 11078             45.02
# 15034             19.87
# 75981             45.29
# 76750           2810.62
# 112094            52.81
# 14446          48612.34
# 49396              3.52
# 91923            164.15
# 4139             169.15
# 113444         94765.64
# 83010              3.30
# 116097            57.80
# 17115              9.13
# 55126          57535.22
# 22600           3642.86
# 29919          99686.79
# 9048              49.15
# 49765             59.00
# 54778              5.52
# 53707         -12258.46
# 32329         128595.11
# 65155             38.27
# 1995              55.02
# 7118             133.39
# 7043               3.35
# 74576            123.60
# 114562             3.28
# 75737          51307.76
# 94258         108854.49
# 71662             -1.29
# 7335          168671.19
#
# [50 rows x 21 columns]

# %%
# 8. Get the dataframe 'df' column names

df.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID',
#        'Consumer Claim', 'Company Offer', 'Amount Received'],
#       dtype='object')

# %%
# 9. Assign the dataframe's index to a variable called 'index'. Get the index values.

index = df.index
index
# Out:
# RangeIndex(start=0, stop=125680, step=1)

# %%
# 10. Create a pandas.Series object with the values [1, 2, 3, 4, 5]. Assign it to varable 's'.

s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# 11. Get the mean, median, amd max of series 's'.

mean = s.mean()
med = s.median()
max_ = s.max()
print(mean, med, max_)
# Out:
# 3.0 3.0 5

# %%
# 12. Use series.plot() method to graph your series after import matplotlib; %matplotlib inline

import matplotlib

matplotlib.style.use('fivethirtyeight')

# %matplotlib inline

s.plot()

# %%
# 13. Add multiply each item in you df by 5 and assign to 's2'. Then use the cumsum() method on 's2'.

s2 = s * 5

s2.cumsum()
# Out:
# 0     5
# 1    15
# 2    30
# 3    50
# 4    75
# dtype: int64

# %%
# 14. Create a function that adds 2 to a number and prints it. series.map() it.

def my_function(x):
    x = x + 2 # x += 2
    print(x)
    return x

s.map(my_function);
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
# 15. Translate your series into raw numpy values.

s.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
# 16. Use the value_counts() method of the series to see the value counts.

s.value_counts()
# Out:
# 5    1
# 4    1
# 3    1
# 2    1
# 1    1
# dtype: int64

# %%
# 17. Write your data to disk using df.to_csv()

df.to_csv('data/new_location.csv')

# %%
# 18. Export this notebook using the file menu above.

# This is done via the menu.

# %% [markdown]
# ---
#
# ## Next Up: [Pandas Selection](12_pandas_selection.ipynb)
