# %% [markdown]
# <img style="float: right;" src="static/small.jpg">

# %% [markdown]
# ---
#
# # Pandas Selection Exercises
#
# See also: [Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html)
#
# ---

# %%
# 1. Import pandas as pd and read the CFPB CSV into a dataframe assigned variable 'df'.

import pandas as pd

df = pd.read_csv('data/cfpb_complaints_with_fictitious_data.csv')
df
# Out:
#        Date received                  Product  \
# 0          3/24/2015              Credit card
# 1          3/23/2015          Debt collection
# 2          3/23/2015              Credit card
# 3          3/23/2015         Credit reporting
# 4          3/23/2015          Debt collection
# 5          3/23/2015             Student loan
# 6          3/23/2015          Debt collection
# 7          3/23/2015         Credit reporting
# 8          3/23/2015              Credit card
# 9          3/23/2015          Debt collection
# 10         3/23/2015             Student loan
# 11         3/23/2015          Debt collection
# 12         3/23/2015                 Mortgage
# 13         3/23/2015                 Mortgage
# 14         3/23/2015          Debt collection
# 15         3/23/2015              Credit card
# 16         3/23/2015              Credit card
# 17         3/24/2015              Credit card
# 18         3/24/2015          Debt collection
# 19         3/24/2015                 Mortgage
# 20         3/24/2015              Payday loan
# 21         3/24/2015          Debt collection
# 22         3/24/2015                 Mortgage
# 23         3/24/2015  Bank account or service
# 24         3/24/2015          Debt collection
# 25         3/24/2015                 Mortgage
# 26         3/24/2015         Credit reporting
# 27         3/24/2015          Debt collection
# 28         3/24/2015  Bank account or service
# 29         3/24/2015          Debt collection
# ...              ...                      ...
# 125650    10/27/2016                 Mortgage
# 125651     9/29/2016            Consumer Loan
# 125652    10/18/2016  Bank account or service
# 125653    12/12/2016          Debt collection
# 125654    11/18/2016                 Mortgage
# 125655     12/2/2016          Debt collection
# 125656     11/4/2016             Student loan
# 125657    11/18/2016          Debt collection
# 125658    12/12/2016              Credit card
# 125659     11/9/2016          Debt collection
# 125660    12/13/2016  Bank account or service
# 125661     10/4/2016          Debt collection
# 125662    12/13/2016              Credit card
# 125663     11/6/2016             Student loan
# 125664    11/12/2016         Credit reporting
# 125665    11/10/2016         Credit reporting
# 125666    12/14/2016              Credit card
# 125667    12/13/2016  Bank account or service
# 125668     11/3/2016         Credit reporting
# 125669    11/19/2016          Debt collection
# 125670    11/18/2016          Debt collection
# 125671    11/16/2016          Debt collection
# 125672    11/19/2016         Credit reporting
# 125673     9/27/2016  Bank account or service
# 125674    12/13/2016                 Mortgage
# 125675    10/21/2016            Consumer Loan
# 125676    11/18/2016             Student loan
# 125677     11/4/2016  Bank account or service
# 125678     11/4/2016  Bank account or service
# 125679     11/9/2016         Credit reporting
#
#                                   Sub-product  \
# 0                                         NaN
# 1       Other (i.e. phone, health club, etc.)
# 2                                         NaN
# 3                                         NaN
# 4                                 Payday loan
# 5                    Non-federal student loan
# 6                                     Medical
# 7                                         NaN
# 8                                         NaN
# 9       Other (i.e. phone, health club, etc.)
# 10                   Non-federal student loan
# 11                                   Mortgage
# 12                               FHA mortgage
# 13                             Other mortgage
# 14                              I do not know
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18      Other (i.e. phone, health club, etc.)
# 19                             Other mortgage
# 20                                Payday loan
# 21                                Credit card
# 22                Conventional fixed mortgage
# 23                           Checking account
# 24                                Credit card
# 25                                VA mortgage
# 26                                        NaN
# 27                              I do not know
# 28                           Checking account
# 29                                       Auto
# ...                                       ...
# 125650            Conventional fixed mortgage
# 125651                       Installment loan
# 125652                       Checking account
# 125653                                Medical
# 125654                         Other mortgage
# 125655  Other (i.e. phone, health club, etc.)
# 125656               Non-federal student loan
# 125657                                Medical
# 125658                                    NaN
# 125659  Other (i.e. phone, health club, etc.)
# 125660                       Checking account
# 125661                                Medical
# 125662                                    NaN
# 125663         Federal student loan servicing
# 125664                                    NaN
# 125665                                    NaN
# 125666                                    NaN
# 125667                       Checking account
# 125668                                    NaN
# 125669                            Credit card
# 125670                          I do not know
# 125671                          I do not know
# 125672                                    NaN
# 125673                       Checking account
# 125674            Conventional fixed mortgage
# 125675                          Vehicle lease
# 125676               Non-federal student loan
# 125677             Other bank product/service
# 125678                       Checking account
# 125679                                    NaN
#
#                                            Issue  \
# 0                                          Other
# 1            Improper contact or sharing of info
# 2                                        Rewards
# 3         Incorrect information on credit report
# 4            Improper contact or sharing of info
# 5             Dealing with my lender or servicer
# 6          Cont'd attempts collect debt not owed
# 7         Incorrect information on credit report
# 8                                          Other
# 9          Cont'd attempts collect debt not owed
# 10                           Can't repay my loan
# 11                         Communication tactics
# 12      Loan servicing, payments, escrow account
# 13      Loan servicing, payments, escrow account
# 14               Disclosure verification of debt
# 15                                      Late fee
# 16                              Billing disputes
# 17                 Credit line increase/decrease
# 18            False statements or representation
# 19      Loan servicing, payments, escrow account
# 20            Can't stop charges to bank account
# 21         Cont'd attempts collect debt not owed
# 22                Credit decision / Underwriting
# 23                     Using a debit or ATM card
# 24                         Communication tactics
# 25      Loan servicing, payments, escrow account
# 26        Incorrect information on credit report
# 27               Disclosure verification of debt
# 28       Account opening, closing, or management
# 29            False statements or representation
# ...                                          ...
# 125650  Loan servicing, payments, escrow account
# 125651       Problems when you are unable to pay
# 125652     Problems caused by my funds being low
# 125653     Cont'd attempts collect debt not owed
# 125654  Application, originator, mortgage broker
# 125655     Cont'd attempts collect debt not owed
# 125656        Dealing with my lender or servicer
# 125657           Disclosure verification of debt
# 125658     Identity theft / Fraud / Embezzlement
# 125659     Cont'd attempts collect debt not owed
# 125660   Account opening, closing, or management
# 125661           Disclosure verification of debt
# 125662                                   Rewards
# 125663        Dealing with my lender or servicer
# 125664    Incorrect information on credit report
# 125665    Incorrect information on credit report
# 125666                                     Other
# 125667   Account opening, closing, or management
# 125668    Incorrect information on credit report
# 125669           Disclosure verification of debt
# 125670     Cont'd attempts collect debt not owed
# 125671       Improper contact or sharing of info
# 125672    Incorrect information on credit report
# 125673                 Using a debit or ATM card
# 125674  Loan servicing, payments, escrow account
# 125675                Managing the loan or lease
# 125676                       Can't repay my loan
# 125677   Account opening, closing, or management
# 125678                  Deposits and withdrawals
# 125679  Credit reporting company's investigation
#
#                                      Sub-issue  \
# 0                                          NaN
# 1            Contacted me after I asked not to
# 2                                          NaN
# 3                      Information is not mine
# 4        Talked to a third party about my debt
# 5        Having problems with customer service
# 6                                Debt was paid
# 7                      Information is not mine
# 8                                          NaN
# 9            Debt resulted from identity theft
# 10          Can't decrease my monthly payments
# 11             Threatened to take legal action
# 12                                         NaN
# 13                                         NaN
# 14        Not given enough info to verify debt
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18           Attempted to collect wrong amount
# 19                                         NaN
# 20          Can't stop charges to bank account
# 21           Debt was discharged in bankruptcy
# 22                                         NaN
# 23                                         NaN
# 24                  Frequent or repeated calls
# 25                                         NaN
# 26                              Account status
# 27      Not disclosed as an attempt to collect
# 28                                         NaN
# 29           Attempted to collect wrong amount
# ...                                        ...
# 125650                                     NaN
# 125651                                     NaN
# 125652                                     NaN
# 125653                        Debt is not mine
# 125654                                     NaN
# 125655                           Debt was paid
# 125656        Keep getting calls about my loan
# 125657    Right to dispute notice not received
# 125658                                     NaN
# 125659                        Debt is not mine
# 125660                                     NaN
# 125661    Not given enough info to verify debt
# 125662                                     NaN
# 125663  Received bad information about my loan
# 125664                          Account status
# 125665                    Personal information
# 125666                                     NaN
# 125667                                     NaN
# 125668                 Information is not mine
# 125669    Not given enough info to verify debt
# 125670                        Debt is not mine
# 125671   Talked to a third party about my debt
# 125672                 Information is not mine
# 125673                                     NaN
# 125674                                     NaN
# 125675                                     NaN
# 125676      Can't get flexible payment options
# 125677                                     NaN
# 125678                                     NaN
# 125679          Inadequate help over the phone
#
#                              Consumer complaint narrative  \
# 0       Received Capital One charge card offer XXXX. A...
# 1       I do n't know how they got my cell number. I t...
# 2       I 'm a longtime member of Charter One Bank/RBS...
# 3       After looking at my credit report, I saw a col...
# 4       I received a call from a XXXX XXXX from XXXX @...
# 5       Was not contacted 4 years later about some pri...
# 6       Collection Consultants is reporting a collecti...
# 7       I had my purse stolen in 2007. They never foun...
# 8       I attempted to apply for a Discover Card Onlin...
# 9       Continued attempts by XXXX XXXX XXXX to collec...
# 10      This is a continuation of a previous issue wit...
# 11      Going through a divorce, my ex and I were unab...
# 12      I am assisted with my mortgage through an agen...
# 13      i submitted a payment on XXXX XXXX 2015 for my...
# 14      I recieved a notice from Midland Credit Manage...
# 15      XXXX Card services was bought out by Capital O...
# 16      I was reported late by Discover Card to the re...
# 17      XXXX i receive an email from citibank regardin...
# 18      I agreed to a settlement arrangement on a acco...
# 19      Green Tree Financial somehow got XXXX Loan AFT...
# 20      I took out a Loan from Cash Central XXXX, Al f...
# 21      I filed ChapterXXXX bankruptcy on my accounts ...
# 22      To whom it may concern, To those that follow t...
# 23      I 'm no longer an account holder of SunTrust. ...
# 24      I 've been receiving numerous robocalls, hang-...
# 25      My mortgage servicer, Wells Fargo, did not giv...
# 26      Please investigate the practices of Experian. ...
# 27      Portfolio Recovery does not disclose who is ca...
# 28      After banking with Citibank for over 3 years, ...
# 29      I am a victim of a parked debt bought by a deb...
# ...                                                   ...
# 125650  My original mortgage was with XXXX. In XXXX 20...
# 125651                             Excessive daily calls.
# 125652  My checking account was set up to decline any ...
# 125653  I recently reviewed my credit reports and I ha...
# 125654  XXXX XXXX has had complaints filed against him...
# 125655  This Collection Agency keeps sending me and my...
# 125656  This is the third time I am writing you about ...
# 125657  I receive a call Capio Partners being disrespe...
# 125658  SYNCB/GAP ACCOUNT NUMBERs : XXXX XX/XX/XXXX XX...
# 125659  XXXX agent miss represent there service and pa...
# 125660  I applied for a joint checking account with my...
# 125661  I contacted this creditor on their secure logi...
# 125662  I signed up a new Citi XXXX XXXX credit card o...
# 125663  I have a unsubsidized Stafford loan from colle...
# 125664  This company XXXX just bought my loan in the p...
# 125665  I have incorrect info on my credit report with...
# 125666  Since the last few months I 've been unable to...
# 125667  I applied to join XXXX XXXX XXXX for a home lo...
# 125668  There was fraud on my account and does not bel...
# 125669  I have disputed this Capital One Credit card c...
# 125670  I received an alert from credit monitoring ser...
# 125671  First Source Adv. is contacting family members...
# 125672  This is a complaint against the Bureau of Equi...
# 125673  I do n't believe I had this account with bank ...
# 125674  On XX/XX/2016, I used online bill pay through ...
# 125675  I leased a vehicle from ALLY, paying all payme...
# 125676  Today my lender increased my private student l...
# 125677  In XXXX 2016, my computer crashed and deleted ...
# 125678  I opened a checking account with Simple Bank (...
# 125679  I have been contacting Transunion for over 2 m...
#
#                                   Company public response  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3        Company chooses not to provide a public response
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7        Company chooses not to provide a public response
# 8                                                     NaN
# 9                                                     NaN
# 10       Company chooses not to provide a public response
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17       Company chooses not to provide a public response
# 18                                                    NaN
# 19                                                    NaN
# 20       Company chooses not to provide a public response
# 21                                                    NaN
# 22                                                    NaN
# 23       Company chooses not to provide a public response
# 24                                                    NaN
# 25                                                    NaN
# 26       Company chooses not to provide a public response
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 125650                                                NaN
# 125651                                                NaN
# 125652                                                NaN
# 125653  Company believes it acted appropriately as aut...
# 125654                                                NaN
# 125655  Company believes it acted appropriately as aut...
# 125656  Company believes it acted appropriately as aut...
# 125657                                                NaN
# 125658  Company has responded to the consumer and the ...
# 125659                                                NaN
# 125660  Company believes it acted appropriately as aut...
# 125661                                                NaN
# 125662  Company has responded to the consumer and the ...
# 125663                                                NaN
# 125664  Company has responded to the consumer and the ...
# 125665  Company has responded to the consumer and the ...
# 125666  Company has responded to the consumer and the ...
# 125667  Company has responded to the consumer and the ...
# 125668                                                NaN
# 125669                                                NaN
# 125670                                                NaN
# 125671  Company believes it acted appropriately as aut...
# 125672                                                NaN
# 125673  Company has responded to the consumer and the ...
# 125674  Company believes it acted appropriately as aut...
# 125675  Company has responded to the consumer and the ...
# 125676                                                NaN
# 125677  Company has responded to the consumer and the ...
# 125678                                                NaN
# 125679  Company has responded to the consumer and the ...
#
#                                                   Company State ZIP code  \
# 0                                             Capital One    OH    440XX
# 1                            CCS Financial Services, Inc.    AR    727XX
# 2                          Citizens Financial Group, Inc.    MI    482XX
# 3                                                Experian    FL    331XX
# 4                                  Big Picture Loans, LLC    SC    291XX
# 5                          Oliphant Financial Corporation    IL    605XX
# 6                    Collection Consultants of California    CA    923XX
# 7                                                Experian    ME    044XX
# 8                                                Discover    MD    217XX
# 9                                   Stellar Recovery Inc.    CT    060XX
# 10                                               Citibank    SC    296XX
# 11                                               Citibank    FL    330XX
# 12                                   Ditech Financial LLC    GA    300XX
# 13                                                  Ocwen    IL    627XX
# 14                                   Encore Capital Group    TX    787XX
# 15                                            Capital One    MI    488XX
# 16                                               Discover    OK    741XX
# 17                                               Citibank    NV    891XX
# 18                                        MS Services LLC    TN    381XX
# 19                                   Ditech Financial LLC    CA    926XX
# 20                       Community Choice Financial, Inc.    AL    351XX
# 21                                   JPMorgan Chase & Co.    NE    681XX
# 22                                         Morgan Stanley    CA    944XX
# 23                                   SunTrust Banks, Inc.    FL    334XX
# 24                                                   Amex    CT    064XX
# 25                                  Wells Fargo & Company    TX    770XX
# 26                                               Experian    CA    900XX
# 27                    Portfolio Recovery Associates, Inc.    WA    980XX
# 28                                               Citibank    TX    797XX
# 29                   Accelerated Financial Solutions, LLC    NV    891XX
# ...                                                   ...   ...      ...
# 125650                                Nationstar Mortgage    NY    103XX
# 125651                                           RFNA, LP    GA    301XX
# 125652                                      Commerce Bank    MO    630XX
# 125653                                    ATG Credit, LLC    IL    605XX
# 125654              Integrity First Financial Group, Inc.    MO    631XX
# 125655                             Duncan Solutions, lnc.    CA    941XX
# 125656                    Capital Management Services, LP    GA    302XX
# 125657                                Capio Partners, LLC    FL    327XX
# 125658                                Synchrony Financial    FL    329XX
# 125659                                         Afni, Inc.    CA    945XX
# 125660                                       USAA Savings    IL    606XX
# 125661  The Law Offices of Mitchell D. Bluhm & Associates    FL    327XX
# 125662                                           Citibank    NY    115XX
# 125663                                             Nelnet    GA    306XX
# 125664                                           Experian    GA    300XX
# 125665             TransUnion Intermediate Holdings, Inc.    OK    730XX
# 125666                                    Bank of America    CA    941XX
# 125667  Fidelity National Information Services, Inc. (...    GA    301XX
# 125668                                       Factual Data    KY    405XX
# 125669                                        Capital One    IL    604XX
# 125670                           Midwest Recovery Systems    SC    291XX
# 125671                         FirstSource Advantage, LLC    PA    164XX
# 125672                                            Equifax    FL    331XX
# 125673                                    Bank of America    CA    900XX
# 125674                               Ditech Financial LLC    WI    535XX
# 125675                                Ally Financial Inc.    VA    201XX
# 125676                                          AES/PHEAA    NY    130XX
# 125677                                     BB&T Financial    PA    191XX
# 125678                                       BBVA Compass    VA    223XX
# 125679             TransUnion Intermediate Holdings, Inc.    IL    600XX
#
#              ...        Consumer consent provided? Submitted via  \
# 0            ...                  Consent provided           Web
# 1            ...                  Consent provided           Web
# 2            ...                  Consent provided           Web
# 3            ...                  Consent provided           Web
# 4            ...                  Consent provided           Web
# 5            ...                  Consent provided           Web
# 6            ...                  Consent provided           Web
# 7            ...                  Consent provided           Web
# 8            ...                  Consent provided           Web
# 9            ...                  Consent provided           Web
# 10           ...                  Consent provided           Web
# 11           ...                  Consent provided           Web
# 12           ...                  Consent provided           Web
# 13           ...                  Consent provided           Web
# 14           ...                  Consent provided           Web
# 15           ...                  Consent provided           Web
# 16           ...                  Consent provided           Web
# 17           ...                  Consent provided           Web
# 18           ...                  Consent provided           Web
# 19           ...                  Consent provided           Web
# 20           ...                  Consent provided           Web
# 21           ...                  Consent provided           Web
# 22           ...                  Consent provided           Web
# 23           ...                  Consent provided           Web
# 24           ...                  Consent provided           Web
# 25           ...                  Consent provided           Web
# 26           ...                  Consent provided           Web
# 27           ...                  Consent provided           Web
# 28           ...                  Consent provided           Web
# 29           ...                  Consent provided           Web
# ...          ...                               ...           ...
# 125650       ...                  Consent provided           Web
# 125651       ...                  Consent provided           Web
# 125652       ...                  Consent provided           Web
# 125653       ...                  Consent provided           Web
# 125654       ...                  Consent provided           Web
# 125655       ...                  Consent provided           Web
# 125656       ...                  Consent provided           Web
# 125657       ...                  Consent provided           Web
# 125658       ...                  Consent provided           Web
# 125659       ...                  Consent provided           Web
# 125660       ...                  Consent provided           Web
# 125661       ...                  Consent provided           Web
# 125662       ...                  Consent provided           Web
# 125663       ...                  Consent provided           Web
# 125664       ...                  Consent provided           Web
# 125665       ...                  Consent provided           Web
# 125666       ...                  Consent provided           Web
# 125667       ...                  Consent provided           Web
# 125668       ...                  Consent provided           Web
# 125669       ...                  Consent provided           Web
# 125670       ...                  Consent provided           Web
# 125671       ...                  Consent provided           Web
# 125672       ...                  Consent provided           Web
# 125673       ...                  Consent provided           Web
# 125674       ...                  Consent provided           Web
# 125675       ...                  Consent provided           Web
# 125676       ...                  Consent provided           Web
# 125677       ...                  Consent provided           Web
# 125678       ...                  Consent provided           Web
# 125679       ...                  Consent provided           Web
#
#        Date sent to company     Company response to consumer Timely response?  \
# 0                 3/30/2015          Closed with explanation              Yes
# 1                 3/23/2015          Closed with explanation              Yes
# 2                 3/23/2015          Closed with explanation              Yes
# 3                 3/27/2015  Closed with non-monetary relief              Yes
# 4                 3/23/2015          Closed with explanation              Yes
# 5                 3/25/2015          Closed with explanation              Yes
# 6                 4/30/2015          Closed with explanation              Yes
# 7                 3/23/2015          Closed with explanation              Yes
# 8                 3/23/2015  Closed with non-monetary relief              Yes
# 9                 3/25/2015          Closed with explanation              Yes
# 10                3/25/2015          Closed with explanation              Yes
# 11                3/23/2015          Closed with explanation              Yes
# 12                3/23/2015      Closed with monetary relief              Yes
# 13                3/23/2015          Closed with explanation              Yes
# 14                3/23/2015  Closed with non-monetary relief              Yes
# 15                3/23/2015      Closed with monetary relief              Yes
# 16                3/23/2015          Closed with explanation              Yes
# 17                3/24/2015          Closed with explanation              Yes
# 18                3/24/2015          Closed with explanation              Yes
# 19                3/24/2015  Closed with non-monetary relief              Yes
# 20                3/24/2015          Closed with explanation              Yes
# 21                3/24/2015          Closed with explanation              Yes
# 22                3/24/2015          Closed with explanation              Yes
# 23                3/24/2015          Closed with explanation              Yes
# 24                3/24/2015          Closed with explanation              Yes
# 25                3/24/2015          Closed with explanation              Yes
# 26                3/24/2015          Closed with explanation              Yes
# 27                3/25/2015  Closed with non-monetary relief              Yes
# 28                3/24/2015          Closed with explanation              Yes
# 29                3/24/2015          Closed with explanation              Yes
# ...                     ...                              ...              ...
# 125650           10/27/2016          Closed with explanation              Yes
# 125651            11/4/2016          Closed with explanation              Yes
# 125652           10/18/2016          Closed with explanation              Yes
# 125653           12/12/2016          Closed with explanation              Yes
# 125654           11/18/2016          Closed with explanation               No
# 125655           12/13/2016          Closed with explanation              Yes
# 125656            11/7/2016          Closed with explanation              Yes
# 125657           11/18/2016  Closed with non-monetary relief              Yes
# 125658           12/12/2016          Closed with explanation              Yes
# 125659            11/9/2016          Closed with explanation              Yes
# 125660           12/13/2016  Closed with non-monetary relief              Yes
# 125661           11/14/2016  Closed with non-monetary relief              Yes
# 125662           12/13/2016          Closed with explanation              Yes
# 125663            11/6/2016          Closed with explanation              Yes
# 125664           11/12/2016          Closed with explanation              Yes
# 125665           11/10/2016          Closed with explanation              Yes
# 125666           12/14/2016          Closed with explanation              Yes
# 125667           12/13/2016          Closed with explanation              Yes
# 125668            11/3/2016          Closed with explanation              Yes
# 125669           11/19/2016          Closed with explanation              Yes
# 125670           11/18/2016                Untimely response               No
# 125671           11/16/2016          Closed with explanation              Yes
# 125672           11/19/2016          Closed with explanation              Yes
# 125673            9/30/2016          Closed with explanation              Yes
# 125674           12/13/2016          Closed with explanation              Yes
# 125675           10/21/2016          Closed with explanation              Yes
# 125676           11/18/2016          Closed with explanation              Yes
# 125677            11/4/2016          Closed with explanation              Yes
# 125678            11/4/2016          Closed with explanation              Yes
# 125679            11/9/2016          Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID  Consumer Claim  Company Offer  \
# 0                      No      1297939          332.63         217.18
# 1                      No      1296593           54.79          41.48
# 2                     Yes      1296693          215.04         231.67
# 3                      No      1296955            3.31           6.30
# 4                      No      1296727           73.99          76.75
# 5                      No      1296773        15869.20       14414.94
# 6                      No      1296774           47.43          55.38
# 7                      No      1296785            5.47           4.06
# 8                      No      1295056          262.58         220.21
# 9                      No      1296777           84.60          81.44
# 10                     No      1295228        17690.44       25099.77
# 11                     No      1295146           78.73          59.09
# 12                    Yes      1296823       185482.51      159366.50
# 13                     No      1296831       101340.54      182761.24
# 14                     No      1295409           81.47          45.18
# 15                     No      1296880          240.76         162.92
# 16                     No      1296890          258.53         232.54
# 17                    Yes      1299216          186.52         278.21
# 18                     No      1297589           56.39          62.17
# 19                     No      1297594       103381.81      186432.77
# 20                     No      1299258            6.02          25.44
# 21                    Yes      1297609           72.04          64.01
# 22                     No      1297626       219860.35      153908.22
# 23                     No      1297629           88.66          70.81
# 24                     No      1297377           74.58          63.52
# 25                     No      1297644       153377.06      169317.86
# 26                     No      1297500            3.31           1.29
# 27                     No      1297662           70.24          68.01
# 28                     No      1297676           86.24          62.34
# 29                    Yes      1297316           60.50          67.60
# ...                   ...          ...             ...            ...
# 125650                 No      2182081       236687.68      221160.59
# 125651                 No      2139621         5753.08        3347.99
# 125652                 No      2165678           73.34          59.51
# 125653                NaN      2245422           83.07          76.03
# 125654                NaN      2215900        74632.68       57102.99
# 125655                NaN      2233235           61.07          55.34
# 125656                 No      2197243        20249.89        9145.76
# 125657                NaN      2215200           82.64          57.09
# 125658                Yes      2244918          220.97         276.09
# 125659                 No      2201273           59.04          60.44
# 125660                NaN      2247284           78.73          68.11
# 125661                 No      2145608           83.07          69.67
# 125662                Yes      2248594          258.87         189.00
# 125663                 No      2198041        16803.25       24457.31
# 125664                 No      2205209            3.41           4.04
# 125665                 No      2203177            7.37           5.44
# 125666                NaN      2247267          214.31         205.83
# 125667                NaN      2248753           73.33          70.85
# 125668                 No      2193913            2.40           2.11
# 125669                NaN      2216039           87.67          54.43
# 125670                NaN      2213687           79.67          56.16
# 125671                 No      2210820           85.51          73.63
# 125672                NaN      2215661            7.25           2.12
# 125673                 No      2133648           69.74          67.79
# 125674                NaN      2247724       136798.52      114342.28
# 125675                 No      2170435         4126.85        4797.82
# 125676                NaN      2215331        24212.35       24333.23
# 125677                 No      2194728           75.45          69.03
# 125678                 No      2196938           70.11          63.83
# 125679                 No      2202865            4.17           4.67
#
#         Amount Received
# 0                130.22
# 1                 49.14
# 2                155.28
# 3                  4.59
# 4                 46.02
# 5              12964.40
# 6                 31.79
# 7                  6.69
# 8                 96.66
# 9                 65.64
# 10             12962.02
# 11                58.94
# 12            234193.94
# 13            122579.47
# 14                45.77
# 15               174.56
# 16               194.73
# 17               288.13
# 18                37.96
# 19            110905.24
# 20                19.35
# 21                42.37
# 22             99746.42
# 23                53.64
# 24                34.51
# 25             79792.59
# 26                 0.34
# 27                45.16
# 28                44.37
# 29                45.81
# ...                 ...
# 125650         64958.93
# 125651          4810.15
# 125652            49.38
# 125653            47.62
# 125654        182860.61
# 125655            34.73
# 125656          6248.93
# 125657            57.02
# 125658            91.89
# 125659            33.40
# 125660            46.51
# 125661            51.44
# 125662           129.45
# 125663         20028.10
# 125664             0.90
# 125665             2.49
# 125666           225.27
# 125667            44.17
# 125668             5.82
# 125669            65.87
# 125670            39.76
# 125671            27.10
# 125672             0.92
# 125673            41.98
# 125674        106343.36
# 125675          1931.60
# 125676          5957.27
# 125677            44.28
# 125678            35.03
# 125679            -0.18
#
# [125680 rows x 21 columns]

# %%
# 2. Select a single column via bracket notation []. What is the type of the column?

type(df['Product']) # df.Product
# Out:
# pandas.core.series.Series

# %%
# 3. Select two or more columns using double bracket notation (list inside of brackets).

df[['Product', 'Sub-product']].head(5)
# Out:
#             Product                            Sub-product
# 0       Credit card                                    NaN
# 1   Debt collection  Other (i.e. phone, health club, etc.)
# 2       Credit card                                    NaN
# 3  Credit reporting                                    NaN
# 4   Debt collection                            Payday loan

# %%
# 4. Use the dataframe's loc[] attribute to get the first row of the df by index.

df.loc[0]
# Out:
# Date received                                                           3/24/2015
# Product                                                               Credit card
# Sub-product                                                                   NaN
# Issue                                                                       Other
# Sub-issue                                                                     NaN
# Consumer complaint narrative    Received Capital One charge card offer XXXX. A...
# Company public response                                                       NaN
# Company                                                               Capital One
# State                                                                          OH
# ZIP code                                                                    440XX
# Tags                                                                          NaN
# Consumer consent provided?                                       Consent provided
# Submitted via                                                                 Web
# Date sent to company                                                    3/30/2015
# Company response to consumer                              Closed with explanation
# Timely response?                                                              Yes
# Consumer disputed?                                                             No
# Complaint ID                                                              1297939
# Consumer Claim                                                             332.63
# Company Offer                                                              217.18
# Amount Received                                                            130.22
# Name: 0, dtype: object

# %%
# 5. Use iloc[] to get the last row of the dataframe by number.

df.iloc[-1]
# Out:
# Date received                                                           11/9/2016
# Product                                                          Credit reporting
# Sub-product                                                                   NaN
# Issue                                    Credit reporting company's investigation
# Sub-issue                                          Inadequate help over the phone
# Consumer complaint narrative    I have been contacting Transunion for over 2 m...
# Company public response         Company has responded to the consumer and the ...
# Company                                    TransUnion Intermediate Holdings, Inc.
# State                                                                          IL
# ZIP code                                                                    600XX
# Tags                                                                          NaN
# Consumer consent provided?                                       Consent provided
# Submitted via                                                                 Web
# Date sent to company                                                    11/9/2016
# Company response to consumer                              Closed with explanation
# Timely response?                                                              Yes
# Consumer disputed?                                                             No
# Complaint ID                                                              2202865
# Consumer Claim                                                               4.17
# Company Offer                                                                4.67
# Amount Received                                                             -0.18
# Name: 125679, dtype: object

# %%
# 6. # Use df[] notation to get a True/False series for 'Product == Mortgage'. Assign to 'mask', then show.

mask = df['Product'] == 'Mortgage'
df[mask]
# Out:
#        Date received   Product                             Sub-product  \
# 12         3/23/2015  Mortgage                            FHA mortgage
# 13         3/23/2015  Mortgage                          Other mortgage
# 19         3/24/2015  Mortgage                          Other mortgage
# 22         3/24/2015  Mortgage             Conventional fixed mortgage
# 25         3/24/2015  Mortgage                             VA mortgage
# 33         3/24/2015  Mortgage             Conventional fixed mortgage
# 43         3/24/2015  Mortgage             Conventional fixed mortgage
# 44         3/19/2015  Mortgage             Conventional fixed mortgage
# 46         3/19/2015  Mortgage                        Reverse mortgage
# 47         3/19/2015  Mortgage             Conventional fixed mortgage
# 48         3/19/2015  Mortgage             Conventional fixed mortgage
# 49         3/19/2015  Mortgage             Conventional fixed mortgage
# 50         3/19/2015  Mortgage                            FHA mortgage
# 57         3/19/2015  Mortgage      Home equity loan or line of credit
# 58         3/24/2015  Mortgage                          Other mortgage
# 64         3/24/2015  Mortgage             Conventional fixed mortgage
# 69         3/19/2015  Mortgage             Conventional fixed mortgage
# 72         3/27/2015  Mortgage      Home equity loan or line of credit
# 81         3/27/2015  Mortgage                          Other mortgage
# 87         3/19/2015  Mortgage             Conventional fixed mortgage
# 88         3/24/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 101        3/27/2015  Mortgage             Conventional fixed mortgage
# 102        3/27/2015  Mortgage             Conventional fixed mortgage
# 104        3/19/2015  Mortgage             Conventional fixed mortgage
# 107        3/24/2015  Mortgage                            FHA mortgage
# 121        3/19/2015  Mortgage                            FHA mortgage
# 122        3/24/2015  Mortgage             Conventional fixed mortgage
# 127        3/19/2015  Mortgage                            FHA mortgage
# 131        3/27/2015  Mortgage                            FHA mortgage
# 139        3/19/2015  Mortgage             Conventional fixed mortgage
# ...              ...       ...                                     ...
# 125541     10/2/2016  Mortgage             Conventional fixed mortgage
# 125543    12/13/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125546    12/13/2016  Mortgage                             VA mortgage
# 125553     6/30/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 125557    11/16/2016  Mortgage             Conventional fixed mortgage
# 125564    10/26/2016  Mortgage             Conventional fixed mortgage
# 125582    12/13/2016  Mortgage                             VA mortgage
# 125583     10/7/2016  Mortgage             Conventional fixed mortgage
# 125585    12/10/2016  Mortgage      Home equity loan or line of credit
# 125591     12/9/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125593    11/11/2016  Mortgage                            FHA mortgage
# 125596     11/3/2016  Mortgage                             VA mortgage
# 125601    10/19/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125610    12/13/2016  Mortgage                            FHA mortgage
# 125616    11/19/2016  Mortgage      Home equity loan or line of credit
# 125618     9/23/2016  Mortgage                            FHA mortgage
# 125619    11/18/2016  Mortgage             Conventional fixed mortgage
# 125620    10/10/2016  Mortgage                             VA mortgage
# 125621    10/31/2016  Mortgage             Conventional fixed mortgage
# 125622     11/2/2016  Mortgage                            FHA mortgage
# 125623    12/13/2016  Mortgage             Conventional fixed mortgage
# 125632    11/18/2016  Mortgage             Conventional fixed mortgage
# 125634    10/26/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125636     11/5/2016  Mortgage             Conventional fixed mortgage
# 125638    11/18/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125645    11/18/2016  Mortgage                            FHA mortgage
# 125647     9/20/2016  Mortgage             Conventional fixed mortgage
# 125650    10/27/2016  Mortgage             Conventional fixed mortgage
# 125654    11/18/2016  Mortgage                          Other mortgage
# 125674    12/13/2016  Mortgage             Conventional fixed mortgage
#
#                                            Issue Sub-issue  \
# 12      Loan servicing, payments, escrow account       NaN
# 13      Loan servicing, payments, escrow account       NaN
# 19      Loan servicing, payments, escrow account       NaN
# 22                Credit decision / Underwriting       NaN
# 25      Loan servicing, payments, escrow account       NaN
# 33      Loan servicing, payments, escrow account       NaN
# 43      Loan servicing, payments, escrow account       NaN
# 44                Credit decision / Underwriting       NaN
# 46      Application, originator, mortgage broker       NaN
# 47      Loan servicing, payments, escrow account       NaN
# 48      Loan servicing, payments, escrow account       NaN
# 49      Loan servicing, payments, escrow account       NaN
# 50      Application, originator, mortgage broker       NaN
# 57      Loan servicing, payments, escrow account       NaN
# 58                  Settlement process and costs       NaN
# 64      Loan servicing, payments, escrow account       NaN
# 69      Loan modification,collection,foreclosure       NaN
# 72      Loan modification,collection,foreclosure       NaN
# 81      Loan servicing, payments, escrow account       NaN
# 87      Loan servicing, payments, escrow account       NaN
# 88      Loan servicing, payments, escrow account       NaN
# 101     Loan modification,collection,foreclosure       NaN
# 102     Loan modification,collection,foreclosure       NaN
# 104                 Settlement process and costs       NaN
# 107     Loan servicing, payments, escrow account       NaN
# 121     Loan servicing, payments, escrow account       NaN
# 122     Loan servicing, payments, escrow account       NaN
# 127     Loan servicing, payments, escrow account       NaN
# 131     Loan modification,collection,foreclosure       NaN
# 139     Loan modification,collection,foreclosure       NaN
# ...                                          ...       ...
# 125541  Loan modification,collection,foreclosure       NaN
# 125543  Loan modification,collection,foreclosure       NaN
# 125546  Application, originator, mortgage broker       NaN
# 125553  Loan modification,collection,foreclosure       NaN
# 125557  Application, originator, mortgage broker       NaN
# 125564  Loan modification,collection,foreclosure       NaN
# 125582              Settlement process and costs       NaN
# 125583  Loan servicing, payments, escrow account       NaN
# 125585  Application, originator, mortgage broker       NaN
# 125591              Settlement process and costs       NaN
# 125593  Loan modification,collection,foreclosure       NaN
# 125596  Loan servicing, payments, escrow account       NaN
# 125601              Settlement process and costs       NaN
# 125610            Credit decision / Underwriting       NaN
# 125616  Loan servicing, payments, escrow account       NaN
# 125618  Loan servicing, payments, escrow account       NaN
# 125619  Loan servicing, payments, escrow account       NaN
# 125620  Loan servicing, payments, escrow account       NaN
# 125621  Loan servicing, payments, escrow account       NaN
# 125622  Loan servicing, payments, escrow account       NaN
# 125623  Loan servicing, payments, escrow account       NaN
# 125632  Loan modification,collection,foreclosure       NaN
# 125634  Loan modification,collection,foreclosure       NaN
# 125636            Credit decision / Underwriting       NaN
# 125638  Loan modification,collection,foreclosure       NaN
# 125645  Loan servicing, payments, escrow account       NaN
# 125647  Loan servicing, payments, escrow account       NaN
# 125650  Loan servicing, payments, escrow account       NaN
# 125654  Application, originator, mortgage broker       NaN
# 125674  Loan servicing, payments, escrow account       NaN
#
#                              Consumer complaint narrative  \
# 12      I am assisted with my mortgage through an agen...
# 13      i submitted a payment on XXXX XXXX 2015 for my...
# 19      Green Tree Financial somehow got XXXX Loan AFT...
# 22      To whom it may concern, To those that follow t...
# 25      My mortgage servicer, Wells Fargo, did not giv...
# 33      I paid off my mortgage with XXXX Mortgage Serv...
# 43      I was emailed that my online account had been ...
# 44      XXXX was submitted XX/XX/XXXX. At the time I s...
# 46      I am very disappointed that the CFPB did not h...
# 47      We fell behind in our payments back in 2014 fo...
# 48      I am a Successor - in -interest to a property ...
# 49      I am writing this letter because my mortgage a...
# 50      I had a mortgage with from XXXX of XXXX to XXX...
# 57      I made a payment on a {$69000.00} loan of $ XX...
# 58      I applied for a loan modification with Suntrus...
# 64      I was {$48.00} behind on our mortgage because ...
# 69      I have been trying to get an audit of my accou...
# 72      We had a Line of Credit with US Bank that was ...
# 81      Ocwen financial services claims simultaneously...
# 87      I had a mortgage with XXXX XXXX XXXX from XXXX...
# 88      I schedule my mortgage payment, using the mort...
# 101     My wife and I just went through 7 months of ap...
# 102     We have been working or a Short Sale for Selec...
# 104     I got behind in payments and worked with B of ...
# 107     Yesterday, I called my mortgage company, Ocwen...
# 121     Wells Fargo Mortgage began foreclosure action ...
# 122     Caliber Home loans has claimed to have made pa...
# 127     Our Mortgage was sold to Carrington Mortgage S...
# 131     I was part of the XXXX and received payment la...
# 139     We are a victim of Ocwen mortgage and their fr...
# ...                                                   ...
# 125541  I am trying to get approved for a loan modific...
# 125543  I have asked Nationstar for assistance for a f...
# 125546  In XX/XX/2016, I received a solicitation from ...
# 125553  XX/XX/XXXX  Immediate concern: Stop  the forec...
# 125557  I was advised by XXXX XXXX at omni mortgage th...
# 125564  I am so devastated and so very disappointed wi...
# 125582  I contracted with USAA Federal Savings Bank to...
# 125583  Since the purchase of my house throughout the ...
# 125585  Over a period a six months, my XXXX mother app...
# 125591  RE : Complaint # XXXX Subject : XXXX / Foreclo...
# 125593  I am trying to get a principal reduction for m...
# 125596  US Bank has not released the lien and sent pro...
# 125601  I filed a rescission to my mortgage lender yea...
# 125610  Sales Manager keeps asking for same info repea...
# 125616  OWCEN made an error on my XXXX XXXX, 2016 and ...
# 125618  My loan was transferred to DiTech for servicin...
# 125619  I just refinanced my mortgage to a 15 yr fixed...
# 125620  Monday, XX/XX/XXXX " From : XXXX XXXX XXXX XXX...
# 125621  My mortgage company ( Ditech ) changed their c...
# 125622  Please see CFPB case # XXXX - I am submitting ...
# 125623  SLS purchased the servicing of my mortgage fro...
# 125632  We had a loan modification done with Nationsta...
# 125634  I have doubled my income in the last 2 months ...
# 125636  Nova financial, you are better off finding ano...
# 125638  I have been working with my lender for a loan ...
# 125645  I obtain a mortgage loan from Finance of Ameri...
# 125647  I have had my mortgage loan through Bank of Am...
# 125650  My original mortgage was with XXXX. In XXXX 20...
# 125654  XXXX XXXX has had complaints filed against him...
# 125674  On XX/XX/2016, I used online bill pay through ...
#
#                                   Company public response  \
# 12                                                    NaN
# 13                                                    NaN
# 19                                                    NaN
# 22                                                    NaN
# 25                                                    NaN
# 33                                                    NaN
# 43                                                    NaN
# 44                                                    NaN
# 46                                                    NaN
# 47                                                    NaN
# 48                                                    NaN
# 49      Company believes it acted appropriately as aut...
# 50                                                    NaN
# 57                                                    NaN
# 58       Company chooses not to provide a public response
# 64                                                    NaN
# 69                                                    NaN
# 72       Company chooses not to provide a public response
# 81                                                    NaN
# 87                                                    NaN
# 88      Company believes it acted appropriately as aut...
# 101      Company chooses not to provide a public response
# 102     Company believes it acted appropriately as aut...
# 104      Company chooses not to provide a public response
# 107                                                   NaN
# 121                                                   NaN
# 122                                                   NaN
# 127                                                   NaN
# 131      Company chooses not to provide a public response
# 139                                                   NaN
# ...                                                   ...
# 125541  Company has responded to the consumer and the ...
# 125543  Company believes it acted appropriately as aut...
# 125546  Company has responded to the consumer and the ...
# 125553   Company chooses not to provide a public response
# 125557                                                NaN
# 125564  Company believes it acted appropriately as aut...
# 125582  Company believes complaint is the result of an...
# 125583                                                NaN
# 125585  Company has responded to the consumer and the ...
# 125591  Company believes it acted appropriately as aut...
# 125593  Company has responded to the consumer and the ...
# 125596  Company has responded to the consumer and the ...
# 125601                                                NaN
# 125610  Company believes it acted appropriately as aut...
# 125616                                                NaN
# 125618  Company believes complaint represents an oppor...
# 125619                                                NaN
# 125620  Company has responded to the consumer and the ...
# 125621  Company believes complaint represents an oppor...
# 125622                                                NaN
# 125623  Company has responded to the consumer and the ...
# 125632                                                NaN
# 125634  Company has responded to the consumer and the ...
# 125636                                                NaN
# 125638                                                NaN
# 125645                                                NaN
# 125647  Company has responded to the consumer and the ...
# 125650                                                NaN
# 125654                                                NaN
# 125674  Company believes it acted appropriately as aut...
#
#                                         Company State ZIP code  \
# 12                         Ditech Financial LLC    GA    300XX
# 13                                        Ocwen    IL    627XX
# 19                         Ditech Financial LLC    CA    926XX
# 22                               Morgan Stanley    CA    944XX
# 25                        Wells Fargo & Company    TX    770XX
# 33             HSBC North America Holdings Inc.    NY    141XX
# 43                        Wells Fargo & Company    MT    598XX
# 44        Rushmore Loan Management Services LLC    CA    956XX
# 46                CIT Bank National Association    NJ    080XX
# 47                          Nationstar Mortgage    VA    230XX
# 48                          Nationstar Mortgage    CA    925XX
# 49              Select Portfolio Servicing, Inc    NJ    080XX
# 50               Citizens Financial Group, Inc.    MA    021XX
# 57               Specialized Loan Servicing LLC    NJ    074XX
# 58                         SunTrust Banks, Inc.    CO    804XX
# 64                         Ditech Financial LLC    MA    020XX
# 69                                     Citibank    MD    207XX
# 72                                 U.S. Bancorp    CO    801XX
# 81                                        Ocwen    MA    017XX
# 87                          Nationstar Mortgage    TX    775XX
# 88                          Nationstar Mortgage    GA    300XX
# 101                                U.S. Bancorp    KS    664XX
# 102             Select Portfolio Servicing, Inc    FL    333XX
# 104                             Bank of America    CA    926XX
# 107                                       Ocwen    TX    770XX
# 121                       Wells Fargo & Company    AZ    853XX
# 122                     Caliber Home Loans, Inc    IN    463XX
# 127          Carrington Mortgage Holdings, LLC.    TX    755XX
# 131                             Bank of America    GA    309XX
# 139                                       Ocwen    KS    666XX
# ...                                         ...   ...      ...
# 125541                    Wells Fargo & Company    CA    945XX
# 125543                      Nationstar Mortgage    CA    920XX
# 125546                         Freedom Mortgage    SC    295XX
# 125553                    Wells Fargo & Company    CA    943XX
# 125557                OMNI MORTGAGE CORPORATION    NY    117XX
# 125564      North Dakota Housing Finance Agency    ND    586XX
# 125582                             USAA Savings    GA    303XX
# 125583                      Nationstar Mortgage    UT    846XX
# 125585                           BB&T Financial    TX    752XX
# 125591                 Shellpoint Partners, LLC    CA    949XX
# 125593                     SunTrust Banks, Inc.    GA    302XX
# 125596                             U.S. Bancorp    FL    329XX
# 125601                                    Ocwen    NJ    078XX
# 125610               Nations Lending Coporation    OH    430XX
# 125616                                    Ocwen    NY    102XX
# 125618                     Ditech Financial LLC    PA    190XX
# 125619                              Arvest Bank    IN    463XX
# 125620                     Round Point Mortgage    GA    300XX
# 125621                     Ditech Financial LLC    TX    750XX
# 125622                Dovenmuehle Mortgage Inc.    PA    191XX
# 125623           Specialized Loan Servicing LLC    NY    100XX
# 125632                      Nationstar Mortgage    TN    377XX
# 125634                          Bank of America    CA    900XX
# 125636  NOVA Financial & Investment Corporation    AZ    856XX
# 125638                  Caliber Home Loans, Inc    CA    925XX
# 125645          Finance of America Mortgage LLC    NJ    083XX
# 125647                          Bank of America    WI    531XX
# 125650                      Nationstar Mortgage    NY    103XX
# 125654    Integrity First Financial Group, Inc.    MO    631XX
# 125674                     Ditech Financial LLC    WI    535XX
#
#              ...        Consumer consent provided? Submitted via  \
# 12           ...                  Consent provided           Web
# 13           ...                  Consent provided           Web
# 19           ...                  Consent provided           Web
# 22           ...                  Consent provided           Web
# 25           ...                  Consent provided           Web
# 33           ...                  Consent provided           Web
# 43           ...                  Consent provided           Web
# 44           ...                  Consent provided           Web
# 46           ...                  Consent provided           Web
# 47           ...                  Consent provided           Web
# 48           ...                  Consent provided           Web
# 49           ...                  Consent provided           Web
# 50           ...                  Consent provided           Web
# 57           ...                  Consent provided           Web
# 58           ...                  Consent provided           Web
# 64           ...                  Consent provided           Web
# 69           ...                  Consent provided           Web
# 72           ...                  Consent provided           Web
# 81           ...                  Consent provided           Web
# 87           ...                  Consent provided           Web
# 88           ...                  Consent provided           Web
# 101          ...                  Consent provided           Web
# 102          ...                  Consent provided           Web
# 104          ...                  Consent provided           Web
# 107          ...                  Consent provided           Web
# 121          ...                  Consent provided           Web
# 122          ...                  Consent provided           Web
# 127          ...                  Consent provided           Web
# 131          ...                  Consent provided           Web
# 139          ...                  Consent provided           Web
# ...          ...                               ...           ...
# 125541       ...                  Consent provided           Web
# 125543       ...                  Consent provided           Web
# 125546       ...                  Consent provided           Web
# 125553       ...                  Consent provided           Web
# 125557       ...                  Consent provided           Web
# 125564       ...                  Consent provided           Web
# 125582       ...                  Consent provided           Web
# 125583       ...                  Consent provided           Web
# 125585       ...                  Consent provided           Web
# 125591       ...                  Consent provided           Web
# 125593       ...                  Consent provided           Web
# 125596       ...                  Consent provided           Web
# 125601       ...                  Consent provided           Web
# 125610       ...                  Consent provided           Web
# 125616       ...                  Consent provided           Web
# 125618       ...                  Consent provided           Web
# 125619       ...                  Consent provided           Web
# 125620       ...                  Consent provided           Web
# 125621       ...                  Consent provided           Web
# 125622       ...                  Consent provided           Web
# 125623       ...                  Consent provided           Web
# 125632       ...                  Consent provided           Web
# 125634       ...                  Consent provided           Web
# 125636       ...                  Consent provided           Web
# 125638       ...                  Consent provided           Web
# 125645       ...                  Consent provided           Web
# 125647       ...                  Consent provided           Web
# 125650       ...                  Consent provided           Web
# 125654       ...                  Consent provided           Web
# 125674       ...                  Consent provided           Web
#
#        Date sent to company     Company response to consumer Timely response?  \
# 12                3/23/2015      Closed with monetary relief              Yes
# 13                3/23/2015          Closed with explanation              Yes
# 19                3/24/2015  Closed with non-monetary relief              Yes
# 22                3/24/2015          Closed with explanation              Yes
# 25                3/24/2015          Closed with explanation              Yes
# 33                3/24/2015          Closed with explanation              Yes
# 43                3/24/2015  Closed with non-monetary relief              Yes
# 44                3/19/2015          Closed with explanation              Yes
# 46                3/19/2015          Closed with explanation              Yes
# 47                3/19/2015          Closed with explanation              Yes
# 48                3/19/2015          Closed with explanation              Yes
# 49                3/19/2015          Closed with explanation              Yes
# 50                3/19/2015          Closed with explanation              Yes
# 57                3/19/2015          Closed with explanation              Yes
# 58                3/24/2015  Closed with non-monetary relief              Yes
# 64                3/24/2015  Closed with non-monetary relief              Yes
# 69                3/19/2015          Closed with explanation              Yes
# 72                3/27/2015          Closed with explanation              Yes
# 81                 4/1/2015          Closed with explanation              Yes
# 87                3/19/2015          Closed with explanation              Yes
# 88                3/24/2015          Closed with explanation              Yes
# 101               3/27/2015          Closed with explanation              Yes
# 102               3/27/2015          Closed with explanation              Yes
# 104               3/19/2015      Closed with monetary relief              Yes
# 107               3/24/2015          Closed with explanation              Yes
# 121               3/19/2015          Closed with explanation              Yes
# 122               3/25/2015          Closed with explanation              Yes
# 127               3/19/2015          Closed with explanation              Yes
# 131                4/6/2015          Closed with explanation              Yes
# 139               3/19/2015          Closed with explanation              Yes
# ...                     ...                              ...              ...
# 125541            10/5/2016          Closed with explanation              Yes
# 125543           12/13/2016          Closed with explanation              Yes
# 125546           12/13/2016          Closed with explanation              Yes
# 125553            6/30/2015          Closed with explanation              Yes
# 125557           11/16/2016          Closed with explanation               No
# 125564           11/18/2016          Closed with explanation              Yes
# 125582           12/13/2016      Closed with monetary relief              Yes
# 125583            10/7/2016          Closed with explanation              Yes
# 125585           12/13/2016          Closed with explanation              Yes
# 125591           12/13/2016          Closed with explanation              Yes
# 125593           11/11/2016          Closed with explanation              Yes
# 125596            11/3/2016          Closed with explanation              Yes
# 125601            11/2/2016          Closed with explanation              Yes
# 125610           12/14/2016          Closed with explanation              Yes
# 125616           11/19/2016          Closed with explanation              Yes
# 125618            9/23/2016          Closed with explanation              Yes
# 125619           11/18/2016          Closed with explanation              Yes
# 125620           10/14/2016          Closed with explanation              Yes
# 125621            11/2/2016          Closed with explanation              Yes
# 125622            11/4/2016          Closed with explanation              Yes
# 125623           12/13/2016          Closed with explanation              Yes
# 125632           11/18/2016                           Closed              Yes
# 125634           10/26/2016          Closed with explanation              Yes
# 125636            11/5/2016          Closed with explanation              Yes
# 125638           11/18/2016                           Closed              Yes
# 125645           11/18/2016          Closed with explanation              Yes
# 125647            9/20/2016      Closed with monetary relief              Yes
# 125650           10/27/2016          Closed with explanation              Yes
# 125654           11/18/2016          Closed with explanation               No
# 125674           12/13/2016          Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID  Consumer Claim  Company Offer  \
# 12                    Yes      1296823       185482.51      159366.50
# 13                     No      1296831       101340.54      182761.24
# 19                     No      1297594       103381.81      186432.77
# 22                     No      1297626       219860.35      153908.22
# 25                     No      1297644       153377.06      169317.86
# 33                     No      1299207       105940.81      123409.96
# 43                     No      1297874       234463.04      133847.95
# 44                    Yes      1292137       177586.11       57294.34
# 46                     No      1290543        71574.50       24275.87
# 47                     No      1292139        61228.78       80961.10
# 48                     No      1290545       180004.43      214540.82
# 49                     No      1292065       136855.25       -7012.71
# 50                    Yes      1290564       110769.16       85293.98
# 57                    Yes      1290644       171647.18      167269.02
# 58                     No      1298042        91360.36      161713.50
# 64                    Yes      1298116       186816.79      228400.77
# 69                    Yes      1290765       174171.64       79753.02
# 72                     No      1304648       183467.48      130950.91
# 81                     No      1304057        94292.76      136124.02
# 87                     No      1290871       213279.65      157675.58
# 88                    Yes      1298322       109029.12       74100.13
# 101                   Yes      1304971       182034.47      114693.36
# 102                    No      1304692       150718.63      165691.38
# 104                    No      1291084       127616.28       66064.08
# 107                    No      1298656       150701.05      167926.46
# 121                   Yes      1291277       166114.09       81243.71
# 122                    No      1298770       198868.56      127222.11
# 127                    No      1292613       249757.98      136786.81
# 131                   Yes      1305325       169979.86       91967.15
# 139                   Yes      1292075       200977.97      208273.54
# ...                   ...          ...             ...            ...
# 125541                 No      2141468       121095.06        7620.71
# 125543                NaN      2247658       202258.79      123664.33
# 125546                NaN      2248476       141880.00      148011.31
# 125553                 No      1444123       152880.49      102193.95
# 125557                NaN      2209300       147430.37      114010.33
# 125564                 No      2180679       177723.48      216986.74
# 125582                NaN      2247493       114277.49      158659.18
# 125583                 No      2152061       129114.44       98844.55
# 125585                NaN      2244513        65426.99      140152.91
# 125591                Yes      2243820       169197.05       66552.62
# 125593                 No      2205208       237211.09       47003.87
# 125596                 No      2192518        97710.88       64392.79
# 125601                 No      2169166       140341.51      138125.27
# 125610                NaN      2248733       117591.02      103684.51
# 125616                Yes      2214614       142775.89      191873.76
# 125618                 No      2128559       182275.93       67170.52
# 125619                NaN      2214834       170016.45       65751.65
# 125620                 No      2153211        61244.98       99590.82
# 125621                 No      2186239       194123.95       63202.10
# 125622                 No      2191249       143222.59       16049.53
# 125623                NaN      2248373       161307.06      119452.98
# 125632                NaN      2215986       134966.28      163581.65
# 125634                 No      2177009        85949.83      165111.24
# 125636                 No      2197004       236151.02      119853.39
# 125638                NaN      2216156       126366.03       67134.38
# 125645                NaN      2215655       185077.71       92015.61
# 125647                 No      2122648       207892.82      180364.18
# 125650                 No      2182081       236687.68      221160.59
# 125654                NaN      2215900        74632.68       57102.99
# 125674                NaN      2247724       136798.52      114342.28
#
#         Amount Received
# 12            234193.94
# 13            122579.47
# 19            110905.24
# 22             99746.42
# 25             79792.59
# 33             89578.55
# 43            104833.17
# 44             89278.77
# 46             65055.48
# 47             22089.39
# 48             29346.45
# 49             70034.66
# 50            140950.99
# 57            115595.66
# 58             17758.65
# 64            134987.03
# 69            101711.41
# 72            141618.46
# 81            123227.27
# 87             79534.17
# 88             40478.75
# 101            67510.76
# 102           136517.37
# 104            77037.93
# 107            53600.10
# 121            26314.16
# 122           104428.20
# 127            71294.46
# 131            12702.47
# 139           140895.90
# ...                 ...
# 125541         -1882.12
# 125543         92247.20
# 125546        -15018.41
# 125553        173177.07
# 125557         47345.30
# 125564        125397.78
# 125582         85375.31
# 125583         56791.42
# 125585         99335.38
# 125591         85769.96
# 125593        190013.21
# 125596         74558.88
# 125601         83521.07
# 125610         43800.98
# 125616        101699.37
# 125618         92324.06
# 125619          1991.28
# 125620         99820.75
# 125621         47589.77
# 125622        112755.79
# 125623         56043.00
# 125632         59377.15
# 125634         84770.01
# 125636        123155.57
# 125638        133643.76
# 125645         69618.41
# 125647         35887.38
# 125650         64958.93
# 125654        182860.61
# 125674        106343.36
#
# [26811 rows x 21 columns]

# %%
# 7. Use boolean indexing by putting the mask inside df[] notation to filter out everything but mortgage.

df[~mask]
# Out:
#        Date received                  Product  \
# 0          3/24/2015              Credit card
# 1          3/23/2015          Debt collection
# 2          3/23/2015              Credit card
# 3          3/23/2015         Credit reporting
# 4          3/23/2015          Debt collection
# 5          3/23/2015             Student loan
# 6          3/23/2015          Debt collection
# 7          3/23/2015         Credit reporting
# 8          3/23/2015              Credit card
# 9          3/23/2015          Debt collection
# 10         3/23/2015             Student loan
# 11         3/23/2015          Debt collection
# 14         3/23/2015          Debt collection
# 15         3/23/2015              Credit card
# 16         3/23/2015              Credit card
# 17         3/24/2015              Credit card
# 18         3/24/2015          Debt collection
# 20         3/24/2015              Payday loan
# 21         3/24/2015          Debt collection
# 23         3/24/2015  Bank account or service
# 24         3/24/2015          Debt collection
# 26         3/24/2015         Credit reporting
# 27         3/24/2015          Debt collection
# 28         3/24/2015  Bank account or service
# 29         3/24/2015          Debt collection
# 30         3/24/2015              Credit card
# 31         3/24/2015         Credit reporting
# 32         3/24/2015          Debt collection
# 34         3/24/2015          Debt collection
# 35         3/24/2015          Debt collection
# ...              ...                      ...
# 125646    12/13/2016          Debt collection
# 125648    12/13/2016              Credit card
# 125649    11/16/2016         Credit reporting
# 125651     9/29/2016            Consumer Loan
# 125652    10/18/2016  Bank account or service
# 125653    12/12/2016          Debt collection
# 125655     12/2/2016          Debt collection
# 125656     11/4/2016             Student loan
# 125657    11/18/2016          Debt collection
# 125658    12/12/2016              Credit card
# 125659     11/9/2016          Debt collection
# 125660    12/13/2016  Bank account or service
# 125661     10/4/2016          Debt collection
# 125662    12/13/2016              Credit card
# 125663     11/6/2016             Student loan
# 125664    11/12/2016         Credit reporting
# 125665    11/10/2016         Credit reporting
# 125666    12/14/2016              Credit card
# 125667    12/13/2016  Bank account or service
# 125668     11/3/2016         Credit reporting
# 125669    11/19/2016          Debt collection
# 125670    11/18/2016          Debt collection
# 125671    11/16/2016          Debt collection
# 125672    11/19/2016         Credit reporting
# 125673     9/27/2016  Bank account or service
# 125675    10/21/2016            Consumer Loan
# 125676    11/18/2016             Student loan
# 125677     11/4/2016  Bank account or service
# 125678     11/4/2016  Bank account or service
# 125679     11/9/2016         Credit reporting
#
#                                   Sub-product  \
# 0                                         NaN
# 1       Other (i.e. phone, health club, etc.)
# 2                                         NaN
# 3                                         NaN
# 4                                 Payday loan
# 5                    Non-federal student loan
# 6                                     Medical
# 7                                         NaN
# 8                                         NaN
# 9       Other (i.e. phone, health club, etc.)
# 10                   Non-federal student loan
# 11                                   Mortgage
# 14                              I do not know
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18      Other (i.e. phone, health club, etc.)
# 20                                Payday loan
# 21                                Credit card
# 23                           Checking account
# 24                                Credit card
# 26                                        NaN
# 27                              I do not know
# 28                           Checking account
# 29                                       Auto
# 30                                        NaN
# 31                                        NaN
# 32                                    Medical
# 34      Other (i.e. phone, health club, etc.)
# 35                              I do not know
# ...                                       ...
# 125646  Other (i.e. phone, health club, etc.)
# 125648                                    NaN
# 125649                                    NaN
# 125651                       Installment loan
# 125652                       Checking account
# 125653                                Medical
# 125655  Other (i.e. phone, health club, etc.)
# 125656               Non-federal student loan
# 125657                                Medical
# 125658                                    NaN
# 125659  Other (i.e. phone, health club, etc.)
# 125660                       Checking account
# 125661                                Medical
# 125662                                    NaN
# 125663         Federal student loan servicing
# 125664                                    NaN
# 125665                                    NaN
# 125666                                    NaN
# 125667                       Checking account
# 125668                                    NaN
# 125669                            Credit card
# 125670                          I do not know
# 125671                          I do not know
# 125672                                    NaN
# 125673                       Checking account
# 125675                          Vehicle lease
# 125676               Non-federal student loan
# 125677             Other bank product/service
# 125678                       Checking account
# 125679                                    NaN
#
#                                            Issue  \
# 0                                          Other
# 1            Improper contact or sharing of info
# 2                                        Rewards
# 3         Incorrect information on credit report
# 4            Improper contact or sharing of info
# 5             Dealing with my lender or servicer
# 6          Cont'd attempts collect debt not owed
# 7         Incorrect information on credit report
# 8                                          Other
# 9          Cont'd attempts collect debt not owed
# 10                           Can't repay my loan
# 11                         Communication tactics
# 14               Disclosure verification of debt
# 15                                      Late fee
# 16                              Billing disputes
# 17                 Credit line increase/decrease
# 18            False statements or representation
# 20            Can't stop charges to bank account
# 21         Cont'd attempts collect debt not owed
# 23                     Using a debit or ATM card
# 24                         Communication tactics
# 26        Incorrect information on credit report
# 27               Disclosure verification of debt
# 28       Account opening, closing, or management
# 29            False statements or representation
# 30         Identity theft / Fraud / Embezzlement
# 31      Credit reporting company's investigation
# 32         Cont'd attempts collect debt not owed
# 34            False statements or representation
# 35                         Communication tactics
# ...                                          ...
# 125646           Disclosure verification of debt
# 125648                          Billing disputes
# 125649  Credit reporting company's investigation
# 125651       Problems when you are unable to pay
# 125652     Problems caused by my funds being low
# 125653     Cont'd attempts collect debt not owed
# 125655     Cont'd attempts collect debt not owed
# 125656        Dealing with my lender or servicer
# 125657           Disclosure verification of debt
# 125658     Identity theft / Fraud / Embezzlement
# 125659     Cont'd attempts collect debt not owed
# 125660   Account opening, closing, or management
# 125661           Disclosure verification of debt
# 125662                                   Rewards
# 125663        Dealing with my lender or servicer
# 125664    Incorrect information on credit report
# 125665    Incorrect information on credit report
# 125666                                     Other
# 125667   Account opening, closing, or management
# 125668    Incorrect information on credit report
# 125669           Disclosure verification of debt
# 125670     Cont'd attempts collect debt not owed
# 125671       Improper contact or sharing of info
# 125672    Incorrect information on credit report
# 125673                 Using a debit or ATM card
# 125675                Managing the loan or lease
# 125676                       Can't repay my loan
# 125677   Account opening, closing, or management
# 125678                  Deposits and withdrawals
# 125679  Credit reporting company's investigation
#
#                                        Sub-issue  \
# 0                                            NaN
# 1              Contacted me after I asked not to
# 2                                            NaN
# 3                        Information is not mine
# 4          Talked to a third party about my debt
# 5          Having problems with customer service
# 6                                  Debt was paid
# 7                        Information is not mine
# 8                                            NaN
# 9              Debt resulted from identity theft
# 10            Can't decrease my monthly payments
# 11               Threatened to take legal action
# 14          Not given enough info to verify debt
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18             Attempted to collect wrong amount
# 20            Can't stop charges to bank account
# 21             Debt was discharged in bankruptcy
# 23                                           NaN
# 24                    Frequent or repeated calls
# 26                                Account status
# 27        Not disclosed as an attempt to collect
# 28                                           NaN
# 29             Attempted to collect wrong amount
# 30                                           NaN
# 31      No notice of investigation status/result
# 32                              Debt is not mine
# 34             Attempted to collect wrong amount
# 35                    Frequent or repeated calls
# ...                                          ...
# 125646      Not given enough info to verify debt
# 125648                                       NaN
# 125649         Problem with statement of dispute
# 125651                                       NaN
# 125652                                       NaN
# 125653                          Debt is not mine
# 125655                             Debt was paid
# 125656          Keep getting calls about my loan
# 125657      Right to dispute notice not received
# 125658                                       NaN
# 125659                          Debt is not mine
# 125660                                       NaN
# 125661      Not given enough info to verify debt
# 125662                                       NaN
# 125663    Received bad information about my loan
# 125664                            Account status
# 125665                      Personal information
# 125666                                       NaN
# 125667                                       NaN
# 125668                   Information is not mine
# 125669      Not given enough info to verify debt
# 125670                          Debt is not mine
# 125671     Talked to a third party about my debt
# 125672                   Information is not mine
# 125673                                       NaN
# 125675                                       NaN
# 125676        Can't get flexible payment options
# 125677                                       NaN
# 125678                                       NaN
# 125679            Inadequate help over the phone
#
#                              Consumer complaint narrative  \
# 0       Received Capital One charge card offer XXXX. A...
# 1       I do n't know how they got my cell number. I t...
# 2       I 'm a longtime member of Charter One Bank/RBS...
# 3       After looking at my credit report, I saw a col...
# 4       I received a call from a XXXX XXXX from XXXX @...
# 5       Was not contacted 4 years later about some pri...
# 6       Collection Consultants is reporting a collecti...
# 7       I had my purse stolen in 2007. They never foun...
# 8       I attempted to apply for a Discover Card Onlin...
# 9       Continued attempts by XXXX XXXX XXXX to collec...
# 10      This is a continuation of a previous issue wit...
# 11      Going through a divorce, my ex and I were unab...
# 14      I recieved a notice from Midland Credit Manage...
# 15      XXXX Card services was bought out by Capital O...
# 16      I was reported late by Discover Card to the re...
# 17      XXXX i receive an email from citibank regardin...
# 18      I agreed to a settlement arrangement on a acco...
# 20      I took out a Loan from Cash Central XXXX, Al f...
# 21      I filed ChapterXXXX bankruptcy on my accounts ...
# 23      I 'm no longer an account holder of SunTrust. ...
# 24      I 've been receiving numerous robocalls, hang-...
# 26      Please investigate the practices of Experian. ...
# 27      Portfolio Recovery does not disclose who is ca...
# 28      After banking with Citibank for over 3 years, ...
# 29      I am a victim of a parked debt bought by a deb...
# 30      I have been a XXXX XXXX XXXX for 4.5 years and...
# 31      I noticed an incorrect item when I received fr...
# 32      I find this medical debt reported on my credit...
# 34      I received a letter from Penn Credit Collectio...
# 35      This gentleman called me and asked for persona...
# ...                                                   ...
# 125646  I am wanting to make sure that this debt is be...
# 125648  We made a furniture purchase in the amount of ...
# 125649  The investigation told me about debt collector...
# 125651                             Excessive daily calls.
# 125652  My checking account was set up to decline any ...
# 125653  I recently reviewed my credit reports and I ha...
# 125655  This Collection Agency keeps sending me and my...
# 125656  This is the third time I am writing you about ...
# 125657  I receive a call Capio Partners being disrespe...
# 125658  SYNCB/GAP ACCOUNT NUMBERs : XXXX XX/XX/XXXX XX...
# 125659  XXXX agent miss represent there service and pa...
# 125660  I applied for a joint checking account with my...
# 125661  I contacted this creditor on their secure logi...
# 125662  I signed up a new Citi XXXX XXXX credit card o...
# 125663  I have a unsubsidized Stafford loan from colle...
# 125664  This company XXXX just bought my loan in the p...
# 125665  I have incorrect info on my credit report with...
# 125666  Since the last few months I 've been unable to...
# 125667  I applied to join XXXX XXXX XXXX for a home lo...
# 125668  There was fraud on my account and does not bel...
# 125669  I have disputed this Capital One Credit card c...
# 125670  I received an alert from credit monitoring ser...
# 125671  First Source Adv. is contacting family members...
# 125672  This is a complaint against the Bureau of Equi...
# 125673  I do n't believe I had this account with bank ...
# 125675  I leased a vehicle from ALLY, paying all payme...
# 125676  Today my lender increased my private student l...
# 125677  In XXXX 2016, my computer crashed and deleted ...
# 125678  I opened a checking account with Simple Bank (...
# 125679  I have been contacting Transunion for over 2 m...
#
#                                   Company public response  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3        Company chooses not to provide a public response
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7        Company chooses not to provide a public response
# 8                                                     NaN
# 9                                                     NaN
# 10       Company chooses not to provide a public response
# 11                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17       Company chooses not to provide a public response
# 18                                                    NaN
# 20       Company chooses not to provide a public response
# 21                                                    NaN
# 23       Company chooses not to provide a public response
# 24                                                    NaN
# 26       Company chooses not to provide a public response
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# 30       Company chooses not to provide a public response
# 31                                                    NaN
# 32       Company chooses not to provide a public response
# 34      Company believes it acted appropriately as aut...
# 35      Company believes it acted appropriately as aut...
# ...                                                   ...
# 125646  Company believes it acted appropriately as aut...
# 125648  Company has responded to the consumer and the ...
# 125649                                                NaN
# 125651                                                NaN
# 125652                                                NaN
# 125653  Company believes it acted appropriately as aut...
# 125655  Company believes it acted appropriately as aut...
# 125656  Company believes it acted appropriately as aut...
# 125657                                                NaN
# 125658  Company has responded to the consumer and the ...
# 125659                                                NaN
# 125660  Company believes it acted appropriately as aut...
# 125661                                                NaN
# 125662  Company has responded to the consumer and the ...
# 125663                                                NaN
# 125664  Company has responded to the consumer and the ...
# 125665  Company has responded to the consumer and the ...
# 125666  Company has responded to the consumer and the ...
# 125667  Company has responded to the consumer and the ...
# 125668                                                NaN
# 125669                                                NaN
# 125670                                                NaN
# 125671  Company believes it acted appropriately as aut...
# 125672                                                NaN
# 125673  Company has responded to the consumer and the ...
# 125675  Company has responded to the consumer and the ...
# 125676                                                NaN
# 125677  Company has responded to the consumer and the ...
# 125678                                                NaN
# 125679  Company has responded to the consumer and the ...
#
#                                                   Company State ZIP code  \
# 0                                             Capital One    OH    440XX
# 1                            CCS Financial Services, Inc.    AR    727XX
# 2                          Citizens Financial Group, Inc.    MI    482XX
# 3                                                Experian    FL    331XX
# 4                                  Big Picture Loans, LLC    SC    291XX
# 5                          Oliphant Financial Corporation    IL    605XX
# 6                    Collection Consultants of California    CA    923XX
# 7                                                Experian    ME    044XX
# 8                                                Discover    MD    217XX
# 9                                   Stellar Recovery Inc.    CT    060XX
# 10                                               Citibank    SC    296XX
# 11                                               Citibank    FL    330XX
# 14                                   Encore Capital Group    TX    787XX
# 15                                            Capital One    MI    488XX
# 16                                               Discover    OK    741XX
# 17                                               Citibank    NV    891XX
# 18                                        MS Services LLC    TN    381XX
# 20                       Community Choice Financial, Inc.    AL    351XX
# 21                                   JPMorgan Chase & Co.    NE    681XX
# 23                                   SunTrust Banks, Inc.    FL    334XX
# 24                                                   Amex    CT    064XX
# 26                                               Experian    CA    900XX
# 27                    Portfolio Recovery Associates, Inc.    WA    980XX
# 28                                               Citibank    TX    797XX
# 29                   Accelerated Financial Solutions, LLC    NV    891XX
# 30                                           Barclays PLC    CA    940XX
# 31                 TransUnion Intermediate Holdings, Inc.    HI    968XX
# 32                          Healthcare Collections-I, LLC    AZ    860XX
# 34                                Penn Credit Corporation    FL    330XX
# 35                                  Client Services, Inc.    NC    274XX
# ...                                                   ...   ...      ...
# 125646                                                ERC    TX    785XX
# 125648                                Synchrony Financial    SC    294XX
# 125649                                            Equifax    IL    600XX
# 125651                                           RFNA, LP    GA    301XX
# 125652                                      Commerce Bank    MO    630XX
# 125653                                    ATG Credit, LLC    IL    605XX
# 125655                             Duncan Solutions, lnc.    CA    941XX
# 125656                    Capital Management Services, LP    GA    302XX
# 125657                                Capio Partners, LLC    FL    327XX
# 125658                                Synchrony Financial    FL    329XX
# 125659                                         Afni, Inc.    CA    945XX
# 125660                                       USAA Savings    IL    606XX
# 125661  The Law Offices of Mitchell D. Bluhm & Associates    FL    327XX
# 125662                                           Citibank    NY    115XX
# 125663                                             Nelnet    GA    306XX
# 125664                                           Experian    GA    300XX
# 125665             TransUnion Intermediate Holdings, Inc.    OK    730XX
# 125666                                    Bank of America    CA    941XX
# 125667  Fidelity National Information Services, Inc. (...    GA    301XX
# 125668                                       Factual Data    KY    405XX
# 125669                                        Capital One    IL    604XX
# 125670                           Midwest Recovery Systems    SC    291XX
# 125671                         FirstSource Advantage, LLC    PA    164XX
# 125672                                            Equifax    FL    331XX
# 125673                                    Bank of America    CA    900XX
# 125675                                Ally Financial Inc.    VA    201XX
# 125676                                          AES/PHEAA    NY    130XX
# 125677                                     BB&T Financial    PA    191XX
# 125678                                       BBVA Compass    VA    223XX
# 125679             TransUnion Intermediate Holdings, Inc.    IL    600XX
#
#              ...        Consumer consent provided? Submitted via  \
# 0            ...                  Consent provided           Web
# 1            ...                  Consent provided           Web
# 2            ...                  Consent provided           Web
# 3            ...                  Consent provided           Web
# 4            ...                  Consent provided           Web
# 5            ...                  Consent provided           Web
# 6            ...                  Consent provided           Web
# 7            ...                  Consent provided           Web
# 8            ...                  Consent provided           Web
# 9            ...                  Consent provided           Web
# 10           ...                  Consent provided           Web
# 11           ...                  Consent provided           Web
# 14           ...                  Consent provided           Web
# 15           ...                  Consent provided           Web
# 16           ...                  Consent provided           Web
# 17           ...                  Consent provided           Web
# 18           ...                  Consent provided           Web
# 20           ...                  Consent provided           Web
# 21           ...                  Consent provided           Web
# 23           ...                  Consent provided           Web
# 24           ...                  Consent provided           Web
# 26           ...                  Consent provided           Web
# 27           ...                  Consent provided           Web
# 28           ...                  Consent provided           Web
# 29           ...                  Consent provided           Web
# 30           ...                  Consent provided           Web
# 31           ...                  Consent provided           Web
# 32           ...                  Consent provided           Web
# 34           ...                  Consent provided           Web
# 35           ...                  Consent provided           Web
# ...          ...                               ...           ...
# 125646       ...                  Consent provided           Web
# 125648       ...                  Consent provided           Web
# 125649       ...                  Consent provided           Web
# 125651       ...                  Consent provided           Web
# 125652       ...                  Consent provided           Web
# 125653       ...                  Consent provided           Web
# 125655       ...                  Consent provided           Web
# 125656       ...                  Consent provided           Web
# 125657       ...                  Consent provided           Web
# 125658       ...                  Consent provided           Web
# 125659       ...                  Consent provided           Web
# 125660       ...                  Consent provided           Web
# 125661       ...                  Consent provided           Web
# 125662       ...                  Consent provided           Web
# 125663       ...                  Consent provided           Web
# 125664       ...                  Consent provided           Web
# 125665       ...                  Consent provided           Web
# 125666       ...                  Consent provided           Web
# 125667       ...                  Consent provided           Web
# 125668       ...                  Consent provided           Web
# 125669       ...                  Consent provided           Web
# 125670       ...                  Consent provided           Web
# 125671       ...                  Consent provided           Web
# 125672       ...                  Consent provided           Web
# 125673       ...                  Consent provided           Web
# 125675       ...                  Consent provided           Web
# 125676       ...                  Consent provided           Web
# 125677       ...                  Consent provided           Web
# 125678       ...                  Consent provided           Web
# 125679       ...                  Consent provided           Web
#
#        Date sent to company     Company response to consumer Timely response?  \
# 0                 3/30/2015          Closed with explanation              Yes
# 1                 3/23/2015          Closed with explanation              Yes
# 2                 3/23/2015          Closed with explanation              Yes
# 3                 3/27/2015  Closed with non-monetary relief              Yes
# 4                 3/23/2015          Closed with explanation              Yes
# 5                 3/25/2015          Closed with explanation              Yes
# 6                 4/30/2015          Closed with explanation              Yes
# 7                 3/23/2015          Closed with explanation              Yes
# 8                 3/23/2015  Closed with non-monetary relief              Yes
# 9                 3/25/2015          Closed with explanation              Yes
# 10                3/25/2015          Closed with explanation              Yes
# 11                3/23/2015          Closed with explanation              Yes
# 14                3/23/2015  Closed with non-monetary relief              Yes
# 15                3/23/2015      Closed with monetary relief              Yes
# 16                3/23/2015          Closed with explanation              Yes
# 17                3/24/2015          Closed with explanation              Yes
# 18                3/24/2015          Closed with explanation              Yes
# 20                3/24/2015          Closed with explanation              Yes
# 21                3/24/2015          Closed with explanation              Yes
# 23                3/24/2015          Closed with explanation              Yes
# 24                3/24/2015          Closed with explanation              Yes
# 26                3/24/2015          Closed with explanation              Yes
# 27                3/25/2015  Closed with non-monetary relief              Yes
# 28                3/24/2015          Closed with explanation              Yes
# 29                3/24/2015          Closed with explanation              Yes
# 30                3/24/2015          Closed with explanation              Yes
# 31                3/24/2015          Closed with explanation              Yes
# 32                3/24/2015          Closed with explanation              Yes
# 34                3/24/2015          Closed with explanation              Yes
# 35                3/24/2015  Closed with non-monetary relief              Yes
# ...                     ...                              ...              ...
# 125646           12/13/2016                           Closed              Yes
# 125648           12/13/2016          Closed with explanation              Yes
# 125649           11/16/2016          Closed with explanation              Yes
# 125651            11/4/2016          Closed with explanation              Yes
# 125652           10/18/2016          Closed with explanation              Yes
# 125653           12/12/2016          Closed with explanation              Yes
# 125655           12/13/2016          Closed with explanation              Yes
# 125656            11/7/2016          Closed with explanation              Yes
# 125657           11/18/2016  Closed with non-monetary relief              Yes
# 125658           12/12/2016          Closed with explanation              Yes
# 125659            11/9/2016          Closed with explanation              Yes
# 125660           12/13/2016  Closed with non-monetary relief              Yes
# 125661           11/14/2016  Closed with non-monetary relief              Yes
# 125662           12/13/2016          Closed with explanation              Yes
# 125663            11/6/2016          Closed with explanation              Yes
# 125664           11/12/2016          Closed with explanation              Yes
# 125665           11/10/2016          Closed with explanation              Yes
# 125666           12/14/2016          Closed with explanation              Yes
# 125667           12/13/2016          Closed with explanation              Yes
# 125668            11/3/2016          Closed with explanation              Yes
# 125669           11/19/2016          Closed with explanation              Yes
# 125670           11/18/2016                Untimely response               No
# 125671           11/16/2016          Closed with explanation              Yes
# 125672           11/19/2016          Closed with explanation              Yes
# 125673            9/30/2016          Closed with explanation              Yes
# 125675           10/21/2016          Closed with explanation              Yes
# 125676           11/18/2016          Closed with explanation              Yes
# 125677            11/4/2016          Closed with explanation              Yes
# 125678            11/4/2016          Closed with explanation              Yes
# 125679            11/9/2016          Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID  Consumer Claim  Company Offer  \
# 0                      No      1297939          332.63         217.18
# 1                      No      1296593           54.79          41.48
# 2                     Yes      1296693          215.04         231.67
# 3                      No      1296955            3.31           6.30
# 4                      No      1296727           73.99          76.75
# 5                      No      1296773        15869.20       14414.94
# 6                      No      1296774           47.43          55.38
# 7                      No      1296785            5.47           4.06
# 8                      No      1295056          262.58         220.21
# 9                      No      1296777           84.60          81.44
# 10                     No      1295228        17690.44       25099.77
# 11                     No      1295146           78.73          59.09
# 14                     No      1295409           81.47          45.18
# 15                     No      1296880          240.76         162.92
# 16                     No      1296890          258.53         232.54
# 17                    Yes      1299216          186.52         278.21
# 18                     No      1297589           56.39          62.17
# 20                     No      1299258            6.02          25.44
# 21                    Yes      1297609           72.04          64.01
# 23                     No      1297629           88.66          70.81
# 24                     No      1297377           74.58          63.52
# 26                     No      1297500            3.31           1.29
# 27                     No      1297662           70.24          68.01
# 28                     No      1297676           86.24          62.34
# 29                    Yes      1297316           60.50          67.60
# 30                    Yes      1297327          312.17         213.44
# 31                    Yes      1297382            5.90           1.64
# 32                     No      1297685           78.64          65.67
# 34                     No      1297371           77.42          56.55
# 35                     No      1297758           49.66          74.74
# ...                   ...          ...             ...            ...
# 125646                NaN      2246957           73.73          57.40
# 125648                NaN      2247898          245.66         160.68
# 125649                 No      2209167            5.39           4.21
# 125651                 No      2139621         5753.08        3347.99
# 125652                 No      2165678           73.34          59.51
# 125653                NaN      2245422           83.07          76.03
# 125655                NaN      2233235           61.07          55.34
# 125656                 No      2197243        20249.89        9145.76
# 125657                NaN      2215200           82.64          57.09
# 125658                Yes      2244918          220.97         276.09
# 125659                 No      2201273           59.04          60.44
# 125660                NaN      2247284           78.73          68.11
# 125661                 No      2145608           83.07          69.67
# 125662                Yes      2248594          258.87         189.00
# 125663                 No      2198041        16803.25       24457.31
# 125664                 No      2205209            3.41           4.04
# 125665                 No      2203177            7.37           5.44
# 125666                NaN      2247267          214.31         205.83
# 125667                NaN      2248753           73.33          70.85
# 125668                 No      2193913            2.40           2.11
# 125669                NaN      2216039           87.67          54.43
# 125670                NaN      2213687           79.67          56.16
# 125671                 No      2210820           85.51          73.63
# 125672                NaN      2215661            7.25           2.12
# 125673                 No      2133648           69.74          67.79
# 125675                 No      2170435         4126.85        4797.82
# 125676                NaN      2215331        24212.35       24333.23
# 125677                 No      2194728           75.45          69.03
# 125678                 No      2196938           70.11          63.83
# 125679                 No      2202865            4.17           4.67
#
#         Amount Received
# 0                130.22
# 1                 49.14
# 2                155.28
# 3                  4.59
# 4                 46.02
# 5              12964.40
# 6                 31.79
# 7                  6.69
# 8                 96.66
# 9                 65.64
# 10             12962.02
# 11                58.94
# 14                45.77
# 15               174.56
# 16               194.73
# 17               288.13
# 18                37.96
# 20                19.35
# 21                42.37
# 23                53.64
# 24                34.51
# 26                 0.34
# 27                45.16
# 28                44.37
# 29                45.81
# 30               174.58
# 31                 2.91
# 32                51.62
# 34                35.24
# 35                53.90
# ...                 ...
# 125646            56.63
# 125648           184.44
# 125649             5.39
# 125651          4810.15
# 125652            49.38
# 125653            47.62
# 125655            34.73
# 125656          6248.93
# 125657            57.02
# 125658            91.89
# 125659            33.40
# 125660            46.51
# 125661            51.44
# 125662           129.45
# 125663         20028.10
# 125664             0.90
# 125665             2.49
# 125666           225.27
# 125667            44.17
# 125668             5.82
# 125669            65.87
# 125670            39.76
# 125671            27.10
# 125672             0.92
# 125673            41.98
# 125675          1931.60
# 125676          5957.27
# 125677            44.28
# 125678            35.03
# 125679            -0.18
#
# [98869 rows x 21 columns]

# %%
# 8. Do the mask operation in steps 6 and 7 in a single line.

df = df[df['Product'] == 'Mortgage']
df
# Out:
#        Date received   Product                             Sub-product  \
# 12         3/23/2015  Mortgage                            FHA mortgage
# 13         3/23/2015  Mortgage                          Other mortgage
# 19         3/24/2015  Mortgage                          Other mortgage
# 22         3/24/2015  Mortgage             Conventional fixed mortgage
# 25         3/24/2015  Mortgage                             VA mortgage
# 33         3/24/2015  Mortgage             Conventional fixed mortgage
# 43         3/24/2015  Mortgage             Conventional fixed mortgage
# 44         3/19/2015  Mortgage             Conventional fixed mortgage
# 46         3/19/2015  Mortgage                        Reverse mortgage
# 47         3/19/2015  Mortgage             Conventional fixed mortgage
# 48         3/19/2015  Mortgage             Conventional fixed mortgage
# 49         3/19/2015  Mortgage             Conventional fixed mortgage
# 50         3/19/2015  Mortgage                            FHA mortgage
# 57         3/19/2015  Mortgage      Home equity loan or line of credit
# 58         3/24/2015  Mortgage                          Other mortgage
# 64         3/24/2015  Mortgage             Conventional fixed mortgage
# 69         3/19/2015  Mortgage             Conventional fixed mortgage
# 72         3/27/2015  Mortgage      Home equity loan or line of credit
# 81         3/27/2015  Mortgage                          Other mortgage
# 87         3/19/2015  Mortgage             Conventional fixed mortgage
# 88         3/24/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 101        3/27/2015  Mortgage             Conventional fixed mortgage
# 102        3/27/2015  Mortgage             Conventional fixed mortgage
# 104        3/19/2015  Mortgage             Conventional fixed mortgage
# 107        3/24/2015  Mortgage                            FHA mortgage
# 121        3/19/2015  Mortgage                            FHA mortgage
# 122        3/24/2015  Mortgage             Conventional fixed mortgage
# 127        3/19/2015  Mortgage                            FHA mortgage
# 131        3/27/2015  Mortgage                            FHA mortgage
# 139        3/19/2015  Mortgage             Conventional fixed mortgage
# ...              ...       ...                                     ...
# 125541     10/2/2016  Mortgage             Conventional fixed mortgage
# 125543    12/13/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125546    12/13/2016  Mortgage                             VA mortgage
# 125553     6/30/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 125557    11/16/2016  Mortgage             Conventional fixed mortgage
# 125564    10/26/2016  Mortgage             Conventional fixed mortgage
# 125582    12/13/2016  Mortgage                             VA mortgage
# 125583     10/7/2016  Mortgage             Conventional fixed mortgage
# 125585    12/10/2016  Mortgage      Home equity loan or line of credit
# 125591     12/9/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125593    11/11/2016  Mortgage                            FHA mortgage
# 125596     11/3/2016  Mortgage                             VA mortgage
# 125601    10/19/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125610    12/13/2016  Mortgage                            FHA mortgage
# 125616    11/19/2016  Mortgage      Home equity loan or line of credit
# 125618     9/23/2016  Mortgage                            FHA mortgage
# 125619    11/18/2016  Mortgage             Conventional fixed mortgage
# 125620    10/10/2016  Mortgage                             VA mortgage
# 125621    10/31/2016  Mortgage             Conventional fixed mortgage
# 125622     11/2/2016  Mortgage                            FHA mortgage
# 125623    12/13/2016  Mortgage             Conventional fixed mortgage
# 125632    11/18/2016  Mortgage             Conventional fixed mortgage
# 125634    10/26/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125636     11/5/2016  Mortgage             Conventional fixed mortgage
# 125638    11/18/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125645    11/18/2016  Mortgage                            FHA mortgage
# 125647     9/20/2016  Mortgage             Conventional fixed mortgage
# 125650    10/27/2016  Mortgage             Conventional fixed mortgage
# 125654    11/18/2016  Mortgage                          Other mortgage
# 125674    12/13/2016  Mortgage             Conventional fixed mortgage
#
#                                            Issue Sub-issue  \
# 12      Loan servicing, payments, escrow account       NaN
# 13      Loan servicing, payments, escrow account       NaN
# 19      Loan servicing, payments, escrow account       NaN
# 22                Credit decision / Underwriting       NaN
# 25      Loan servicing, payments, escrow account       NaN
# 33      Loan servicing, payments, escrow account       NaN
# 43      Loan servicing, payments, escrow account       NaN
# 44                Credit decision / Underwriting       NaN
# 46      Application, originator, mortgage broker       NaN
# 47      Loan servicing, payments, escrow account       NaN
# 48      Loan servicing, payments, escrow account       NaN
# 49      Loan servicing, payments, escrow account       NaN
# 50      Application, originator, mortgage broker       NaN
# 57      Loan servicing, payments, escrow account       NaN
# 58                  Settlement process and costs       NaN
# 64      Loan servicing, payments, escrow account       NaN
# 69      Loan modification,collection,foreclosure       NaN
# 72      Loan modification,collection,foreclosure       NaN
# 81      Loan servicing, payments, escrow account       NaN
# 87      Loan servicing, payments, escrow account       NaN
# 88      Loan servicing, payments, escrow account       NaN
# 101     Loan modification,collection,foreclosure       NaN
# 102     Loan modification,collection,foreclosure       NaN
# 104                 Settlement process and costs       NaN
# 107     Loan servicing, payments, escrow account       NaN
# 121     Loan servicing, payments, escrow account       NaN
# 122     Loan servicing, payments, escrow account       NaN
# 127     Loan servicing, payments, escrow account       NaN
# 131     Loan modification,collection,foreclosure       NaN
# 139     Loan modification,collection,foreclosure       NaN
# ...                                          ...       ...
# 125541  Loan modification,collection,foreclosure       NaN
# 125543  Loan modification,collection,foreclosure       NaN
# 125546  Application, originator, mortgage broker       NaN
# 125553  Loan modification,collection,foreclosure       NaN
# 125557  Application, originator, mortgage broker       NaN
# 125564  Loan modification,collection,foreclosure       NaN
# 125582              Settlement process and costs       NaN
# 125583  Loan servicing, payments, escrow account       NaN
# 125585  Application, originator, mortgage broker       NaN
# 125591              Settlement process and costs       NaN
# 125593  Loan modification,collection,foreclosure       NaN
# 125596  Loan servicing, payments, escrow account       NaN
# 125601              Settlement process and costs       NaN
# 125610            Credit decision / Underwriting       NaN
# 125616  Loan servicing, payments, escrow account       NaN
# 125618  Loan servicing, payments, escrow account       NaN
# 125619  Loan servicing, payments, escrow account       NaN
# 125620  Loan servicing, payments, escrow account       NaN
# 125621  Loan servicing, payments, escrow account       NaN
# 125622  Loan servicing, payments, escrow account       NaN
# 125623  Loan servicing, payments, escrow account       NaN
# 125632  Loan modification,collection,foreclosure       NaN
# 125634  Loan modification,collection,foreclosure       NaN
# 125636            Credit decision / Underwriting       NaN
# 125638  Loan modification,collection,foreclosure       NaN
# 125645  Loan servicing, payments, escrow account       NaN
# 125647  Loan servicing, payments, escrow account       NaN
# 125650  Loan servicing, payments, escrow account       NaN
# 125654  Application, originator, mortgage broker       NaN
# 125674  Loan servicing, payments, escrow account       NaN
#
#                              Consumer complaint narrative  \
# 12      I am assisted with my mortgage through an agen...
# 13      i submitted a payment on XXXX XXXX 2015 for my...
# 19      Green Tree Financial somehow got XXXX Loan AFT...
# 22      To whom it may concern, To those that follow t...
# 25      My mortgage servicer, Wells Fargo, did not giv...
# 33      I paid off my mortgage with XXXX Mortgage Serv...
# 43      I was emailed that my online account had been ...
# 44      XXXX was submitted XX/XX/XXXX. At the time I s...
# 46      I am very disappointed that the CFPB did not h...
# 47      We fell behind in our payments back in 2014 fo...
# 48      I am a Successor - in -interest to a property ...
# 49      I am writing this letter because my mortgage a...
# 50      I had a mortgage with from XXXX of XXXX to XXX...
# 57      I made a payment on a {$69000.00} loan of $ XX...
# 58      I applied for a loan modification with Suntrus...
# 64      I was {$48.00} behind on our mortgage because ...
# 69      I have been trying to get an audit of my accou...
# 72      We had a Line of Credit with US Bank that was ...
# 81      Ocwen financial services claims simultaneously...
# 87      I had a mortgage with XXXX XXXX XXXX from XXXX...
# 88      I schedule my mortgage payment, using the mort...
# 101     My wife and I just went through 7 months of ap...
# 102     We have been working or a Short Sale for Selec...
# 104     I got behind in payments and worked with B of ...
# 107     Yesterday, I called my mortgage company, Ocwen...
# 121     Wells Fargo Mortgage began foreclosure action ...
# 122     Caliber Home loans has claimed to have made pa...
# 127     Our Mortgage was sold to Carrington Mortgage S...
# 131     I was part of the XXXX and received payment la...
# 139     We are a victim of Ocwen mortgage and their fr...
# ...                                                   ...
# 125541  I am trying to get approved for a loan modific...
# 125543  I have asked Nationstar for assistance for a f...
# 125546  In XX/XX/2016, I received a solicitation from ...
# 125553  XX/XX/XXXX  Immediate concern: Stop  the forec...
# 125557  I was advised by XXXX XXXX at omni mortgage th...
# 125564  I am so devastated and so very disappointed wi...
# 125582  I contracted with USAA Federal Savings Bank to...
# 125583  Since the purchase of my house throughout the ...
# 125585  Over a period a six months, my XXXX mother app...
# 125591  RE : Complaint # XXXX Subject : XXXX / Foreclo...
# 125593  I am trying to get a principal reduction for m...
# 125596  US Bank has not released the lien and sent pro...
# 125601  I filed a rescission to my mortgage lender yea...
# 125610  Sales Manager keeps asking for same info repea...
# 125616  OWCEN made an error on my XXXX XXXX, 2016 and ...
# 125618  My loan was transferred to DiTech for servicin...
# 125619  I just refinanced my mortgage to a 15 yr fixed...
# 125620  Monday, XX/XX/XXXX " From : XXXX XXXX XXXX XXX...
# 125621  My mortgage company ( Ditech ) changed their c...
# 125622  Please see CFPB case # XXXX - I am submitting ...
# 125623  SLS purchased the servicing of my mortgage fro...
# 125632  We had a loan modification done with Nationsta...
# 125634  I have doubled my income in the last 2 months ...
# 125636  Nova financial, you are better off finding ano...
# 125638  I have been working with my lender for a loan ...
# 125645  I obtain a mortgage loan from Finance of Ameri...
# 125647  I have had my mortgage loan through Bank of Am...
# 125650  My original mortgage was with XXXX. In XXXX 20...
# 125654  XXXX XXXX has had complaints filed against him...
# 125674  On XX/XX/2016, I used online bill pay through ...
#
#                                   Company public response  \
# 12                                                    NaN
# 13                                                    NaN
# 19                                                    NaN
# 22                                                    NaN
# 25                                                    NaN
# 33                                                    NaN
# 43                                                    NaN
# 44                                                    NaN
# 46                                                    NaN
# 47                                                    NaN
# 48                                                    NaN
# 49      Company believes it acted appropriately as aut...
# 50                                                    NaN
# 57                                                    NaN
# 58       Company chooses not to provide a public response
# 64                                                    NaN
# 69                                                    NaN
# 72       Company chooses not to provide a public response
# 81                                                    NaN
# 87                                                    NaN
# 88      Company believes it acted appropriately as aut...
# 101      Company chooses not to provide a public response
# 102     Company believes it acted appropriately as aut...
# 104      Company chooses not to provide a public response
# 107                                                   NaN
# 121                                                   NaN
# 122                                                   NaN
# 127                                                   NaN
# 131      Company chooses not to provide a public response
# 139                                                   NaN
# ...                                                   ...
# 125541  Company has responded to the consumer and the ...
# 125543  Company believes it acted appropriately as aut...
# 125546  Company has responded to the consumer and the ...
# 125553   Company chooses not to provide a public response
# 125557                                                NaN
# 125564  Company believes it acted appropriately as aut...
# 125582  Company believes complaint is the result of an...
# 125583                                                NaN
# 125585  Company has responded to the consumer and the ...
# 125591  Company believes it acted appropriately as aut...
# 125593  Company has responded to the consumer and the ...
# 125596  Company has responded to the consumer and the ...
# 125601                                                NaN
# 125610  Company believes it acted appropriately as aut...
# 125616                                                NaN
# 125618  Company believes complaint represents an oppor...
# 125619                                                NaN
# 125620  Company has responded to the consumer and the ...
# 125621  Company believes complaint represents an oppor...
# 125622                                                NaN
# 125623  Company has responded to the consumer and the ...
# 125632                                                NaN
# 125634  Company has responded to the consumer and the ...
# 125636                                                NaN
# 125638                                                NaN
# 125645                                                NaN
# 125647  Company has responded to the consumer and the ...
# 125650                                                NaN
# 125654                                                NaN
# 125674  Company believes it acted appropriately as aut...
#
#                                         Company State ZIP code  \
# 12                         Ditech Financial LLC    GA    300XX
# 13                                        Ocwen    IL    627XX
# 19                         Ditech Financial LLC    CA    926XX
# 22                               Morgan Stanley    CA    944XX
# 25                        Wells Fargo & Company    TX    770XX
# 33             HSBC North America Holdings Inc.    NY    141XX
# 43                        Wells Fargo & Company    MT    598XX
# 44        Rushmore Loan Management Services LLC    CA    956XX
# 46                CIT Bank National Association    NJ    080XX
# 47                          Nationstar Mortgage    VA    230XX
# 48                          Nationstar Mortgage    CA    925XX
# 49              Select Portfolio Servicing, Inc    NJ    080XX
# 50               Citizens Financial Group, Inc.    MA    021XX
# 57               Specialized Loan Servicing LLC    NJ    074XX
# 58                         SunTrust Banks, Inc.    CO    804XX
# 64                         Ditech Financial LLC    MA    020XX
# 69                                     Citibank    MD    207XX
# 72                                 U.S. Bancorp    CO    801XX
# 81                                        Ocwen    MA    017XX
# 87                          Nationstar Mortgage    TX    775XX
# 88                          Nationstar Mortgage    GA    300XX
# 101                                U.S. Bancorp    KS    664XX
# 102             Select Portfolio Servicing, Inc    FL    333XX
# 104                             Bank of America    CA    926XX
# 107                                       Ocwen    TX    770XX
# 121                       Wells Fargo & Company    AZ    853XX
# 122                     Caliber Home Loans, Inc    IN    463XX
# 127          Carrington Mortgage Holdings, LLC.    TX    755XX
# 131                             Bank of America    GA    309XX
# 139                                       Ocwen    KS    666XX
# ...                                         ...   ...      ...
# 125541                    Wells Fargo & Company    CA    945XX
# 125543                      Nationstar Mortgage    CA    920XX
# 125546                         Freedom Mortgage    SC    295XX
# 125553                    Wells Fargo & Company    CA    943XX
# 125557                OMNI MORTGAGE CORPORATION    NY    117XX
# 125564      North Dakota Housing Finance Agency    ND    586XX
# 125582                             USAA Savings    GA    303XX
# 125583                      Nationstar Mortgage    UT    846XX
# 125585                           BB&T Financial    TX    752XX
# 125591                 Shellpoint Partners, LLC    CA    949XX
# 125593                     SunTrust Banks, Inc.    GA    302XX
# 125596                             U.S. Bancorp    FL    329XX
# 125601                                    Ocwen    NJ    078XX
# 125610               Nations Lending Coporation    OH    430XX
# 125616                                    Ocwen    NY    102XX
# 125618                     Ditech Financial LLC    PA    190XX
# 125619                              Arvest Bank    IN    463XX
# 125620                     Round Point Mortgage    GA    300XX
# 125621                     Ditech Financial LLC    TX    750XX
# 125622                Dovenmuehle Mortgage Inc.    PA    191XX
# 125623           Specialized Loan Servicing LLC    NY    100XX
# 125632                      Nationstar Mortgage    TN    377XX
# 125634                          Bank of America    CA    900XX
# 125636  NOVA Financial & Investment Corporation    AZ    856XX
# 125638                  Caliber Home Loans, Inc    CA    925XX
# 125645          Finance of America Mortgage LLC    NJ    083XX
# 125647                          Bank of America    WI    531XX
# 125650                      Nationstar Mortgage    NY    103XX
# 125654    Integrity First Financial Group, Inc.    MO    631XX
# 125674                     Ditech Financial LLC    WI    535XX
#
#              ...        Consumer consent provided? Submitted via  \
# 12           ...                  Consent provided           Web
# 13           ...                  Consent provided           Web
# 19           ...                  Consent provided           Web
# 22           ...                  Consent provided           Web
# 25           ...                  Consent provided           Web
# 33           ...                  Consent provided           Web
# 43           ...                  Consent provided           Web
# 44           ...                  Consent provided           Web
# 46           ...                  Consent provided           Web
# 47           ...                  Consent provided           Web
# 48           ...                  Consent provided           Web
# 49           ...                  Consent provided           Web
# 50           ...                  Consent provided           Web
# 57           ...                  Consent provided           Web
# 58           ...                  Consent provided           Web
# 64           ...                  Consent provided           Web
# 69           ...                  Consent provided           Web
# 72           ...                  Consent provided           Web
# 81           ...                  Consent provided           Web
# 87           ...                  Consent provided           Web
# 88           ...                  Consent provided           Web
# 101          ...                  Consent provided           Web
# 102          ...                  Consent provided           Web
# 104          ...                  Consent provided           Web
# 107          ...                  Consent provided           Web
# 121          ...                  Consent provided           Web
# 122          ...                  Consent provided           Web
# 127          ...                  Consent provided           Web
# 131          ...                  Consent provided           Web
# 139          ...                  Consent provided           Web
# ...          ...                               ...           ...
# 125541       ...                  Consent provided           Web
# 125543       ...                  Consent provided           Web
# 125546       ...                  Consent provided           Web
# 125553       ...                  Consent provided           Web
# 125557       ...                  Consent provided           Web
# 125564       ...                  Consent provided           Web
# 125582       ...                  Consent provided           Web
# 125583       ...                  Consent provided           Web
# 125585       ...                  Consent provided           Web
# 125591       ...                  Consent provided           Web
# 125593       ...                  Consent provided           Web
# 125596       ...                  Consent provided           Web
# 125601       ...                  Consent provided           Web
# 125610       ...                  Consent provided           Web
# 125616       ...                  Consent provided           Web
# 125618       ...                  Consent provided           Web
# 125619       ...                  Consent provided           Web
# 125620       ...                  Consent provided           Web
# 125621       ...                  Consent provided           Web
# 125622       ...                  Consent provided           Web
# 125623       ...                  Consent provided           Web
# 125632       ...                  Consent provided           Web
# 125634       ...                  Consent provided           Web
# 125636       ...                  Consent provided           Web
# 125638       ...                  Consent provided           Web
# 125645       ...                  Consent provided           Web
# 125647       ...                  Consent provided           Web
# 125650       ...                  Consent provided           Web
# 125654       ...                  Consent provided           Web
# 125674       ...                  Consent provided           Web
#
#        Date sent to company     Company response to consumer Timely response?  \
# 12                3/23/2015      Closed with monetary relief              Yes
# 13                3/23/2015          Closed with explanation              Yes
# 19                3/24/2015  Closed with non-monetary relief              Yes
# 22                3/24/2015          Closed with explanation              Yes
# 25                3/24/2015          Closed with explanation              Yes
# 33                3/24/2015          Closed with explanation              Yes
# 43                3/24/2015  Closed with non-monetary relief              Yes
# 44                3/19/2015          Closed with explanation              Yes
# 46                3/19/2015          Closed with explanation              Yes
# 47                3/19/2015          Closed with explanation              Yes
# 48                3/19/2015          Closed with explanation              Yes
# 49                3/19/2015          Closed with explanation              Yes
# 50                3/19/2015          Closed with explanation              Yes
# 57                3/19/2015          Closed with explanation              Yes
# 58                3/24/2015  Closed with non-monetary relief              Yes
# 64                3/24/2015  Closed with non-monetary relief              Yes
# 69                3/19/2015          Closed with explanation              Yes
# 72                3/27/2015          Closed with explanation              Yes
# 81                 4/1/2015          Closed with explanation              Yes
# 87                3/19/2015          Closed with explanation              Yes
# 88                3/24/2015          Closed with explanation              Yes
# 101               3/27/2015          Closed with explanation              Yes
# 102               3/27/2015          Closed with explanation              Yes
# 104               3/19/2015      Closed with monetary relief              Yes
# 107               3/24/2015          Closed with explanation              Yes
# 121               3/19/2015          Closed with explanation              Yes
# 122               3/25/2015          Closed with explanation              Yes
# 127               3/19/2015          Closed with explanation              Yes
# 131                4/6/2015          Closed with explanation              Yes
# 139               3/19/2015          Closed with explanation              Yes
# ...                     ...                              ...              ...
# 125541            10/5/2016          Closed with explanation              Yes
# 125543           12/13/2016          Closed with explanation              Yes
# 125546           12/13/2016          Closed with explanation              Yes
# 125553            6/30/2015          Closed with explanation              Yes
# 125557           11/16/2016          Closed with explanation               No
# 125564           11/18/2016          Closed with explanation              Yes
# 125582           12/13/2016      Closed with monetary relief              Yes
# 125583            10/7/2016          Closed with explanation              Yes
# 125585           12/13/2016          Closed with explanation              Yes
# 125591           12/13/2016          Closed with explanation              Yes
# 125593           11/11/2016          Closed with explanation              Yes
# 125596            11/3/2016          Closed with explanation              Yes
# 125601            11/2/2016          Closed with explanation              Yes
# 125610           12/14/2016          Closed with explanation              Yes
# 125616           11/19/2016          Closed with explanation              Yes
# 125618            9/23/2016          Closed with explanation              Yes
# 125619           11/18/2016          Closed with explanation              Yes
# 125620           10/14/2016          Closed with explanation              Yes
# 125621            11/2/2016          Closed with explanation              Yes
# 125622            11/4/2016          Closed with explanation              Yes
# 125623           12/13/2016          Closed with explanation              Yes
# 125632           11/18/2016                           Closed              Yes
# 125634           10/26/2016          Closed with explanation              Yes
# 125636            11/5/2016          Closed with explanation              Yes
# 125638           11/18/2016                           Closed              Yes
# 125645           11/18/2016          Closed with explanation              Yes
# 125647            9/20/2016      Closed with monetary relief              Yes
# 125650           10/27/2016          Closed with explanation              Yes
# 125654           11/18/2016          Closed with explanation               No
# 125674           12/13/2016          Closed with explanation              Yes
#
#        Consumer disputed? Complaint ID  Consumer Claim  Company Offer  \
# 12                    Yes      1296823       185482.51      159366.50
# 13                     No      1296831       101340.54      182761.24
# 19                     No      1297594       103381.81      186432.77
# 22                     No      1297626       219860.35      153908.22
# 25                     No      1297644       153377.06      169317.86
# 33                     No      1299207       105940.81      123409.96
# 43                     No      1297874       234463.04      133847.95
# 44                    Yes      1292137       177586.11       57294.34
# 46                     No      1290543        71574.50       24275.87
# 47                     No      1292139        61228.78       80961.10
# 48                     No      1290545       180004.43      214540.82
# 49                     No      1292065       136855.25       -7012.71
# 50                    Yes      1290564       110769.16       85293.98
# 57                    Yes      1290644       171647.18      167269.02
# 58                     No      1298042        91360.36      161713.50
# 64                    Yes      1298116       186816.79      228400.77
# 69                    Yes      1290765       174171.64       79753.02
# 72                     No      1304648       183467.48      130950.91
# 81                     No      1304057        94292.76      136124.02
# 87                     No      1290871       213279.65      157675.58
# 88                    Yes      1298322       109029.12       74100.13
# 101                   Yes      1304971       182034.47      114693.36
# 102                    No      1304692       150718.63      165691.38
# 104                    No      1291084       127616.28       66064.08
# 107                    No      1298656       150701.05      167926.46
# 121                   Yes      1291277       166114.09       81243.71
# 122                    No      1298770       198868.56      127222.11
# 127                    No      1292613       249757.98      136786.81
# 131                   Yes      1305325       169979.86       91967.15
# 139                   Yes      1292075       200977.97      208273.54
# ...                   ...          ...             ...            ...
# 125541                 No      2141468       121095.06        7620.71
# 125543                NaN      2247658       202258.79      123664.33
# 125546                NaN      2248476       141880.00      148011.31
# 125553                 No      1444123       152880.49      102193.95
# 125557                NaN      2209300       147430.37      114010.33
# 125564                 No      2180679       177723.48      216986.74
# 125582                NaN      2247493       114277.49      158659.18
# 125583                 No      2152061       129114.44       98844.55
# 125585                NaN      2244513        65426.99      140152.91
# 125591                Yes      2243820       169197.05       66552.62
# 125593                 No      2205208       237211.09       47003.87
# 125596                 No      2192518        97710.88       64392.79
# 125601                 No      2169166       140341.51      138125.27
# 125610                NaN      2248733       117591.02      103684.51
# 125616                Yes      2214614       142775.89      191873.76
# 125618                 No      2128559       182275.93       67170.52
# 125619                NaN      2214834       170016.45       65751.65
# 125620                 No      2153211        61244.98       99590.82
# 125621                 No      2186239       194123.95       63202.10
# 125622                 No      2191249       143222.59       16049.53
# 125623                NaN      2248373       161307.06      119452.98
# 125632                NaN      2215986       134966.28      163581.65
# 125634                 No      2177009        85949.83      165111.24
# 125636                 No      2197004       236151.02      119853.39
# 125638                NaN      2216156       126366.03       67134.38
# 125645                NaN      2215655       185077.71       92015.61
# 125647                 No      2122648       207892.82      180364.18
# 125650                 No      2182081       236687.68      221160.59
# 125654                NaN      2215900        74632.68       57102.99
# 125674                NaN      2247724       136798.52      114342.28
#
#         Amount Received
# 12            234193.94
# 13            122579.47
# 19            110905.24
# 22             99746.42
# 25             79792.59
# 33             89578.55
# 43            104833.17
# 44             89278.77
# 46             65055.48
# 47             22089.39
# 48             29346.45
# 49             70034.66
# 50            140950.99
# 57            115595.66
# 58             17758.65
# 64            134987.03
# 69            101711.41
# 72            141618.46
# 81            123227.27
# 87             79534.17
# 88             40478.75
# 101            67510.76
# 102           136517.37
# 104            77037.93
# 107            53600.10
# 121            26314.16
# 122           104428.20
# 127            71294.46
# 131            12702.47
# 139           140895.90
# ...                 ...
# 125541         -1882.12
# 125543         92247.20
# 125546        -15018.41
# 125553        173177.07
# 125557         47345.30
# 125564        125397.78
# 125582         85375.31
# 125583         56791.42
# 125585         99335.38
# 125591         85769.96
# 125593        190013.21
# 125596         74558.88
# 125601         83521.07
# 125610         43800.98
# 125616        101699.37
# 125618         92324.06
# 125619          1991.28
# 125620         99820.75
# 125621         47589.77
# 125622        112755.79
# 125623         56043.00
# 125632         59377.15
# 125634         84770.01
# 125636        123155.57
# 125638        133643.76
# 125645         69618.41
# 125647         35887.38
# 125650         64958.93
# 125654        182860.61
# 125674        106343.36
#
# [26811 rows x 21 columns]

# %%
# 9. Use df[(condition_1) | (condition_2)] notation to get Mortgage and Credit card products.
# Hint: separate conditions must be wrapped in () (and use | or & like notation).

df[(df['Product'] == 'Mortgage') & (df['State'] == 'GA')]
# Out:
#        Date received   Product                             Sub-product  \
# 12         3/23/2015  Mortgage                            FHA mortgage
# 88         3/24/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 131        3/27/2015  Mortgage                            FHA mortgage
# 149        3/28/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 180        3/29/2015  Mortgage                            FHA mortgage
# 329        3/30/2015  Mortgage             Conventional fixed mortgage
# 398        3/30/2015  Mortgage                            FHA mortgage
# 466         4/4/2015  Mortgage                            FHA mortgage
# 667         4/1/2015  Mortgage             Conventional fixed mortgage
# 837         4/1/2015  Mortgage                          Other mortgage
# 978        4/16/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 1311       4/13/2015  Mortgage                             VA mortgage
# 1324       4/18/2015  Mortgage                            FHA mortgage
# 1429       4/20/2015  Mortgage             Conventional fixed mortgage
# 1461       4/23/2015  Mortgage                        Reverse mortgage
# 1670       4/14/2015  Mortgage             Conventional fixed mortgage
# 1701       4/15/2015  Mortgage                            FHA mortgage
# 1813        5/8/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 1846       4/29/2015  Mortgage             Conventional fixed mortgage
# 1847       4/29/2015  Mortgage             Conventional fixed mortgage
# 1959       4/23/2015  Mortgage                          Other mortgage
# 2035        5/8/2015  Mortgage             Conventional fixed mortgage
# 2044       5/14/2015  Mortgage             Conventional fixed mortgage
# 2122       4/29/2015  Mortgage                             VA mortgage
# 2350       4/30/2015  Mortgage             Conventional fixed mortgage
# 2370       5/12/2015  Mortgage                            FHA mortgage
# 2443       5/20/2015  Mortgage             Conventional fixed mortgage
# 2497       5/26/2015  Mortgage                            FHA mortgage
# 2652       5/15/2015  Mortgage                          Other mortgage
# 2737       5/20/2015  Mortgage                             VA mortgage
# ...              ...       ...                                     ...
# 122460     3/21/2016  Mortgage                            FHA mortgage
# 122470     10/3/2016  Mortgage                            FHA mortgage
# 122646    11/22/2016  Mortgage             Conventional fixed mortgage
# 122693     12/7/2016  Mortgage                            FHA mortgage
# 122814     9/19/2016  Mortgage             Conventional fixed mortgage
# 122835    11/13/2016  Mortgage             Conventional fixed mortgage
# 122954     12/6/2016  Mortgage                            FHA mortgage
# 122999    10/22/2016  Mortgage             Conventional fixed mortgage
# 123239     11/5/2016  Mortgage                            FHA mortgage
# 123395    11/15/2016  Mortgage             Conventional fixed mortgage
# 123507     11/4/2016  Mortgage                             VA mortgage
# 123642    10/31/2016  Mortgage                          Other mortgage
# 123915    10/14/2016  Mortgage                            FHA mortgage
# 123968    11/18/2016  Mortgage                          Other mortgage
# 124204    11/17/2016  Mortgage             Conventional fixed mortgage
# 124262     11/1/2016  Mortgage             Conventional fixed mortgage
# 124431     12/9/2016  Mortgage             Conventional fixed mortgage
# 124787    11/17/2016  Mortgage             Conventional fixed mortgage
# 124799     12/9/2016  Mortgage             Conventional fixed mortgage
# 125028    11/17/2016  Mortgage             Conventional fixed mortgage
# 125030     12/8/2016  Mortgage      Home equity loan or line of credit
# 125093     12/8/2016  Mortgage                            FHA mortgage
# 125283    12/13/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125327    11/18/2016  Mortgage             Conventional fixed mortgage
# 125437    12/13/2016  Mortgage                            FHA mortgage
# 125469    11/18/2016  Mortgage      Home equity loan or line of credit
# 125492    12/14/2016  Mortgage                             VA mortgage
# 125582    12/13/2016  Mortgage                             VA mortgage
# 125593    11/11/2016  Mortgage                            FHA mortgage
# 125620    10/10/2016  Mortgage                             VA mortgage
#
#                                            Issue Sub-issue  \
# 12      Loan servicing, payments, escrow account       NaN
# 88      Loan servicing, payments, escrow account       NaN
# 131     Loan modification,collection,foreclosure       NaN
# 149     Loan servicing, payments, escrow account       NaN
# 180     Application, originator, mortgage broker       NaN
# 329     Loan servicing, payments, escrow account       NaN
# 398                 Settlement process and costs       NaN
# 466     Loan modification,collection,foreclosure       NaN
# 667     Loan modification,collection,foreclosure       NaN
# 837     Loan modification,collection,foreclosure       NaN
# 978     Application, originator, mortgage broker       NaN
# 1311    Loan servicing, payments, escrow account       NaN
# 1324    Loan servicing, payments, escrow account       NaN
# 1429              Credit decision / Underwriting       NaN
# 1461    Loan servicing, payments, escrow account       NaN
# 1670                Settlement process and costs       NaN
# 1701    Loan modification,collection,foreclosure       NaN
# 1813    Loan servicing, payments, escrow account       NaN
# 1846    Loan servicing, payments, escrow account       NaN
# 1847    Loan modification,collection,foreclosure       NaN
# 1959    Loan servicing, payments, escrow account       NaN
# 2035    Loan modification,collection,foreclosure       NaN
# 2044    Loan servicing, payments, escrow account       NaN
# 2122                Settlement process and costs       NaN
# 2350    Loan servicing, payments, escrow account       NaN
# 2370    Loan modification,collection,foreclosure       NaN
# 2443    Loan servicing, payments, escrow account       NaN
# 2497    Loan servicing, payments, escrow account       NaN
# 2652    Application, originator, mortgage broker       NaN
# 2737    Loan servicing, payments, escrow account       NaN
# ...                                          ...       ...
# 122460  Application, originator, mortgage broker       NaN
# 122470  Loan modification,collection,foreclosure       NaN
# 122646              Settlement process and costs       NaN
# 122693  Application, originator, mortgage broker       NaN
# 122814  Loan servicing, payments, escrow account       NaN
# 122835  Loan servicing, payments, escrow account       NaN
# 122954  Loan modification,collection,foreclosure       NaN
# 122999  Loan servicing, payments, escrow account       NaN
# 123239  Loan modification,collection,foreclosure       NaN
# 123395  Application, originator, mortgage broker       NaN
# 123507  Application, originator, mortgage broker       NaN
# 123642  Loan servicing, payments, escrow account       NaN
# 123915  Loan modification,collection,foreclosure       NaN
# 123968  Loan modification,collection,foreclosure       NaN
# 124204  Loan servicing, payments, escrow account       NaN
# 124262  Loan servicing, payments, escrow account       NaN
# 124431  Loan modification,collection,foreclosure       NaN
# 124787            Credit decision / Underwriting       NaN
# 124799  Loan servicing, payments, escrow account       NaN
# 125028  Loan servicing, payments, escrow account       NaN
# 125030  Loan modification,collection,foreclosure       NaN
# 125093  Loan modification,collection,foreclosure       NaN
# 125283  Loan modification,collection,foreclosure       NaN
# 125327  Loan servicing, payments, escrow account       NaN
# 125437  Loan modification,collection,foreclosure       NaN
# 125469  Loan servicing, payments, escrow account       NaN
# 125492  Application, originator, mortgage broker       NaN
# 125582              Settlement process and costs       NaN
# 125593  Loan modification,collection,foreclosure       NaN
# 125620  Loan servicing, payments, escrow account       NaN
#
#                              Consumer complaint narrative  \
# 12      I am assisted with my mortgage through an agen...
# 88      I schedule my mortgage payment, using the mort...
# 131     I was part of the XXXX and received payment la...
# 149     This complaint relates to my mortgage, service...
# 180     I was approved for an FHA loan by MLD MORTGAGE...
# 329     The complaint is against Wells Fargo Mortgage ...
# 398     The XXXX company have tried to enforce a fraud...
# 466     We got behind on our house payments, and the m...
# 667     I am writing this on behalf of my client, who ...
# 837     I applied for a loan modification through BSI ...
# 978     Capital One has XXXX me once again. This would...
# 1311    XX/XX/XXXX and XX/XX/XXXX - I tried to make a ...
# 1324    Once again, FOR THE NINTH CONSECUTIVE MONTH, t...
# 1429    We applied for a mortgage with BBVA Compass. S...
# 1461    For more than XXXX days, the family of XXXX XX...
# 1670    In XXXX of XXXX I notified PNC Mortgage that I...
# 1701    Dual Tracking and Foreclosure violation by Cal...
# 1813    Green Tree Servicing ( Called GT here ) owns m...
# 1846    United Security Financial is the most deceptiv...
# 1847    My mortgage company is refusing to work with m...
# 1959    I have a mortgage loan with XXXX XXXX in which...
# 2035    My family income rate decreased which lead us ...
# 2044    Mortgagor has asked for and received excessive...
# 2122    The very first day that I spoke with Wells Far...
# 2350    My house is being foreclosed on by a mortgage ...
# 2370    I bought my house in XXXX, my first lender was...
# 2443    Ocwen Loan Servicing , LLC sent an Annual Escr...
# 2497    I own my home through Freedom Mortgage XXXX XX...
# 2652    I am requesting your assistance with a Deed In...
# 2737    According to our PSA 's from the United States...
# ...                                                   ...
# 122460  Southeast Mortgage, XXXX, GA was the lender on...
# 122470  I was with a company Called Green Tree Mortgag...
# 122646  Approved for a XXXX with Wells Fargo Bank and ...
# 122693  I went under contract for a home in XXXX 2016 ...
# 122814  I am very concern about the shortage of our es...
# 122835  I have been sending extra money to Ocwen to be...
# 122954  I have a FHA loan and I called Wells Fargo to ...
# 122999  We have been trying to refinance a XXXX loan w...
# 123239  Dear XXXX iam writing this note to you telling...
# 123395  I sent in my payment for XXXX 10 days ago and ...
# 123507  Service 1st mortgage claims to help veterans b...
# 123642  My husband and I bought a home with a typical ...
# 123915  CitiMortgage Inc. is the mortgage company I ha...
# 123968  I fell behind in my mortgage due to some finan...
# 124204  I have my mortgage with 21st mortgage. So far ...
# 124262  Our loan was acquired by LoanCare on XXXX/XXXX...
# 124431  I started a short sale process with Select Por...
# 124787  We have been approved for a Loan and three wee...
# 124799  I received a foreclosure letter from Select Po...
# 125028  I am a former XXXX Mortgage holder, whose loan...
# 125030  We were recently denied a settlement counter-o...
# 125093  I had to have XXXX in XX/XX/2016, XXXX months ...
# 125283  XX/XX/XXXX XXXX XXXX XXXX XXXX, GA XXXX Direct...
# 125327  My mortage loan with XXXX was sold to Ocwen. W...
# 125437  In XXXX of XXXX I lost my job and became worri...
# 125469  Realtime Resolutions out of XXXX TX took over ...
# 125492  Suntrust violated the Equal Credit Opportunity...
# 125582  I contracted with USAA Federal Savings Bank to...
# 125593  I am trying to get a principal reduction for m...
# 125620  Monday, XX/XX/XXXX " From : XXXX XXXX XXXX XXX...
#
#                                   Company public response  \
# 12                                                    NaN
# 88      Company believes it acted appropriately as aut...
# 131      Company chooses not to provide a public response
# 149                                                   NaN
# 180     Company disputes the facts presented in the co...
# 329                                                   NaN
# 398      Company chooses not to provide a public response
# 466                                                   NaN
# 667     Company believes it acted appropriately as aut...
# 837     Company believes complaint is the result of an...
# 978                                                   NaN
# 1311                                                  NaN
# 1324                                                  NaN
# 1429                                                  NaN
# 1461                                                  NaN
# 1670                                                  NaN
# 1701                                                  NaN
# 1813                                                  NaN
# 1846                                                  NaN
# 1847                                                  NaN
# 1959                                                  NaN
# 2035                                                  NaN
# 2044                                                  NaN
# 2122     Company chooses not to provide a public response
# 2350                                                  NaN
# 2370                                                  NaN
# 2443                                                  NaN
# 2497     Company chooses not to provide a public response
# 2652                                                  NaN
# 2737                                                  NaN
# ...                                                   ...
# 122460                                                NaN
# 122470  Company believes it acted appropriately as aut...
# 122646  Company has responded to the consumer and the ...
# 122693  Company has responded to the consumer and the ...
# 122814  Company believes it acted appropriately as aut...
# 122835                                                NaN
# 122954  Company has responded to the consumer and the ...
# 122999                                                NaN
# 123239  Company believes it acted appropriately as aut...
# 123395                                                NaN
# 123507  Company disputes the facts presented in the co...
# 123642  Company has responded to the consumer and the ...
# 123915  Company has responded to the consumer and the ...
# 123968                                                NaN
# 124204                                                NaN
# 124262  Company has responded to the consumer and the ...
# 124431  Company believes it acted appropriately as aut...
# 124787                                                NaN
# 124799  Company believes it acted appropriately as aut...
# 125028                                                NaN
# 125030  Company believes it acted appropriately as aut...
# 125093  Company has responded to the consumer and the ...
# 125283  Company believes it acted appropriately as aut...
# 125327                                                NaN
# 125437  Company has responded to the consumer and the ...
# 125469                                                NaN
# 125492  Company has responded to the consumer and the ...
# 125582  Company believes complaint is the result of an...
# 125593  Company has responded to the consumer and the ...
# 125620  Company has responded to the consumer and the ...
#
#                                       Company State ZIP code       ...         \
# 12                       Ditech Financial LLC    GA    300XX       ...
# 88                        Nationstar Mortgage    GA    300XX       ...
# 131                           Bank of America    GA    309XX       ...
# 149                      JPMorgan Chase & Co.    GA    303XX       ...
# 180                        MLD Mortgage, Inc.    GA    303XX       ...
# 329                     Wells Fargo & Company    GA    308XX       ...
# 398                      SunTrust Banks, Inc.    GA    302XX       ...
# 466                      Ditech Financial LLC    GA    302XX       ...
# 667                          Servis One, Inc.    GA    300XX       ...
# 837                          Servis One, Inc.    GA    306XX       ...
# 978                               Capital One    GA    300XX       ...
# 1311       Carrington Mortgage Holdings, LLC.    GA    301XX       ...
# 1324                                    Ocwen    GA    300XX       ...
# 1429                             BBVA Compass    GA    303XX       ...
# 1461            CIT Bank National Association    GA    300XX       ...
# 1670                            PNC Bank N.A.    GA    301XX       ...
# 1701                  Caliber Home Loans, Inc    GA    300XX       ...
# 1813                     Ditech Financial LLC    GA    303XX       ...
# 1846           United Security Financial Corp    GA    351XX       ...
# 1847           Specialized Loan Servicing LLC    GA    300XX       ...
# 1959                            Seterus, Inc.    GA    300XX       ...
# 2035                      Nationstar Mortgage    GA    315XX       ...
# 2044                     Ditech Financial LLC    GA    303XX       ...
# 2122                    Wells Fargo & Company    GA    309XX       ...
# 2350                     Ditech Financial LLC    GA    301XX       ...
# 2370                          Bank of America    GA    302XX       ...
# 2443                                    Ocwen    GA    300XX       ...
# 2497                         Freedom Mortgage    GA    306XX       ...
# 2652                          Bank of America    GA    306XX       ...
# 2737                     JPMorgan Chase & Co.    GA    302XX       ...
# ...                                       ...   ...      ...       ...
# 122460    Southeast Mortgage of Georgia, Inc.    GA    301XX       ...
# 122470                   Ditech Financial LLC    GA    314XX       ...
# 122646                  Wells Fargo & Company    GA    302XX       ...
# 122693                  Wells Fargo & Company    GA    301XX       ...
# 122814           Primary Residential Mortgage    GA    300XX       ...
# 122835                                  Ocwen    GA    308XX       ...
# 122954                  Wells Fargo & Company    GA    301XX       ...
# 122999                          Seterus, Inc.    GA    303XX       ...
# 123239  Rushmore Loan Management Services LLC    GA    302XX       ...
# 123395                                  Ocwen    GA    303XX       ...
# 123507             Service 1st Mortgage, Inc.    GA    233XX       ...
# 123642                         BB&T Financial    GA    303XX       ...
# 123915                               Citibank    GA    300XX       ...
# 123968                    Nationstar Mortgage    GA    303XX       ...
# 124204              21st Mortgage Corporation    GA    310XX       ...
# 124262                              Loan Care    GA    300XX       ...
# 124431        Select Portfolio Servicing, Inc    GA    301XX       ...
# 124787                     Home Servicing LLC    GA    301XX       ...
# 124799        Select Portfolio Servicing, Inc    GA    300XX       ...
# 125028                          Seterus, Inc.    GA    300XX       ...
# 125030                           USAA Savings    GA    301XX       ...
# 125093                           U.S. Bancorp    GA    302XX       ...
# 125283        Select Portfolio Servicing, Inc    GA    303XX       ...
# 125327                                  Ocwen    GA    302XX       ...
# 125437                  Wells Fargo & Company    GA    300XX       ...
# 125469                  Real Time Resolutions    GA    314XX       ...
# 125492                   SunTrust Banks, Inc.    GA    300XX       ...
# 125582                           USAA Savings    GA    303XX       ...
# 125593                   SunTrust Banks, Inc.    GA    302XX       ...
# 125620                   Round Point Mortgage    GA    300XX       ...
#
#        Consumer consent provided? Submitted via Date sent to company  \
# 12               Consent provided           Web            3/23/2015
# 88               Consent provided           Web            3/24/2015
# 131              Consent provided           Web             4/6/2015
# 149              Consent provided           Web            3/28/2015
# 180              Consent provided           Web            3/29/2015
# 329              Consent provided           Web            3/30/2015
# 398              Consent provided           Web             5/4/2015
# 466              Consent provided           Web             4/4/2015
# 667              Consent provided           Web             4/1/2015
# 837              Consent provided           Web             4/1/2015
# 978              Consent provided           Web            4/16/2015
# 1311             Consent provided           Web            4/13/2015
# 1324             Consent provided           Web            4/21/2015
# 1429             Consent provided           Web            4/20/2015
# 1461             Consent provided           Web            5/20/2015
# 1670             Consent provided           Web            4/14/2015
# 1701             Consent provided           Web            4/15/2015
# 1813             Consent provided           Web             5/8/2015
# 1846             Consent provided           Web            4/29/2015
# 1847             Consent provided           Web            4/29/2015
# 1959             Consent provided           Web            4/23/2015
# 2035             Consent provided           Web             5/8/2015
# 2044             Consent provided           Web            5/14/2015
# 2122             Consent provided           Web            4/29/2015
# 2350             Consent provided           Web            4/30/2015
# 2370             Consent provided           Web            5/12/2015
# 2443             Consent provided           Web            5/20/2015
# 2497             Consent provided           Web            5/29/2015
# 2652             Consent provided           Web            5/15/2015
# 2737             Consent provided           Web            5/28/2015
# ...                           ...           ...                  ...
# 122460           Consent provided           Web            3/21/2016
# 122470           Consent provided           Web            10/3/2016
# 122646           Consent provided           Web           11/22/2016
# 122693           Consent provided           Web            12/7/2016
# 122814           Consent provided           Web            9/19/2016
# 122835           Consent provided           Web           11/13/2016
# 122954           Consent provided           Web            12/6/2016
# 122999           Consent provided           Web           10/31/2016
# 123239           Consent provided           Web            11/5/2016
# 123395           Consent provided           Web           11/15/2016
# 123507           Consent provided           Web            11/4/2016
# 123642           Consent provided           Web           10/31/2016
# 123915           Consent provided           Web           10/18/2016
# 123968           Consent provided           Web           11/18/2016
# 124204           Consent provided           Web           11/17/2016
# 124262           Consent provided           Web            11/2/2016
# 124431           Consent provided           Web            12/9/2016
# 124787           Consent provided           Web           11/17/2016
# 124799           Consent provided           Web            12/9/2016
# 125028           Consent provided           Web           11/17/2016
# 125030           Consent provided           Web            12/8/2016
# 125093           Consent provided           Web            12/9/2016
# 125283           Consent provided           Web           12/13/2016
# 125327           Consent provided           Web           11/18/2016
# 125437           Consent provided           Web           12/13/2016
# 125469           Consent provided           Web           11/18/2016
# 125492           Consent provided           Web           12/14/2016
# 125582           Consent provided           Web           12/13/2016
# 125593           Consent provided           Web           11/11/2016
# 125620           Consent provided           Web           10/14/2016
#
#            Company response to consumer Timely response? Consumer disputed?  \
# 12          Closed with monetary relief              Yes                Yes
# 88              Closed with explanation              Yes                Yes
# 131             Closed with explanation              Yes                Yes
# 149             Closed with explanation              Yes                Yes
# 180             Closed with explanation              Yes                 No
# 329             Closed with explanation               No                 No
# 398             Closed with explanation              Yes                Yes
# 466             Closed with explanation              Yes                 No
# 667             Closed with explanation              Yes                 No
# 837             Closed with explanation              Yes                Yes
# 978             Closed with explanation              Yes                 No
# 1311            Closed with explanation              Yes                 No
# 1324            Closed with explanation              Yes                Yes
# 1429            Closed with explanation              Yes                 No
# 1461            Closed with explanation               No                 No
# 1670            Closed with explanation              Yes                 No
# 1701            Closed with explanation              Yes                 No
# 1813            Closed with explanation              Yes                 No
# 1846    Closed with non-monetary relief              Yes                Yes
# 1847            Closed with explanation              Yes                 No
# 1959            Closed with explanation              Yes                 No
# 2035            Closed with explanation              Yes                 No
# 2044            Closed with explanation              Yes                 No
# 2122        Closed with monetary relief              Yes                 No
# 2350            Closed with explanation              Yes                 No
# 2370            Closed with explanation              Yes                 No
# 2443            Closed with explanation              Yes                 No
# 2497            Closed with explanation              Yes                 No
# 2652            Closed with explanation              Yes                 No
# 2737            Closed with explanation              Yes                Yes
# ...                                 ...              ...                ...
# 122460          Closed with explanation               No                NaN
# 122470          Closed with explanation              Yes                 No
# 122646          Closed with explanation              Yes                NaN
# 122693          Closed with explanation              Yes                NaN
# 122814          Closed with explanation              Yes                 No
# 122835          Closed with explanation              Yes                NaN
# 122954          Closed with explanation              Yes                NaN
# 122999          Closed with explanation              Yes                 No
# 123239          Closed with explanation              Yes                 No
# 123395          Closed with explanation              Yes                NaN
# 123507                           Closed              Yes                 No
# 123642          Closed with explanation              Yes                 No
# 123915          Closed with explanation              Yes                 No
# 123968                           Closed              Yes                NaN
# 124204          Closed with explanation              Yes                NaN
# 124262          Closed with explanation              Yes                 No
# 124431          Closed with explanation              Yes                NaN
# 124787          Closed with explanation              Yes                 No
# 124799          Closed with explanation              Yes                NaN
# 125028          Closed with explanation              Yes                NaN
# 125030          Closed with explanation              Yes                NaN
# 125093          Closed with explanation              Yes                NaN
# 125283          Closed with explanation              Yes                NaN
# 125327                           Closed              Yes                Yes
# 125437          Closed with explanation              Yes                Yes
# 125469          Closed with explanation              Yes                Yes
# 125492          Closed with explanation              Yes                NaN
# 125582      Closed with monetary relief              Yes                NaN
# 125593          Closed with explanation              Yes                 No
# 125620          Closed with explanation              Yes                 No
#
#        Complaint ID  Consumer Claim  Company Offer  Amount Received
# 12          1296823       185482.51      159366.50        234193.94
# 88          1298322       109029.12       74100.13         40478.75
# 131         1305325       169979.86       91967.15         12702.47
# 149         1305793       184625.19        1226.74         10242.66
# 180         1306165       214602.28      143057.00        122503.93
# 329         1307141        76500.33       81054.54        203861.04
# 398         1307644       166344.51       93443.10        104976.01
# 466         1315899       128175.27       69980.88        113732.41
# 667         1310406       147487.55      105607.53         21039.04
# 837         1311558       224559.48      180150.22         55289.36
# 978         1334018       151710.20      140374.67         73828.95
# 1311        1328166       126602.27      231495.06        181341.73
# 1324        1336418       161569.82      116721.57         79172.50
# 1429        1336628       164600.70      192379.80         99823.85
# 1461        1344920        89796.25       97208.45          9496.22
# 1670        1328808       196960.65      179300.09        180097.21
# 1701        1330526       178336.92      178085.09        140899.80
# 1813        1366758       162091.69      100004.49         42993.26
# 1846        1353732       118184.26       99955.54        137885.82
# 1847        1351933       224643.54       69501.74         22359.82
# 1959        1344667       152630.63      132054.59        135188.18
# 2035        1367642        99620.56       75026.29         99339.33
# 2044        1375831       187352.06      196702.73         81399.49
# 2122        1353196       156905.42      118892.54        201563.97
# 2350        1354014       145348.02       77170.94         92721.00
# 2370        1371019       102585.44      128109.57        168376.32
# 2443        1384435       174817.48      142009.18         95164.16
# 2497        1391837       175966.52       58289.72         60346.60
# 2652        1377850       210699.47      140108.39        157655.04
# 2737        1385493       152960.40      199737.58         87236.60
# ...             ...             ...            ...              ...
# 122460      1842188       180136.89      149072.05         70039.79
# 122470      2141071       111107.97      105241.38         30999.34
# 122646      2217161       162188.57       90647.60        109593.09
# 122693      2237365       121964.51       69816.56         74774.63
# 122814      2119761       111292.98      200558.15         56697.41
# 122835      2205581       177464.32       61611.87          9067.13
# 122954      2238624       198846.95       18588.77         65911.63
# 122999      2173281       140697.62       59803.30        101345.87
# 123239      2197100        92465.34       39208.33        120469.00
# 123395      2210056       231392.64       72112.79         80776.94
# 123507      2195173       142893.63       52472.05         35924.53
# 123642      2186788       112256.25      230457.22        138063.71
# 123915      2160190       152983.60      117799.13        165549.63
# 123968      2212683       152081.68       93149.30        196304.85
# 124204      2213124       124183.45      149248.95         76440.68
# 124262      2188530       170995.44      123101.97         91708.06
# 124431      2243987       117766.59      166203.18         94733.25
# 124787      2212907       149056.70      173649.71        132007.58
# 124799      2243154       141881.31      142814.07        140269.99
# 125028      2213865       107377.32      240290.71         22657.51
# 125030      2242023       126176.37      121678.26        136253.34
# 125093      2242317       164359.23       47870.72        120262.89
# 125283      2245563       214274.37       37899.57         53982.70
# 125327      2213561       151735.11      137970.86         93771.72
# 125437      2247676       161591.63       22851.64         44769.32
# 125469      2216184       193971.82       83765.61         68540.53
# 125492      2249249       100111.89      100326.73        156761.48
# 125582      2247493       114277.49      158659.18         85375.31
# 125593      2205208       237211.09       47003.87        190013.21
# 125620      2153211        61244.98       99590.82         99820.75
#
# [1375 rows x 21 columns]

# %%
# 10. Drop a row from your df.

df = df.drop(12)
df.head(5)
# Out:
#    Date received   Product                  Sub-product  \
# 13     3/23/2015  Mortgage               Other mortgage
# 19     3/24/2015  Mortgage               Other mortgage
# 22     3/24/2015  Mortgage  Conventional fixed mortgage
# 25     3/24/2015  Mortgage                  VA mortgage
# 33     3/24/2015  Mortgage  Conventional fixed mortgage
#
#                                        Issue Sub-issue  \
# 13  Loan servicing, payments, escrow account       NaN
# 19  Loan servicing, payments, escrow account       NaN
# 22            Credit decision / Underwriting       NaN
# 25  Loan servicing, payments, escrow account       NaN
# 33  Loan servicing, payments, escrow account       NaN
#
#                          Consumer complaint narrative Company public response  \
# 13  i submitted a payment on XXXX XXXX 2015 for my...                     NaN
# 19  Green Tree Financial somehow got XXXX Loan AFT...                     NaN
# 22  To whom it may concern, To those that follow t...                     NaN
# 25  My mortgage servicer, Wells Fargo, did not giv...                     NaN
# 33  I paid off my mortgage with XXXX Mortgage Serv...                     NaN
#
#                              Company State ZIP code       ...         \
# 13                             Ocwen    IL    627XX       ...
# 19              Ditech Financial LLC    CA    926XX       ...
# 22                    Morgan Stanley    CA    944XX       ...
# 25             Wells Fargo & Company    TX    770XX       ...
# 33  HSBC North America Holdings Inc.    NY    141XX       ...
#
#    Consumer consent provided? Submitted via Date sent to company  \
# 13           Consent provided           Web            3/23/2015
# 19           Consent provided           Web            3/24/2015
# 22           Consent provided           Web            3/24/2015
# 25           Consent provided           Web            3/24/2015
# 33           Consent provided           Web            3/24/2015
#
#        Company response to consumer Timely response? Consumer disputed?  \
# 13          Closed with explanation              Yes                 No
# 19  Closed with non-monetary relief              Yes                 No
# 22          Closed with explanation              Yes                 No
# 25          Closed with explanation              Yes                 No
# 33          Closed with explanation              Yes                 No
#
#    Complaint ID  Consumer Claim  Company Offer  Amount Received
# 13      1296831       101340.54      182761.24        122579.47
# 19      1297594       103381.81      186432.77        110905.24
# 22      1297626       219860.35      153908.22         99746.42
# 25      1297644       153377.06      169317.86         79792.59
# 33      1299207       105940.81      123409.96         89578.55
#
# [5 rows x 21 columns]

# %%
# 11. Drop a column from your df.

df = df.drop('Submitted via', axis=1)
df
# Out:
#        Date received   Product                             Sub-product  \
# 13         3/23/2015  Mortgage                          Other mortgage
# 19         3/24/2015  Mortgage                          Other mortgage
# 22         3/24/2015  Mortgage             Conventional fixed mortgage
# 25         3/24/2015  Mortgage                             VA mortgage
# 33         3/24/2015  Mortgage             Conventional fixed mortgage
# 43         3/24/2015  Mortgage             Conventional fixed mortgage
# 44         3/19/2015  Mortgage             Conventional fixed mortgage
# 46         3/19/2015  Mortgage                        Reverse mortgage
# 47         3/19/2015  Mortgage             Conventional fixed mortgage
# 48         3/19/2015  Mortgage             Conventional fixed mortgage
# 49         3/19/2015  Mortgage             Conventional fixed mortgage
# 50         3/19/2015  Mortgage                            FHA mortgage
# 57         3/19/2015  Mortgage      Home equity loan or line of credit
# 58         3/24/2015  Mortgage                          Other mortgage
# 64         3/24/2015  Mortgage             Conventional fixed mortgage
# 69         3/19/2015  Mortgage             Conventional fixed mortgage
# 72         3/27/2015  Mortgage      Home equity loan or line of credit
# 81         3/27/2015  Mortgage                          Other mortgage
# 87         3/19/2015  Mortgage             Conventional fixed mortgage
# 88         3/24/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 101        3/27/2015  Mortgage             Conventional fixed mortgage
# 102        3/27/2015  Mortgage             Conventional fixed mortgage
# 104        3/19/2015  Mortgage             Conventional fixed mortgage
# 107        3/24/2015  Mortgage                            FHA mortgage
# 121        3/19/2015  Mortgage                            FHA mortgage
# 122        3/24/2015  Mortgage             Conventional fixed mortgage
# 127        3/19/2015  Mortgage                            FHA mortgage
# 131        3/27/2015  Mortgage                            FHA mortgage
# 139        3/19/2015  Mortgage             Conventional fixed mortgage
# 146        3/28/2015  Mortgage  Conventional adjustable mortgage (ARM)
# ...              ...       ...                                     ...
# 125541     10/2/2016  Mortgage             Conventional fixed mortgage
# 125543    12/13/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125546    12/13/2016  Mortgage                             VA mortgage
# 125553     6/30/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 125557    11/16/2016  Mortgage             Conventional fixed mortgage
# 125564    10/26/2016  Mortgage             Conventional fixed mortgage
# 125582    12/13/2016  Mortgage                             VA mortgage
# 125583     10/7/2016  Mortgage             Conventional fixed mortgage
# 125585    12/10/2016  Mortgage      Home equity loan or line of credit
# 125591     12/9/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125593    11/11/2016  Mortgage                            FHA mortgage
# 125596     11/3/2016  Mortgage                             VA mortgage
# 125601    10/19/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125610    12/13/2016  Mortgage                            FHA mortgage
# 125616    11/19/2016  Mortgage      Home equity loan or line of credit
# 125618     9/23/2016  Mortgage                            FHA mortgage
# 125619    11/18/2016  Mortgage             Conventional fixed mortgage
# 125620    10/10/2016  Mortgage                             VA mortgage
# 125621    10/31/2016  Mortgage             Conventional fixed mortgage
# 125622     11/2/2016  Mortgage                            FHA mortgage
# 125623    12/13/2016  Mortgage             Conventional fixed mortgage
# 125632    11/18/2016  Mortgage             Conventional fixed mortgage
# 125634    10/26/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125636     11/5/2016  Mortgage             Conventional fixed mortgage
# 125638    11/18/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125645    11/18/2016  Mortgage                            FHA mortgage
# 125647     9/20/2016  Mortgage             Conventional fixed mortgage
# 125650    10/27/2016  Mortgage             Conventional fixed mortgage
# 125654    11/18/2016  Mortgage                          Other mortgage
# 125674    12/13/2016  Mortgage             Conventional fixed mortgage
#
#                                            Issue Sub-issue  \
# 13      Loan servicing, payments, escrow account       NaN
# 19      Loan servicing, payments, escrow account       NaN
# 22                Credit decision / Underwriting       NaN
# 25      Loan servicing, payments, escrow account       NaN
# 33      Loan servicing, payments, escrow account       NaN
# 43      Loan servicing, payments, escrow account       NaN
# 44                Credit decision / Underwriting       NaN
# 46      Application, originator, mortgage broker       NaN
# 47      Loan servicing, payments, escrow account       NaN
# 48      Loan servicing, payments, escrow account       NaN
# 49      Loan servicing, payments, escrow account       NaN
# 50      Application, originator, mortgage broker       NaN
# 57      Loan servicing, payments, escrow account       NaN
# 58                  Settlement process and costs       NaN
# 64      Loan servicing, payments, escrow account       NaN
# 69      Loan modification,collection,foreclosure       NaN
# 72      Loan modification,collection,foreclosure       NaN
# 81      Loan servicing, payments, escrow account       NaN
# 87      Loan servicing, payments, escrow account       NaN
# 88      Loan servicing, payments, escrow account       NaN
# 101     Loan modification,collection,foreclosure       NaN
# 102     Loan modification,collection,foreclosure       NaN
# 104                 Settlement process and costs       NaN
# 107     Loan servicing, payments, escrow account       NaN
# 121     Loan servicing, payments, escrow account       NaN
# 122     Loan servicing, payments, escrow account       NaN
# 127     Loan servicing, payments, escrow account       NaN
# 131     Loan modification,collection,foreclosure       NaN
# 139     Loan modification,collection,foreclosure       NaN
# 146     Loan modification,collection,foreclosure       NaN
# ...                                          ...       ...
# 125541  Loan modification,collection,foreclosure       NaN
# 125543  Loan modification,collection,foreclosure       NaN
# 125546  Application, originator, mortgage broker       NaN
# 125553  Loan modification,collection,foreclosure       NaN
# 125557  Application, originator, mortgage broker       NaN
# 125564  Loan modification,collection,foreclosure       NaN
# 125582              Settlement process and costs       NaN
# 125583  Loan servicing, payments, escrow account       NaN
# 125585  Application, originator, mortgage broker       NaN
# 125591              Settlement process and costs       NaN
# 125593  Loan modification,collection,foreclosure       NaN
# 125596  Loan servicing, payments, escrow account       NaN
# 125601              Settlement process and costs       NaN
# 125610            Credit decision / Underwriting       NaN
# 125616  Loan servicing, payments, escrow account       NaN
# 125618  Loan servicing, payments, escrow account       NaN
# 125619  Loan servicing, payments, escrow account       NaN
# 125620  Loan servicing, payments, escrow account       NaN
# 125621  Loan servicing, payments, escrow account       NaN
# 125622  Loan servicing, payments, escrow account       NaN
# 125623  Loan servicing, payments, escrow account       NaN
# 125632  Loan modification,collection,foreclosure       NaN
# 125634  Loan modification,collection,foreclosure       NaN
# 125636            Credit decision / Underwriting       NaN
# 125638  Loan modification,collection,foreclosure       NaN
# 125645  Loan servicing, payments, escrow account       NaN
# 125647  Loan servicing, payments, escrow account       NaN
# 125650  Loan servicing, payments, escrow account       NaN
# 125654  Application, originator, mortgage broker       NaN
# 125674  Loan servicing, payments, escrow account       NaN
#
#                              Consumer complaint narrative  \
# 13      i submitted a payment on XXXX XXXX 2015 for my...
# 19      Green Tree Financial somehow got XXXX Loan AFT...
# 22      To whom it may concern, To those that follow t...
# 25      My mortgage servicer, Wells Fargo, did not giv...
# 33      I paid off my mortgage with XXXX Mortgage Serv...
# 43      I was emailed that my online account had been ...
# 44      XXXX was submitted XX/XX/XXXX. At the time I s...
# 46      I am very disappointed that the CFPB did not h...
# 47      We fell behind in our payments back in 2014 fo...
# 48      I am a Successor - in -interest to a property ...
# 49      I am writing this letter because my mortgage a...
# 50      I had a mortgage with from XXXX of XXXX to XXX...
# 57      I made a payment on a {$69000.00} loan of $ XX...
# 58      I applied for a loan modification with Suntrus...
# 64      I was {$48.00} behind on our mortgage because ...
# 69      I have been trying to get an audit of my accou...
# 72      We had a Line of Credit with US Bank that was ...
# 81      Ocwen financial services claims simultaneously...
# 87      I had a mortgage with XXXX XXXX XXXX from XXXX...
# 88      I schedule my mortgage payment, using the mort...
# 101     My wife and I just went through 7 months of ap...
# 102     We have been working or a Short Sale for Selec...
# 104     I got behind in payments and worked with B of ...
# 107     Yesterday, I called my mortgage company, Ocwen...
# 121     Wells Fargo Mortgage began foreclosure action ...
# 122     Caliber Home loans has claimed to have made pa...
# 127     Our Mortgage was sold to Carrington Mortgage S...
# 131     I was part of the XXXX and received payment la...
# 139     We are a victim of Ocwen mortgage and their fr...
# 146     Please know I greatly appreciate your assistan...
# ...                                                   ...
# 125541  I am trying to get approved for a loan modific...
# 125543  I have asked Nationstar for assistance for a f...
# 125546  In XX/XX/2016, I received a solicitation from ...
# 125553  XX/XX/XXXX  Immediate concern: Stop  the forec...
# 125557  I was advised by XXXX XXXX at omni mortgage th...
# 125564  I am so devastated and so very disappointed wi...
# 125582  I contracted with USAA Federal Savings Bank to...
# 125583  Since the purchase of my house throughout the ...
# 125585  Over a period a six months, my XXXX mother app...
# 125591  RE : Complaint # XXXX Subject : XXXX / Foreclo...
# 125593  I am trying to get a principal reduction for m...
# 125596  US Bank has not released the lien and sent pro...
# 125601  I filed a rescission to my mortgage lender yea...
# 125610  Sales Manager keeps asking for same info repea...
# 125616  OWCEN made an error on my XXXX XXXX, 2016 and ...
# 125618  My loan was transferred to DiTech for servicin...
# 125619  I just refinanced my mortgage to a 15 yr fixed...
# 125620  Monday, XX/XX/XXXX " From : XXXX XXXX XXXX XXX...
# 125621  My mortgage company ( Ditech ) changed their c...
# 125622  Please see CFPB case # XXXX - I am submitting ...
# 125623  SLS purchased the servicing of my mortgage fro...
# 125632  We had a loan modification done with Nationsta...
# 125634  I have doubled my income in the last 2 months ...
# 125636  Nova financial, you are better off finding ano...
# 125638  I have been working with my lender for a loan ...
# 125645  I obtain a mortgage loan from Finance of Ameri...
# 125647  I have had my mortgage loan through Bank of Am...
# 125650  My original mortgage was with XXXX. In XXXX 20...
# 125654  XXXX XXXX has had complaints filed against him...
# 125674  On XX/XX/2016, I used online bill pay through ...
#
#                                   Company public response  \
# 13                                                    NaN
# 19                                                    NaN
# 22                                                    NaN
# 25                                                    NaN
# 33                                                    NaN
# 43                                                    NaN
# 44                                                    NaN
# 46                                                    NaN
# 47                                                    NaN
# 48                                                    NaN
# 49      Company believes it acted appropriately as aut...
# 50                                                    NaN
# 57                                                    NaN
# 58       Company chooses not to provide a public response
# 64                                                    NaN
# 69                                                    NaN
# 72       Company chooses not to provide a public response
# 81                                                    NaN
# 87                                                    NaN
# 88      Company believes it acted appropriately as aut...
# 101      Company chooses not to provide a public response
# 102     Company believes it acted appropriately as aut...
# 104      Company chooses not to provide a public response
# 107                                                   NaN
# 121                                                   NaN
# 122                                                   NaN
# 127                                                   NaN
# 131      Company chooses not to provide a public response
# 139                                                   NaN
# 146                                                   NaN
# ...                                                   ...
# 125541  Company has responded to the consumer and the ...
# 125543  Company believes it acted appropriately as aut...
# 125546  Company has responded to the consumer and the ...
# 125553   Company chooses not to provide a public response
# 125557                                                NaN
# 125564  Company believes it acted appropriately as aut...
# 125582  Company believes complaint is the result of an...
# 125583                                                NaN
# 125585  Company has responded to the consumer and the ...
# 125591  Company believes it acted appropriately as aut...
# 125593  Company has responded to the consumer and the ...
# 125596  Company has responded to the consumer and the ...
# 125601                                                NaN
# 125610  Company believes it acted appropriately as aut...
# 125616                                                NaN
# 125618  Company believes complaint represents an oppor...
# 125619                                                NaN
# 125620  Company has responded to the consumer and the ...
# 125621  Company believes complaint represents an oppor...
# 125622                                                NaN
# 125623  Company has responded to the consumer and the ...
# 125632                                                NaN
# 125634  Company has responded to the consumer and the ...
# 125636                                                NaN
# 125638                                                NaN
# 125645                                                NaN
# 125647  Company has responded to the consumer and the ...
# 125650                                                NaN
# 125654                                                NaN
# 125674  Company believes it acted appropriately as aut...
#
#                                         Company State ZIP code  \
# 13                                        Ocwen    IL    627XX
# 19                         Ditech Financial LLC    CA    926XX
# 22                               Morgan Stanley    CA    944XX
# 25                        Wells Fargo & Company    TX    770XX
# 33             HSBC North America Holdings Inc.    NY    141XX
# 43                        Wells Fargo & Company    MT    598XX
# 44        Rushmore Loan Management Services LLC    CA    956XX
# 46                CIT Bank National Association    NJ    080XX
# 47                          Nationstar Mortgage    VA    230XX
# 48                          Nationstar Mortgage    CA    925XX
# 49              Select Portfolio Servicing, Inc    NJ    080XX
# 50               Citizens Financial Group, Inc.    MA    021XX
# 57               Specialized Loan Servicing LLC    NJ    074XX
# 58                         SunTrust Banks, Inc.    CO    804XX
# 64                         Ditech Financial LLC    MA    020XX
# 69                                     Citibank    MD    207XX
# 72                                 U.S. Bancorp    CO    801XX
# 81                                        Ocwen    MA    017XX
# 87                          Nationstar Mortgage    TX    775XX
# 88                          Nationstar Mortgage    GA    300XX
# 101                                U.S. Bancorp    KS    664XX
# 102             Select Portfolio Servicing, Inc    FL    333XX
# 104                             Bank of America    CA    926XX
# 107                                       Ocwen    TX    770XX
# 121                       Wells Fargo & Company    AZ    853XX
# 122                     Caliber Home Loans, Inc    IN    463XX
# 127          Carrington Mortgage Holdings, LLC.    TX    755XX
# 131                             Bank of America    GA    309XX
# 139                                       Ocwen    KS    666XX
# 146                               Seterus, Inc.    FL    331XX
# ...                                         ...   ...      ...
# 125541                    Wells Fargo & Company    CA    945XX
# 125543                      Nationstar Mortgage    CA    920XX
# 125546                         Freedom Mortgage    SC    295XX
# 125553                    Wells Fargo & Company    CA    943XX
# 125557                OMNI MORTGAGE CORPORATION    NY    117XX
# 125564      North Dakota Housing Finance Agency    ND    586XX
# 125582                             USAA Savings    GA    303XX
# 125583                      Nationstar Mortgage    UT    846XX
# 125585                           BB&T Financial    TX    752XX
# 125591                 Shellpoint Partners, LLC    CA    949XX
# 125593                     SunTrust Banks, Inc.    GA    302XX
# 125596                             U.S. Bancorp    FL    329XX
# 125601                                    Ocwen    NJ    078XX
# 125610               Nations Lending Coporation    OH    430XX
# 125616                                    Ocwen    NY    102XX
# 125618                     Ditech Financial LLC    PA    190XX
# 125619                              Arvest Bank    IN    463XX
# 125620                     Round Point Mortgage    GA    300XX
# 125621                     Ditech Financial LLC    TX    750XX
# 125622                Dovenmuehle Mortgage Inc.    PA    191XX
# 125623           Specialized Loan Servicing LLC    NY    100XX
# 125632                      Nationstar Mortgage    TN    377XX
# 125634                          Bank of America    CA    900XX
# 125636  NOVA Financial & Investment Corporation    AZ    856XX
# 125638                  Caliber Home Loans, Inc    CA    925XX
# 125645          Finance of America Mortgage LLC    NJ    083XX
# 125647                          Bank of America    WI    531XX
# 125650                      Nationstar Mortgage    NY    103XX
# 125654    Integrity First Financial Group, Inc.    MO    631XX
# 125674                     Ditech Financial LLC    WI    535XX
#
#                   Tags Consumer consent provided? Date sent to company  \
# 13                 NaN           Consent provided            3/23/2015
# 19                 NaN           Consent provided            3/24/2015
# 22                 NaN           Consent provided            3/24/2015
# 25       Servicemember           Consent provided            3/24/2015
# 33                 NaN           Consent provided            3/24/2015
# 43                 NaN           Consent provided            3/24/2015
# 44      Older American           Consent provided            3/19/2015
# 46      Older American           Consent provided            3/19/2015
# 47                 NaN           Consent provided            3/19/2015
# 48                 NaN           Consent provided            3/19/2015
# 49                 NaN           Consent provided            3/19/2015
# 50                 NaN           Consent provided            3/19/2015
# 57                 NaN           Consent provided            3/19/2015
# 58                 NaN           Consent provided            3/24/2015
# 64                 NaN           Consent provided            3/24/2015
# 69                 NaN           Consent provided            3/19/2015
# 72                 NaN           Consent provided            3/27/2015
# 81                 NaN           Consent provided             4/1/2015
# 87                 NaN           Consent provided            3/19/2015
# 88                 NaN           Consent provided            3/24/2015
# 101                NaN           Consent provided            3/27/2015
# 102                NaN           Consent provided            3/27/2015
# 104                NaN           Consent provided            3/19/2015
# 107                NaN           Consent provided            3/24/2015
# 121                NaN           Consent provided            3/19/2015
# 122                NaN           Consent provided            3/25/2015
# 127                NaN           Consent provided            3/19/2015
# 131      Servicemember           Consent provided             4/6/2015
# 139      Servicemember           Consent provided            3/19/2015
# 146                NaN           Consent provided            3/28/2015
# ...                ...                        ...                  ...
# 125541             NaN           Consent provided            10/5/2016
# 125543  Older American           Consent provided           12/13/2016
# 125546  Older American           Consent provided           12/13/2016
# 125553             NaN           Consent provided            6/30/2015
# 125557             NaN           Consent provided           11/16/2016
# 125564             NaN           Consent provided           11/18/2016
# 125582             NaN           Consent provided           12/13/2016
# 125583             NaN           Consent provided            10/7/2016
# 125585             NaN           Consent provided           12/13/2016
# 125591  Older American           Consent provided           12/13/2016
# 125593   Servicemember           Consent provided           11/11/2016
# 125596             NaN           Consent provided            11/3/2016
# 125601             NaN           Consent provided            11/2/2016
# 125610             NaN           Consent provided           12/14/2016
# 125616             NaN           Consent provided           11/19/2016
# 125618             NaN           Consent provided            9/23/2016
# 125619             NaN           Consent provided           11/18/2016
# 125620             NaN           Consent provided           10/14/2016
# 125621  Older American           Consent provided            11/2/2016
# 125622             NaN           Consent provided            11/4/2016
# 125623  Older American           Consent provided           12/13/2016
# 125632             NaN           Consent provided           11/18/2016
# 125634             NaN           Consent provided           10/26/2016
# 125636   Servicemember           Consent provided            11/5/2016
# 125638             NaN           Consent provided           11/18/2016
# 125645             NaN           Consent provided           11/18/2016
# 125647             NaN           Consent provided            9/20/2016
# 125650             NaN           Consent provided           10/27/2016
# 125654             NaN           Consent provided           11/18/2016
# 125674             NaN           Consent provided           12/13/2016
#
#            Company response to consumer Timely response? Consumer disputed?  \
# 13              Closed with explanation              Yes                 No
# 19      Closed with non-monetary relief              Yes                 No
# 22              Closed with explanation              Yes                 No
# 25              Closed with explanation              Yes                 No
# 33              Closed with explanation              Yes                 No
# 43      Closed with non-monetary relief              Yes                 No
# 44              Closed with explanation              Yes                Yes
# 46              Closed with explanation              Yes                 No
# 47              Closed with explanation              Yes                 No
# 48              Closed with explanation              Yes                 No
# 49              Closed with explanation              Yes                 No
# 50              Closed with explanation              Yes                Yes
# 57              Closed with explanation              Yes                Yes
# 58      Closed with non-monetary relief              Yes                 No
# 64      Closed with non-monetary relief              Yes                Yes
# 69              Closed with explanation              Yes                Yes
# 72              Closed with explanation              Yes                 No
# 81              Closed with explanation              Yes                 No
# 87              Closed with explanation              Yes                 No
# 88              Closed with explanation              Yes                Yes
# 101             Closed with explanation              Yes                Yes
# 102             Closed with explanation              Yes                 No
# 104         Closed with monetary relief              Yes                 No
# 107             Closed with explanation              Yes                 No
# 121             Closed with explanation              Yes                Yes
# 122             Closed with explanation              Yes                 No
# 127             Closed with explanation              Yes                 No
# 131             Closed with explanation              Yes                Yes
# 139             Closed with explanation              Yes                Yes
# 146             Closed with explanation              Yes                Yes
# ...                                 ...              ...                ...
# 125541          Closed with explanation              Yes                 No
# 125543          Closed with explanation              Yes                NaN
# 125546          Closed with explanation              Yes                NaN
# 125553          Closed with explanation              Yes                 No
# 125557          Closed with explanation               No                NaN
# 125564          Closed with explanation              Yes                 No
# 125582      Closed with monetary relief              Yes                NaN
# 125583          Closed with explanation              Yes                 No
# 125585          Closed with explanation              Yes                NaN
# 125591          Closed with explanation              Yes                Yes
# 125593          Closed with explanation              Yes                 No
# 125596          Closed with explanation              Yes                 No
# 125601          Closed with explanation              Yes                 No
# 125610          Closed with explanation              Yes                NaN
# 125616          Closed with explanation              Yes                Yes
# 125618          Closed with explanation              Yes                 No
# 125619          Closed with explanation              Yes                NaN
# 125620          Closed with explanation              Yes                 No
# 125621          Closed with explanation              Yes                 No
# 125622          Closed with explanation              Yes                 No
# 125623          Closed with explanation              Yes                NaN
# 125632                           Closed              Yes                NaN
# 125634          Closed with explanation              Yes                 No
# 125636          Closed with explanation              Yes                 No
# 125638                           Closed              Yes                NaN
# 125645          Closed with explanation              Yes                NaN
# 125647      Closed with monetary relief              Yes                 No
# 125650          Closed with explanation              Yes                 No
# 125654          Closed with explanation               No                NaN
# 125674          Closed with explanation              Yes                NaN
#
#         Complaint ID  Consumer Claim  Company Offer  Amount Received
# 13           1296831       101340.54      182761.24        122579.47
# 19           1297594       103381.81      186432.77        110905.24
# 22           1297626       219860.35      153908.22         99746.42
# 25           1297644       153377.06      169317.86         79792.59
# 33           1299207       105940.81      123409.96         89578.55
# 43           1297874       234463.04      133847.95        104833.17
# 44           1292137       177586.11       57294.34         89278.77
# 46           1290543        71574.50       24275.87         65055.48
# 47           1292139        61228.78       80961.10         22089.39
# 48           1290545       180004.43      214540.82         29346.45
# 49           1292065       136855.25       -7012.71         70034.66
# 50           1290564       110769.16       85293.98        140950.99
# 57           1290644       171647.18      167269.02        115595.66
# 58           1298042        91360.36      161713.50         17758.65
# 64           1298116       186816.79      228400.77        134987.03
# 69           1290765       174171.64       79753.02        101711.41
# 72           1304648       183467.48      130950.91        141618.46
# 81           1304057        94292.76      136124.02        123227.27
# 87           1290871       213279.65      157675.58         79534.17
# 88           1298322       109029.12       74100.13         40478.75
# 101          1304971       182034.47      114693.36         67510.76
# 102          1304692       150718.63      165691.38        136517.37
# 104          1291084       127616.28       66064.08         77037.93
# 107          1298656       150701.05      167926.46         53600.10
# 121          1291277       166114.09       81243.71         26314.16
# 122          1298770       198868.56      127222.11        104428.20
# 127          1292613       249757.98      136786.81         71294.46
# 131          1305325       169979.86       91967.15         12702.47
# 139          1292075       200977.97      208273.54        140895.90
# 146          1305831       192775.55      176085.10         46461.77
# ...              ...             ...            ...              ...
# 125541       2141468       121095.06        7620.71         -1882.12
# 125543       2247658       202258.79      123664.33         92247.20
# 125546       2248476       141880.00      148011.31        -15018.41
# 125553       1444123       152880.49      102193.95        173177.07
# 125557       2209300       147430.37      114010.33         47345.30
# 125564       2180679       177723.48      216986.74        125397.78
# 125582       2247493       114277.49      158659.18         85375.31
# 125583       2152061       129114.44       98844.55         56791.42
# 125585       2244513        65426.99      140152.91         99335.38
# 125591       2243820       169197.05       66552.62         85769.96
# 125593       2205208       237211.09       47003.87        190013.21
# 125596       2192518        97710.88       64392.79         74558.88
# 125601       2169166       140341.51      138125.27         83521.07
# 125610       2248733       117591.02      103684.51         43800.98
# 125616       2214614       142775.89      191873.76        101699.37
# 125618       2128559       182275.93       67170.52         92324.06
# 125619       2214834       170016.45       65751.65          1991.28
# 125620       2153211        61244.98       99590.82         99820.75
# 125621       2186239       194123.95       63202.10         47589.77
# 125622       2191249       143222.59       16049.53        112755.79
# 125623       2248373       161307.06      119452.98         56043.00
# 125632       2215986       134966.28      163581.65         59377.15
# 125634       2177009        85949.83      165111.24         84770.01
# 125636       2197004       236151.02      119853.39        123155.57
# 125638       2216156       126366.03       67134.38        133643.76
# 125645       2215655       185077.71       92015.61         69618.41
# 125647       2122648       207892.82      180364.18         35887.38
# 125650       2182081       236687.68      221160.59         64958.93
# 125654       2215900        74632.68       57102.99        182860.61
# 125674       2247724       136798.52      114342.28        106343.36
#
# [26810 rows x 20 columns]

# %%
# 12. Use your df's loc[] attribute to get specific rows and columns using loc[NUMBER, NUMBER] notation.

df.loc[22, 'Product']
# Out:
# 'Mortgage'

# %%
# 13. User your dataframe's set_index() method to use a ['Product', 'Sub-product']. Then sort_index().

df.set_index(['Product', 'Sub-product']).sort_index().head(5)
# Out:
#                                                 Date received  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)     3/24/2015
#          Conventional adjustable mortgage (ARM)     3/28/2015
#          Conventional adjustable mortgage (ARM)     3/28/2015
#          Conventional adjustable mortgage (ARM)     3/28/2015
#          Conventional adjustable mortgage (ARM)     3/28/2015
#
#                                                                                     Issue  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)  Loan servicing, payments, escrow account
#          Conventional adjustable mortgage (ARM)  Loan modification,collection,foreclosure
#          Conventional adjustable mortgage (ARM)  Loan servicing, payments, escrow account
#          Conventional adjustable mortgage (ARM)  Loan modification,collection,foreclosure
#          Conventional adjustable mortgage (ARM)  Loan modification,collection,foreclosure
#
#                                                 Sub-issue  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)       NaN
#          Conventional adjustable mortgage (ARM)       NaN
#          Conventional adjustable mortgage (ARM)       NaN
#          Conventional adjustable mortgage (ARM)       NaN
#          Conventional adjustable mortgage (ARM)       NaN
#
#                                                                       Consumer complaint narrative  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)  I schedule my mortgage payment, using the mort...
#          Conventional adjustable mortgage (ARM)  Please know I greatly appreciate your assistan...
#          Conventional adjustable mortgage (ARM)  This complaint relates to my mortgage, service...
#          Conventional adjustable mortgage (ARM)  I first started with country wide and was in t...
#          Conventional adjustable mortgage (ARM)  I had a 5 year loan modification with XXXX XXX...
#
#                                                                            Company public response  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)  Company believes it acted appropriately as aut...
#          Conventional adjustable mortgage (ARM)                                                NaN
#          Conventional adjustable mortgage (ARM)                                                NaN
#          Conventional adjustable mortgage (ARM)                                                NaN
#          Conventional adjustable mortgage (ARM)                                                NaN
#
#                                                               Company State  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)   Nationstar Mortgage    GA
#          Conventional adjustable mortgage (ARM)         Seterus, Inc.    FL
#          Conventional adjustable mortgage (ARM)  JPMorgan Chase & Co.    GA
#          Conventional adjustable mortgage (ARM)   Nationstar Mortgage    CA
#          Conventional adjustable mortgage (ARM)   Nationstar Mortgage    CA
#
#                                                 ZIP code Tags  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)    300XX  NaN
#          Conventional adjustable mortgage (ARM)    331XX  NaN
#          Conventional adjustable mortgage (ARM)    303XX  NaN
#          Conventional adjustable mortgage (ARM)    956XX  NaN
#          Conventional adjustable mortgage (ARM)    925XX  NaN
#
#                                                 Consumer consent provided?  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)           Consent provided
#          Conventional adjustable mortgage (ARM)           Consent provided
#          Conventional adjustable mortgage (ARM)           Consent provided
#          Conventional adjustable mortgage (ARM)           Consent provided
#          Conventional adjustable mortgage (ARM)           Consent provided
#
#                                                 Date sent to company  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)            3/24/2015
#          Conventional adjustable mortgage (ARM)            3/28/2015
#          Conventional adjustable mortgage (ARM)            3/28/2015
#          Conventional adjustable mortgage (ARM)            3/28/2015
#          Conventional adjustable mortgage (ARM)            3/28/2015
#
#                                                 Company response to consumer  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)      Closed with explanation
#          Conventional adjustable mortgage (ARM)      Closed with explanation
#          Conventional adjustable mortgage (ARM)      Closed with explanation
#          Conventional adjustable mortgage (ARM)      Closed with explanation
#          Conventional adjustable mortgage (ARM)      Closed with explanation
#
#                                                 Timely response?  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)              Yes
#          Conventional adjustable mortgage (ARM)              Yes
#          Conventional adjustable mortgage (ARM)              Yes
#          Conventional adjustable mortgage (ARM)              Yes
#          Conventional adjustable mortgage (ARM)              Yes
#
#                                                 Consumer disputed?  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)                Yes
#          Conventional adjustable mortgage (ARM)                Yes
#          Conventional adjustable mortgage (ARM)                Yes
#          Conventional adjustable mortgage (ARM)                Yes
#          Conventional adjustable mortgage (ARM)                 No
#
#                                                  Complaint ID  Consumer Claim  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)       1298322       109029.12
#          Conventional adjustable mortgage (ARM)       1305831       192775.55
#          Conventional adjustable mortgage (ARM)       1305793       184625.19
#          Conventional adjustable mortgage (ARM)       1305965       111894.32
#          Conventional adjustable mortgage (ARM)       1306024       203858.68
#
#                                                  Company Offer  \
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)       74100.13
#          Conventional adjustable mortgage (ARM)      176085.10
#          Conventional adjustable mortgage (ARM)        1226.74
#          Conventional adjustable mortgage (ARM)      115955.23
#          Conventional adjustable mortgage (ARM)      138588.95
#
#                                                  Amount Received
# Product  Sub-product
# Mortgage Conventional adjustable mortgage (ARM)         40478.75
#          Conventional adjustable mortgage (ARM)         46461.77
#          Conventional adjustable mortgage (ARM)         10242.66
#          Conventional adjustable mortgage (ARM)         81744.55
#          Conventional adjustable mortgage (ARM)         32298.28

# %%
# 14. Use loc[] with a number like 1000000, and add a row to the dataframe.

df.loc[10000000] = 'WUT'
df.tail(2)
# Out:
#          Date received   Product                  Sub-product  \
# 125674      12/13/2016  Mortgage  Conventional fixed mortgage
# 10000000           WUT       WUT                          WUT
#
#                                              Issue Sub-issue  \
# 125674    Loan servicing, payments, escrow account       NaN
# 10000000                                       WUT       WUT
#
#                                Consumer complaint narrative  \
# 125674    On XX/XX/2016, I used online bill pay through ...
# 10000000                                                WUT
#
#                                     Company public response  \
# 125674    Company believes it acted appropriately as aut...
# 10000000                                                WUT
#
#                        Company State ZIP code Tags Consumer consent provided?  \
# 125674    Ditech Financial LLC    WI    535XX  NaN           Consent provided
# 10000000                   WUT   WUT      WUT  WUT                        WUT
#
#          Date sent to company Company response to consumer Timely response?  \
# 125674             12/13/2016      Closed with explanation              Yes
# 10000000                  WUT                          WUT              WUT
#
#          Consumer disputed? Complaint ID Consumer Claim Company Offer  \
# 125674                  NaN      2247724         136799        114342
# 10000000                WUT          WUT            WUT           WUT
#
#          Amount Received
# 125674            106343
# 10000000             WUT

# %%
# 15. Add a column to the dataframe named "Custom" that copies the values in another column.

df['Custom'] = df['Consumer consent provided?']
df
# Out:
#          Date received   Product                             Sub-product  \
# 13           3/23/2015  Mortgage                          Other mortgage
# 19           3/24/2015  Mortgage                          Other mortgage
# 22           3/24/2015  Mortgage             Conventional fixed mortgage
# 25           3/24/2015  Mortgage                             VA mortgage
# 33           3/24/2015  Mortgage             Conventional fixed mortgage
# 43           3/24/2015  Mortgage             Conventional fixed mortgage
# 44           3/19/2015  Mortgage             Conventional fixed mortgage
# 46           3/19/2015  Mortgage                        Reverse mortgage
# 47           3/19/2015  Mortgage             Conventional fixed mortgage
# 48           3/19/2015  Mortgage             Conventional fixed mortgage
# 49           3/19/2015  Mortgage             Conventional fixed mortgage
# 50           3/19/2015  Mortgage                            FHA mortgage
# 57           3/19/2015  Mortgage      Home equity loan or line of credit
# 58           3/24/2015  Mortgage                          Other mortgage
# 64           3/24/2015  Mortgage             Conventional fixed mortgage
# 69           3/19/2015  Mortgage             Conventional fixed mortgage
# 72           3/27/2015  Mortgage      Home equity loan or line of credit
# 81           3/27/2015  Mortgage                          Other mortgage
# 87           3/19/2015  Mortgage             Conventional fixed mortgage
# 88           3/24/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 101          3/27/2015  Mortgage             Conventional fixed mortgage
# 102          3/27/2015  Mortgage             Conventional fixed mortgage
# 104          3/19/2015  Mortgage             Conventional fixed mortgage
# 107          3/24/2015  Mortgage                            FHA mortgage
# 121          3/19/2015  Mortgage                            FHA mortgage
# 122          3/24/2015  Mortgage             Conventional fixed mortgage
# 127          3/19/2015  Mortgage                            FHA mortgage
# 131          3/27/2015  Mortgage                            FHA mortgage
# 139          3/19/2015  Mortgage             Conventional fixed mortgage
# 146          3/28/2015  Mortgage  Conventional adjustable mortgage (ARM)
# ...                ...       ...                                     ...
# 125543      12/13/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125546      12/13/2016  Mortgage                             VA mortgage
# 125553       6/30/2015  Mortgage  Conventional adjustable mortgage (ARM)
# 125557      11/16/2016  Mortgage             Conventional fixed mortgage
# 125564      10/26/2016  Mortgage             Conventional fixed mortgage
# 125582      12/13/2016  Mortgage                             VA mortgage
# 125583       10/7/2016  Mortgage             Conventional fixed mortgage
# 125585      12/10/2016  Mortgage      Home equity loan or line of credit
# 125591       12/9/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125593      11/11/2016  Mortgage                            FHA mortgage
# 125596       11/3/2016  Mortgage                             VA mortgage
# 125601      10/19/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125610      12/13/2016  Mortgage                            FHA mortgage
# 125616      11/19/2016  Mortgage      Home equity loan or line of credit
# 125618       9/23/2016  Mortgage                            FHA mortgage
# 125619      11/18/2016  Mortgage             Conventional fixed mortgage
# 125620      10/10/2016  Mortgage                             VA mortgage
# 125621      10/31/2016  Mortgage             Conventional fixed mortgage
# 125622       11/2/2016  Mortgage                            FHA mortgage
# 125623      12/13/2016  Mortgage             Conventional fixed mortgage
# 125632      11/18/2016  Mortgage             Conventional fixed mortgage
# 125634      10/26/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125636       11/5/2016  Mortgage             Conventional fixed mortgage
# 125638      11/18/2016  Mortgage  Conventional adjustable mortgage (ARM)
# 125645      11/18/2016  Mortgage                            FHA mortgage
# 125647       9/20/2016  Mortgage             Conventional fixed mortgage
# 125650      10/27/2016  Mortgage             Conventional fixed mortgage
# 125654      11/18/2016  Mortgage                          Other mortgage
# 125674      12/13/2016  Mortgage             Conventional fixed mortgage
# 10000000           WUT       WUT                                     WUT
#
#                                              Issue Sub-issue  \
# 13        Loan servicing, payments, escrow account       NaN
# 19        Loan servicing, payments, escrow account       NaN
# 22                  Credit decision / Underwriting       NaN
# 25        Loan servicing, payments, escrow account       NaN
# 33        Loan servicing, payments, escrow account       NaN
# 43        Loan servicing, payments, escrow account       NaN
# 44                  Credit decision / Underwriting       NaN
# 46        Application, originator, mortgage broker       NaN
# 47        Loan servicing, payments, escrow account       NaN
# 48        Loan servicing, payments, escrow account       NaN
# 49        Loan servicing, payments, escrow account       NaN
# 50        Application, originator, mortgage broker       NaN
# 57        Loan servicing, payments, escrow account       NaN
# 58                    Settlement process and costs       NaN
# 64        Loan servicing, payments, escrow account       NaN
# 69        Loan modification,collection,foreclosure       NaN
# 72        Loan modification,collection,foreclosure       NaN
# 81        Loan servicing, payments, escrow account       NaN
# 87        Loan servicing, payments, escrow account       NaN
# 88        Loan servicing, payments, escrow account       NaN
# 101       Loan modification,collection,foreclosure       NaN
# 102       Loan modification,collection,foreclosure       NaN
# 104                   Settlement process and costs       NaN
# 107       Loan servicing, payments, escrow account       NaN
# 121       Loan servicing, payments, escrow account       NaN
# 122       Loan servicing, payments, escrow account       NaN
# 127       Loan servicing, payments, escrow account       NaN
# 131       Loan modification,collection,foreclosure       NaN
# 139       Loan modification,collection,foreclosure       NaN
# 146       Loan modification,collection,foreclosure       NaN
# ...                                            ...       ...
# 125543    Loan modification,collection,foreclosure       NaN
# 125546    Application, originator, mortgage broker       NaN
# 125553    Loan modification,collection,foreclosure       NaN
# 125557    Application, originator, mortgage broker       NaN
# 125564    Loan modification,collection,foreclosure       NaN
# 125582                Settlement process and costs       NaN
# 125583    Loan servicing, payments, escrow account       NaN
# 125585    Application, originator, mortgage broker       NaN
# 125591                Settlement process and costs       NaN
# 125593    Loan modification,collection,foreclosure       NaN
# 125596    Loan servicing, payments, escrow account       NaN
# 125601                Settlement process and costs       NaN
# 125610              Credit decision / Underwriting       NaN
# 125616    Loan servicing, payments, escrow account       NaN
# 125618    Loan servicing, payments, escrow account       NaN
# 125619    Loan servicing, payments, escrow account       NaN
# 125620    Loan servicing, payments, escrow account       NaN
# 125621    Loan servicing, payments, escrow account       NaN
# 125622    Loan servicing, payments, escrow account       NaN
# 125623    Loan servicing, payments, escrow account       NaN
# 125632    Loan modification,collection,foreclosure       NaN
# 125634    Loan modification,collection,foreclosure       NaN
# 125636              Credit decision / Underwriting       NaN
# 125638    Loan modification,collection,foreclosure       NaN
# 125645    Loan servicing, payments, escrow account       NaN
# 125647    Loan servicing, payments, escrow account       NaN
# 125650    Loan servicing, payments, escrow account       NaN
# 125654    Application, originator, mortgage broker       NaN
# 125674    Loan servicing, payments, escrow account       NaN
# 10000000                                       WUT       WUT
#
#                                Consumer complaint narrative  \
# 13        i submitted a payment on XXXX XXXX 2015 for my...
# 19        Green Tree Financial somehow got XXXX Loan AFT...
# 22        To whom it may concern, To those that follow t...
# 25        My mortgage servicer, Wells Fargo, did not giv...
# 33        I paid off my mortgage with XXXX Mortgage Serv...
# 43        I was emailed that my online account had been ...
# 44        XXXX was submitted XX/XX/XXXX. At the time I s...
# 46        I am very disappointed that the CFPB did not h...
# 47        We fell behind in our payments back in 2014 fo...
# 48        I am a Successor - in -interest to a property ...
# 49        I am writing this letter because my mortgage a...
# 50        I had a mortgage with from XXXX of XXXX to XXX...
# 57        I made a payment on a {$69000.00} loan of $ XX...
# 58        I applied for a loan modification with Suntrus...
# 64        I was {$48.00} behind on our mortgage because ...
# 69        I have been trying to get an audit of my accou...
# 72        We had a Line of Credit with US Bank that was ...
# 81        Ocwen financial services claims simultaneously...
# 87        I had a mortgage with XXXX XXXX XXXX from XXXX...
# 88        I schedule my mortgage payment, using the mort...
# 101       My wife and I just went through 7 months of ap...
# 102       We have been working or a Short Sale for Selec...
# 104       I got behind in payments and worked with B of ...
# 107       Yesterday, I called my mortgage company, Ocwen...
# 121       Wells Fargo Mortgage began foreclosure action ...
# 122       Caliber Home loans has claimed to have made pa...
# 127       Our Mortgage was sold to Carrington Mortgage S...
# 131       I was part of the XXXX and received payment la...
# 139       We are a victim of Ocwen mortgage and their fr...
# 146       Please know I greatly appreciate your assistan...
# ...                                                     ...
# 125543    I have asked Nationstar for assistance for a f...
# 125546    In XX/XX/2016, I received a solicitation from ...
# 125553    XX/XX/XXXX  Immediate concern: Stop  the forec...
# 125557    I was advised by XXXX XXXX at omni mortgage th...
# 125564    I am so devastated and so very disappointed wi...
# 125582    I contracted with USAA Federal Savings Bank to...
# 125583    Since the purchase of my house throughout the ...
# 125585    Over a period a six months, my XXXX mother app...
# 125591    RE : Complaint # XXXX Subject : XXXX / Foreclo...
# 125593    I am trying to get a principal reduction for m...
# 125596    US Bank has not released the lien and sent pro...
# 125601    I filed a rescission to my mortgage lender yea...
# 125610    Sales Manager keeps asking for same info repea...
# 125616    OWCEN made an error on my XXXX XXXX, 2016 and ...
# 125618    My loan was transferred to DiTech for servicin...
# 125619    I just refinanced my mortgage to a 15 yr fixed...
# 125620    Monday, XX/XX/XXXX " From : XXXX XXXX XXXX XXX...
# 125621    My mortgage company ( Ditech ) changed their c...
# 125622    Please see CFPB case # XXXX - I am submitting ...
# 125623    SLS purchased the servicing of my mortgage fro...
# 125632    We had a loan modification done with Nationsta...
# 125634    I have doubled my income in the last 2 months ...
# 125636    Nova financial, you are better off finding ano...
# 125638    I have been working with my lender for a loan ...
# 125645    I obtain a mortgage loan from Finance of Ameri...
# 125647    I have had my mortgage loan through Bank of Am...
# 125650    My original mortgage was with XXXX. In XXXX 20...
# 125654    XXXX XXXX has had complaints filed against him...
# 125674    On XX/XX/2016, I used online bill pay through ...
# 10000000                                                WUT
#
#                                     Company public response  \
# 13                                                      NaN
# 19                                                      NaN
# 22                                                      NaN
# 25                                                      NaN
# 33                                                      NaN
# 43                                                      NaN
# 44                                                      NaN
# 46                                                      NaN
# 47                                                      NaN
# 48                                                      NaN
# 49        Company believes it acted appropriately as aut...
# 50                                                      NaN
# 57                                                      NaN
# 58         Company chooses not to provide a public response
# 64                                                      NaN
# 69                                                      NaN
# 72         Company chooses not to provide a public response
# 81                                                      NaN
# 87                                                      NaN
# 88        Company believes it acted appropriately as aut...
# 101        Company chooses not to provide a public response
# 102       Company believes it acted appropriately as aut...
# 104        Company chooses not to provide a public response
# 107                                                     NaN
# 121                                                     NaN
# 122                                                     NaN
# 127                                                     NaN
# 131        Company chooses not to provide a public response
# 139                                                     NaN
# 146                                                     NaN
# ...                                                     ...
# 125543    Company believes it acted appropriately as aut...
# 125546    Company has responded to the consumer and the ...
# 125553     Company chooses not to provide a public response
# 125557                                                  NaN
# 125564    Company believes it acted appropriately as aut...
# 125582    Company believes complaint is the result of an...
# 125583                                                  NaN
# 125585    Company has responded to the consumer and the ...
# 125591    Company believes it acted appropriately as aut...
# 125593    Company has responded to the consumer and the ...
# 125596    Company has responded to the consumer and the ...
# 125601                                                  NaN
# 125610    Company believes it acted appropriately as aut...
# 125616                                                  NaN
# 125618    Company believes complaint represents an oppor...
# 125619                                                  NaN
# 125620    Company has responded to the consumer and the ...
# 125621    Company believes complaint represents an oppor...
# 125622                                                  NaN
# 125623    Company has responded to the consumer and the ...
# 125632                                                  NaN
# 125634    Company has responded to the consumer and the ...
# 125636                                                  NaN
# 125638                                                  NaN
# 125645                                                  NaN
# 125647    Company has responded to the consumer and the ...
# 125650                                                  NaN
# 125654                                                  NaN
# 125674    Company believes it acted appropriately as aut...
# 10000000                                                WUT
#
#                                           Company State ZIP code  \
# 13                                          Ocwen    IL    627XX
# 19                           Ditech Financial LLC    CA    926XX
# 22                                 Morgan Stanley    CA    944XX
# 25                          Wells Fargo & Company    TX    770XX
# 33               HSBC North America Holdings Inc.    NY    141XX
# 43                          Wells Fargo & Company    MT    598XX
# 44          Rushmore Loan Management Services LLC    CA    956XX
# 46                  CIT Bank National Association    NJ    080XX
# 47                            Nationstar Mortgage    VA    230XX
# 48                            Nationstar Mortgage    CA    925XX
# 49                Select Portfolio Servicing, Inc    NJ    080XX
# 50                 Citizens Financial Group, Inc.    MA    021XX
# 57                 Specialized Loan Servicing LLC    NJ    074XX
# 58                           SunTrust Banks, Inc.    CO    804XX
# 64                           Ditech Financial LLC    MA    020XX
# 69                                       Citibank    MD    207XX
# 72                                   U.S. Bancorp    CO    801XX
# 81                                          Ocwen    MA    017XX
# 87                            Nationstar Mortgage    TX    775XX
# 88                            Nationstar Mortgage    GA    300XX
# 101                                  U.S. Bancorp    KS    664XX
# 102               Select Portfolio Servicing, Inc    FL    333XX
# 104                               Bank of America    CA    926XX
# 107                                         Ocwen    TX    770XX
# 121                         Wells Fargo & Company    AZ    853XX
# 122                       Caliber Home Loans, Inc    IN    463XX
# 127            Carrington Mortgage Holdings, LLC.    TX    755XX
# 131                               Bank of America    GA    309XX
# 139                                         Ocwen    KS    666XX
# 146                                 Seterus, Inc.    FL    331XX
# ...                                           ...   ...      ...
# 125543                        Nationstar Mortgage    CA    920XX
# 125546                           Freedom Mortgage    SC    295XX
# 125553                      Wells Fargo & Company    CA    943XX
# 125557                  OMNI MORTGAGE CORPORATION    NY    117XX
# 125564        North Dakota Housing Finance Agency    ND    586XX
# 125582                               USAA Savings    GA    303XX
# 125583                        Nationstar Mortgage    UT    846XX
# 125585                             BB&T Financial    TX    752XX
# 125591                   Shellpoint Partners, LLC    CA    949XX
# 125593                       SunTrust Banks, Inc.    GA    302XX
# 125596                               U.S. Bancorp    FL    329XX
# 125601                                      Ocwen    NJ    078XX
# 125610                 Nations Lending Coporation    OH    430XX
# 125616                                      Ocwen    NY    102XX
# 125618                       Ditech Financial LLC    PA    190XX
# 125619                                Arvest Bank    IN    463XX
# 125620                       Round Point Mortgage    GA    300XX
# 125621                       Ditech Financial LLC    TX    750XX
# 125622                  Dovenmuehle Mortgage Inc.    PA    191XX
# 125623             Specialized Loan Servicing LLC    NY    100XX
# 125632                        Nationstar Mortgage    TN    377XX
# 125634                            Bank of America    CA    900XX
# 125636    NOVA Financial & Investment Corporation    AZ    856XX
# 125638                    Caliber Home Loans, Inc    CA    925XX
# 125645            Finance of America Mortgage LLC    NJ    083XX
# 125647                            Bank of America    WI    531XX
# 125650                        Nationstar Mortgage    NY    103XX
# 125654      Integrity First Financial Group, Inc.    MO    631XX
# 125674                       Ditech Financial LLC    WI    535XX
# 10000000                                      WUT   WUT      WUT
#
#                 ...        Consumer consent provided? Date sent to company  \
# 13              ...                  Consent provided            3/23/2015
# 19              ...                  Consent provided            3/24/2015
# 22              ...                  Consent provided            3/24/2015
# 25              ...                  Consent provided            3/24/2015
# 33              ...                  Consent provided            3/24/2015
# 43              ...                  Consent provided            3/24/2015
# 44              ...                  Consent provided            3/19/2015
# 46              ...                  Consent provided            3/19/2015
# 47              ...                  Consent provided            3/19/2015
# 48              ...                  Consent provided            3/19/2015
# 49              ...                  Consent provided            3/19/2015
# 50              ...                  Consent provided            3/19/2015
# 57              ...                  Consent provided            3/19/2015
# 58              ...                  Consent provided            3/24/2015
# 64              ...                  Consent provided            3/24/2015
# 69              ...                  Consent provided            3/19/2015
# 72              ...                  Consent provided            3/27/2015
# 81              ...                  Consent provided             4/1/2015
# 87              ...                  Consent provided            3/19/2015
# 88              ...                  Consent provided            3/24/2015
# 101             ...                  Consent provided            3/27/2015
# 102             ...                  Consent provided            3/27/2015
# 104             ...                  Consent provided            3/19/2015
# 107             ...                  Consent provided            3/24/2015
# 121             ...                  Consent provided            3/19/2015
# 122             ...                  Consent provided            3/25/2015
# 127             ...                  Consent provided            3/19/2015
# 131             ...                  Consent provided             4/6/2015
# 139             ...                  Consent provided            3/19/2015
# 146             ...                  Consent provided            3/28/2015
# ...             ...                               ...                  ...
# 125543          ...                  Consent provided           12/13/2016
# 125546          ...                  Consent provided           12/13/2016
# 125553          ...                  Consent provided            6/30/2015
# 125557          ...                  Consent provided           11/16/2016
# 125564          ...                  Consent provided           11/18/2016
# 125582          ...                  Consent provided           12/13/2016
# 125583          ...                  Consent provided            10/7/2016
# 125585          ...                  Consent provided           12/13/2016
# 125591          ...                  Consent provided           12/13/2016
# 125593          ...                  Consent provided           11/11/2016
# 125596          ...                  Consent provided            11/3/2016
# 125601          ...                  Consent provided            11/2/2016
# 125610          ...                  Consent provided           12/14/2016
# 125616          ...                  Consent provided           11/19/2016
# 125618          ...                  Consent provided            9/23/2016
# 125619          ...                  Consent provided           11/18/2016
# 125620          ...                  Consent provided           10/14/2016
# 125621          ...                  Consent provided            11/2/2016
# 125622          ...                  Consent provided            11/4/2016
# 125623          ...                  Consent provided           12/13/2016
# 125632          ...                  Consent provided           11/18/2016
# 125634          ...                  Consent provided           10/26/2016
# 125636          ...                  Consent provided            11/5/2016
# 125638          ...                  Consent provided           11/18/2016
# 125645          ...                  Consent provided           11/18/2016
# 125647          ...                  Consent provided            9/20/2016
# 125650          ...                  Consent provided           10/27/2016
# 125654          ...                  Consent provided           11/18/2016
# 125674          ...                  Consent provided           12/13/2016
# 10000000        ...                               WUT                  WUT
#
#              Company response to consumer Timely response? Consumer disputed?  \
# 13                Closed with explanation              Yes                 No
# 19        Closed with non-monetary relief              Yes                 No
# 22                Closed with explanation              Yes                 No
# 25                Closed with explanation              Yes                 No
# 33                Closed with explanation              Yes                 No
# 43        Closed with non-monetary relief              Yes                 No
# 44                Closed with explanation              Yes                Yes
# 46                Closed with explanation              Yes                 No
# 47                Closed with explanation              Yes                 No
# 48                Closed with explanation              Yes                 No
# 49                Closed with explanation              Yes                 No
# 50                Closed with explanation              Yes                Yes
# 57                Closed with explanation              Yes                Yes
# 58        Closed with non-monetary relief              Yes                 No
# 64        Closed with non-monetary relief              Yes                Yes
# 69                Closed with explanation              Yes                Yes
# 72                Closed with explanation              Yes                 No
# 81                Closed with explanation              Yes                 No
# 87                Closed with explanation              Yes                 No
# 88                Closed with explanation              Yes                Yes
# 101               Closed with explanation              Yes                Yes
# 102               Closed with explanation              Yes                 No
# 104           Closed with monetary relief              Yes                 No
# 107               Closed with explanation              Yes                 No
# 121               Closed with explanation              Yes                Yes
# 122               Closed with explanation              Yes                 No
# 127               Closed with explanation              Yes                 No
# 131               Closed with explanation              Yes                Yes
# 139               Closed with explanation              Yes                Yes
# 146               Closed with explanation              Yes                Yes
# ...                                   ...              ...                ...
# 125543            Closed with explanation              Yes                NaN
# 125546            Closed with explanation              Yes                NaN
# 125553            Closed with explanation              Yes                 No
# 125557            Closed with explanation               No                NaN
# 125564            Closed with explanation              Yes                 No
# 125582        Closed with monetary relief              Yes                NaN
# 125583            Closed with explanation              Yes                 No
# 125585            Closed with explanation              Yes                NaN
# 125591            Closed with explanation              Yes                Yes
# 125593            Closed with explanation              Yes                 No
# 125596            Closed with explanation              Yes                 No
# 125601            Closed with explanation              Yes                 No
# 125610            Closed with explanation              Yes                NaN
# 125616            Closed with explanation              Yes                Yes
# 125618            Closed with explanation              Yes                 No
# 125619            Closed with explanation              Yes                NaN
# 125620            Closed with explanation              Yes                 No
# 125621            Closed with explanation              Yes                 No
# 125622            Closed with explanation              Yes                 No
# 125623            Closed with explanation              Yes                NaN
# 125632                             Closed              Yes                NaN
# 125634            Closed with explanation              Yes                 No
# 125636            Closed with explanation              Yes                 No
# 125638                             Closed              Yes                NaN
# 125645            Closed with explanation              Yes                NaN
# 125647        Closed with monetary relief              Yes                 No
# 125650            Closed with explanation              Yes                 No
# 125654            Closed with explanation               No                NaN
# 125674            Closed with explanation              Yes                NaN
# 10000000                              WUT              WUT                WUT
#
#          Complaint ID Consumer Claim Company Offer Amount Received  \
# 13            1296831         101341        182761          122579
# 19            1297594         103382        186433          110905
# 22            1297626         219860        153908         99746.4
# 25            1297644         153377        169318         79792.6
# 33            1299207         105941        123410         89578.6
# 43            1297874         234463        133848          104833
# 44            1292137         177586       57294.3         89278.8
# 46            1290543        71574.5       24275.9         65055.5
# 47            1292139        61228.8       80961.1         22089.4
# 48            1290545         180004        214541         29346.5
# 49            1292065         136855      -7012.71         70034.7
# 50            1290564         110769         85294          140951
# 57            1290644         171647        167269          115596
# 58            1298042        91360.4        161714         17758.7
# 64            1298116         186817        228401          134987
# 69            1290765         174172         79753          101711
# 72            1304648         183467        130951          141618
# 81            1304057        94292.8        136124          123227
# 87            1290871         213280        157676         79534.2
# 88            1298322         109029       74100.1         40478.8
# 101           1304971         182034        114693         67510.8
# 102           1304692         150719        165691          136517
# 104           1291084         127616       66064.1         77037.9
# 107           1298656         150701        167926         53600.1
# 121           1291277         166114       81243.7         26314.2
# 122           1298770         198869        127222          104428
# 127           1292613         249758        136787         71294.5
# 131           1305325         169980       91967.1         12702.5
# 139           1292075         200978        208274          140896
# 146           1305831         192776        176085         46461.8
# ...               ...            ...           ...             ...
# 125543        2247658         202259        123664         92247.2
# 125546        2248476         141880        148011        -15018.4
# 125553        1444123         152880        102194          173177
# 125557        2209300         147430        114010         47345.3
# 125564        2180679         177723        216987          125398
# 125582        2247493         114277        158659         85375.3
# 125583        2152061         129114       98844.6         56791.4
# 125585        2244513          65427        140153         99335.4
# 125591        2243820         169197       66552.6           85770
# 125593        2205208         237211       47003.9          190013
# 125596        2192518        97710.9       64392.8         74558.9
# 125601        2169166         140342        138125         83521.1
# 125610        2248733         117591        103685           43801
# 125616        2214614         142776        191874          101699
# 125618        2128559         182276       67170.5         92324.1
# 125619        2214834         170016       65751.6         1991.28
# 125620        2153211          61245       99590.8         99820.8
# 125621        2186239         194124       63202.1         47589.8
# 125622        2191249         143223       16049.5          112756
# 125623        2248373         161307        119453           56043
# 125632        2215986         134966        163582         59377.2
# 125634        2177009        85949.8        165111           84770
# 125636        2197004         236151        119853          123156
# 125638        2216156         126366       67134.4          133644
# 125645        2215655         185078       92015.6         69618.4
# 125647        2122648         207893        180364         35887.4
# 125650        2182081         236688        221161         64958.9
# 125654        2215900        74632.7         57103          182861
# 125674        2247724         136799        114342          106343
# 10000000          WUT            WUT           WUT             WUT
#
#                     Custom
# 13        Consent provided
# 19        Consent provided
# 22        Consent provided
# 25        Consent provided
# 33        Consent provided
# 43        Consent provided
# 44        Consent provided
# 46        Consent provided
# 47        Consent provided
# 48        Consent provided
# 49        Consent provided
# 50        Consent provided
# 57        Consent provided
# 58        Consent provided
# 64        Consent provided
# 69        Consent provided
# 72        Consent provided
# 81        Consent provided
# 87        Consent provided
# 88        Consent provided
# 101       Consent provided
# 102       Consent provided
# 104       Consent provided
# 107       Consent provided
# 121       Consent provided
# 122       Consent provided
# 127       Consent provided
# 131       Consent provided
# 139       Consent provided
# 146       Consent provided
# ...                    ...
# 125543    Consent provided
# 125546    Consent provided
# 125553    Consent provided
# 125557    Consent provided
# 125564    Consent provided
# 125582    Consent provided
# 125583    Consent provided
# 125585    Consent provided
# 125591    Consent provided
# 125593    Consent provided
# 125596    Consent provided
# 125601    Consent provided
# 125610    Consent provided
# 125616    Consent provided
# 125618    Consent provided
# 125619    Consent provided
# 125620    Consent provided
# 125621    Consent provided
# 125622    Consent provided
# 125623    Consent provided
# 125632    Consent provided
# 125634    Consent provided
# 125636    Consent provided
# 125638    Consent provided
# 125645    Consent provided
# 125647    Consent provided
# 125650    Consent provided
# 125654    Consent provided
# 125674    Consent provided
# 10000000               WUT
#
# [26811 rows x 21 columns]

# %%
# 16. Select based on a condition using the loc[CONDITION, COLUMN_NAME] notation.

df.loc[df['Product'] == 'Credit card', 'Consumer complaint narrative'].head(5)
# Out:
# Series([], Name: Consumer complaint narrative, dtype: object)

# %%
# 17. Select using loc[] and a list of index values.

df.loc[(13, 19, 22), 'Consumer complaint narrative']
# Out:
# 13    i submitted a payment on XXXX XXXX 2015 for my...
# 19    Green Tree Financial somehow got XXXX Loan AFT...
# 22    To whom it may concern, To those that follow t...
# Name: Consumer complaint narrative, dtype: object

# %%
# 18. Use the [CONDITIONAL] selection to get all complaints from 2015.

df['Date received'] = pd.to_datetime(df['Date received'], errors='coerce')

df.loc[df['Date received'].dt.year == 2015, :] # , : not necessary.
# Out:
#        Date received   Product                             Sub-product  \
# 13        2015-03-23  Mortgage                          Other mortgage
# 19        2015-03-24  Mortgage                          Other mortgage
# 22        2015-03-24  Mortgage             Conventional fixed mortgage
# 25        2015-03-24  Mortgage                             VA mortgage
# 33        2015-03-24  Mortgage             Conventional fixed mortgage
# 43        2015-03-24  Mortgage             Conventional fixed mortgage
# 44        2015-03-19  Mortgage             Conventional fixed mortgage
# 46        2015-03-19  Mortgage                        Reverse mortgage
# 47        2015-03-19  Mortgage             Conventional fixed mortgage
# 48        2015-03-19  Mortgage             Conventional fixed mortgage
# 49        2015-03-19  Mortgage             Conventional fixed mortgage
# 50        2015-03-19  Mortgage                            FHA mortgage
# 57        2015-03-19  Mortgage      Home equity loan or line of credit
# 58        2015-03-24  Mortgage                          Other mortgage
# 64        2015-03-24  Mortgage             Conventional fixed mortgage
# 69        2015-03-19  Mortgage             Conventional fixed mortgage
# 72        2015-03-27  Mortgage      Home equity loan or line of credit
# 81        2015-03-27  Mortgage                          Other mortgage
# 87        2015-03-19  Mortgage             Conventional fixed mortgage
# 88        2015-03-24  Mortgage  Conventional adjustable mortgage (ARM)
# 101       2015-03-27  Mortgage             Conventional fixed mortgage
# 102       2015-03-27  Mortgage             Conventional fixed mortgage
# 104       2015-03-19  Mortgage             Conventional fixed mortgage
# 107       2015-03-24  Mortgage                            FHA mortgage
# 121       2015-03-19  Mortgage                            FHA mortgage
# 122       2015-03-24  Mortgage             Conventional fixed mortgage
# 127       2015-03-19  Mortgage                            FHA mortgage
# 131       2015-03-27  Mortgage                            FHA mortgage
# 139       2015-03-19  Mortgage             Conventional fixed mortgage
# 146       2015-03-28  Mortgage  Conventional adjustable mortgage (ARM)
# ...              ...       ...                                     ...
# 88107     2015-03-31  Mortgage             Conventional fixed mortgage
# 88316     2015-07-17  Mortgage  Conventional adjustable mortgage (ARM)
# 92597     2015-11-24  Mortgage             Conventional fixed mortgage
# 94752     2015-07-30  Mortgage             Conventional fixed mortgage
# 94760     2015-07-06  Mortgage                            FHA mortgage
# 99906     2015-09-22  Mortgage             Conventional fixed mortgage
# 101075    2015-05-21  Mortgage  Conventional adjustable mortgage (ARM)
# 101087    2015-05-01  Mortgage                          Other mortgage
# 101099    2015-06-08  Mortgage                          Other mortgage
# 101108    2015-06-23  Mortgage      Home equity loan or line of credit
# 101124    2015-11-11  Mortgage      Home equity loan or line of credit
# 101133    2015-05-12  Mortgage      Home equity loan or line of credit
# 101135    2015-10-21  Mortgage      Home equity loan or line of credit
# 101157    2015-08-27  Mortgage      Home equity loan or line of credit
# 101162    2015-10-13  Mortgage      Home equity loan or line of credit
# 101165    2015-03-28  Mortgage      Home equity loan or line of credit
# 101190    2015-04-30  Mortgage      Home equity loan or line of credit
# 101196    2015-12-15  Mortgage      Home equity loan or line of credit
# 105493    2015-09-16  Mortgage  Conventional adjustable mortgage (ARM)
# 106142    2015-07-07  Mortgage  Conventional adjustable mortgage (ARM)
# 106453    2015-07-29  Mortgage  Conventional adjustable mortgage (ARM)
# 106590    2015-08-19  Mortgage  Conventional adjustable mortgage (ARM)
# 109394    2015-09-23  Mortgage             Conventional fixed mortgage
# 109465    2015-10-14  Mortgage             Conventional fixed mortgage
# 115638    2015-08-03  Mortgage             Conventional fixed mortgage
# 116479    2015-04-24  Mortgage      Home equity loan or line of credit
# 116618    2015-04-14  Mortgage             Conventional fixed mortgage
# 120778    2015-08-13  Mortgage             Conventional fixed mortgage
# 121251    2015-07-11  Mortgage             Conventional fixed mortgage
# 125553    2015-06-30  Mortgage  Conventional adjustable mortgage (ARM)
#
#                                            Issue Sub-issue  \
# 13      Loan servicing, payments, escrow account       NaN
# 19      Loan servicing, payments, escrow account       NaN
# 22                Credit decision / Underwriting       NaN
# 25      Loan servicing, payments, escrow account       NaN
# 33      Loan servicing, payments, escrow account       NaN
# 43      Loan servicing, payments, escrow account       NaN
# 44                Credit decision / Underwriting       NaN
# 46      Application, originator, mortgage broker       NaN
# 47      Loan servicing, payments, escrow account       NaN
# 48      Loan servicing, payments, escrow account       NaN
# 49      Loan servicing, payments, escrow account       NaN
# 50      Application, originator, mortgage broker       NaN
# 57      Loan servicing, payments, escrow account       NaN
# 58                  Settlement process and costs       NaN
# 64      Loan servicing, payments, escrow account       NaN
# 69      Loan modification,collection,foreclosure       NaN
# 72      Loan modification,collection,foreclosure       NaN
# 81      Loan servicing, payments, escrow account       NaN
# 87      Loan servicing, payments, escrow account       NaN
# 88      Loan servicing, payments, escrow account       NaN
# 101     Loan modification,collection,foreclosure       NaN
# 102     Loan modification,collection,foreclosure       NaN
# 104                 Settlement process and costs       NaN
# 107     Loan servicing, payments, escrow account       NaN
# 121     Loan servicing, payments, escrow account       NaN
# 122     Loan servicing, payments, escrow account       NaN
# 127     Loan servicing, payments, escrow account       NaN
# 131     Loan modification,collection,foreclosure       NaN
# 139     Loan modification,collection,foreclosure       NaN
# 146     Loan modification,collection,foreclosure       NaN
# ...                                          ...       ...
# 88107   Loan servicing, payments, escrow account       NaN
# 88316   Loan modification,collection,foreclosure       NaN
# 92597             Credit decision / Underwriting       NaN
# 94752   Application, originator, mortgage broker       NaN
# 94760   Loan servicing, payments, escrow account       NaN
# 99906   Loan modification,collection,foreclosure       NaN
# 101075            Credit decision / Underwriting       NaN
# 101087  Loan modification,collection,foreclosure       NaN
# 101099            Credit decision / Underwriting       NaN
# 101108  Loan servicing, payments, escrow account       NaN
# 101124  Application, originator, mortgage broker       NaN
# 101133  Loan servicing, payments, escrow account       NaN
# 101135  Loan servicing, payments, escrow account       NaN
# 101157  Loan servicing, payments, escrow account       NaN
# 101162  Loan servicing, payments, escrow account       NaN
# 101165  Application, originator, mortgage broker       NaN
# 101190  Loan modification,collection,foreclosure       NaN
# 101196  Application, originator, mortgage broker       NaN
# 105493  Application, originator, mortgage broker       NaN
# 106142  Loan servicing, payments, escrow account       NaN
# 106453  Loan servicing, payments, escrow account       NaN
# 106590  Loan servicing, payments, escrow account       NaN
# 109394  Loan servicing, payments, escrow account       NaN
# 109465  Loan modification,collection,foreclosure       NaN
# 115638  Application, originator, mortgage broker       NaN
# 116479  Application, originator, mortgage broker       NaN
# 116618            Credit decision / Underwriting       NaN
# 120778  Application, originator, mortgage broker       NaN
# 121251  Application, originator, mortgage broker       NaN
# 125553  Loan modification,collection,foreclosure       NaN
#
#                              Consumer complaint narrative  \
# 13      i submitted a payment on XXXX XXXX 2015 for my...
# 19      Green Tree Financial somehow got XXXX Loan AFT...
# 22      To whom it may concern, To those that follow t...
# 25      My mortgage servicer, Wells Fargo, did not giv...
# 33      I paid off my mortgage with XXXX Mortgage Serv...
# 43      I was emailed that my online account had been ...
# 44      XXXX was submitted XX/XX/XXXX. At the time I s...
# 46      I am very disappointed that the CFPB did not h...
# 47      We fell behind in our payments back in 2014 fo...
# 48      I am a Successor - in -interest to a property ...
# 49      I am writing this letter because my mortgage a...
# 50      I had a mortgage with from XXXX of XXXX to XXX...
# 57      I made a payment on a {$69000.00} loan of $ XX...
# 58      I applied for a loan modification with Suntrus...
# 64      I was {$48.00} behind on our mortgage because ...
# 69      I have been trying to get an audit of my accou...
# 72      We had a Line of Credit with US Bank that was ...
# 81      Ocwen financial services claims simultaneously...
# 87      I had a mortgage with XXXX XXXX XXXX from XXXX...
# 88      I schedule my mortgage payment, using the mort...
# 101     My wife and I just went through 7 months of ap...
# 102     We have been working or a Short Sale for Selec...
# 104     I got behind in payments and worked with B of ...
# 107     Yesterday, I called my mortgage company, Ocwen...
# 121     Wells Fargo Mortgage began foreclosure action ...
# 122     Caliber Home loans has claimed to have made pa...
# 127     Our Mortgage was sold to Carrington Mortgage S...
# 131     I was part of the XXXX and received payment la...
# 139     We are a victim of Ocwen mortgage and their fr...
# 146     Please know I greatly appreciate your assistan...
# ...                                                   ...
# 88107   Had XXXX mortgage loans w/XXXX bank paying rig...
# 88316   I made a timely appeal request and no written ...
# 92597   XXXX XXXX, XXXX I took out a mortgage XXXX. Le...
# 94752   On the day before we locked in a mortgage rate...
# 94760   My mortgage was due on XXXX XXXX with a grace ...
# 99906   I am a victim of the Wells Fargo modification ...
# 101075  i recently applied for a mortgage with key ban...
# 101087  I had a house in XXXX OR. I paid the mortgage ...
# 101099  I noticed a hard inquiry on my credit from XXX...
# 101108  a ) KeyBank stopped using the existing ACH deb...
# 101124  I am attempting to sell my current home and to...
# 101133  I WAS ASSESSED ATTORNEY FEES ON XXXX/XXXX/15 {...
# 101135  Subject : Loan Modification RMA was Denied. Ho...
# 101157  Attachment for Keybank : Foreclosure Fraud Rev...
# 101162  I have a XXXX on my house in XXXX Ca. with Key...
# 101165  I had a Home Equity about to go into repayment...
# 101190  What Happened? \r\r\n\r\r\nSubject : Key Bank ...
# 101196  I bought a house in XXXX XXXX, 2014. We extens...
# 105493  I wish to remain anonymous. Recently, I found ...
# 106142  This is a situation of being ignored by Chase ...
# 106453  this is a complaint I also filed with the XXXX...
# 106590  I just days ago got from XXXX a credit report ...
# 109394  This complaint is in reference to First Niagar...
# 109465  XX/XX/XXXX I had been hurt at work and was una...
# 115638  I refinanced my home with MLD mortgage. They w...
# 116479  I declared Bankruptcy in XXXX XXXX and it was ...
# 116618  We applied for a mortgage from Mortgage Master...
# 120778  I made a mortgage application with I3 lending ...
# 121251  In XXXX, 2015 We were refinancing our mortgage...
# 125553  XX/XX/XXXX  Immediate concern: Stop  the forec...
#
#                                   Company public response  \
# 13                                                    NaN
# 19                                                    NaN
# 22                                                    NaN
# 25                                                    NaN
# 33                                                    NaN
# 43                                                    NaN
# 44                                                    NaN
# 46                                                    NaN
# 47                                                    NaN
# 48                                                    NaN
# 49      Company believes it acted appropriately as aut...
# 50                                                    NaN
# 57                                                    NaN
# 58       Company chooses not to provide a public response
# 64                                                    NaN
# 69                                                    NaN
# 72       Company chooses not to provide a public response
# 81                                                    NaN
# 87                                                    NaN
# 88      Company believes it acted appropriately as aut...
# 101      Company chooses not to provide a public response
# 102     Company believes it acted appropriately as aut...
# 104      Company chooses not to provide a public response
# 107                                                   NaN
# 121                                                   NaN
# 122                                                   NaN
# 127                                                   NaN
# 131      Company chooses not to provide a public response
# 139                                                   NaN
# 146                                                   NaN
# ...                                                   ...
# 88107                                                 NaN
# 88316    Company chooses not to provide a public response
# 92597    Company chooses not to provide a public response
# 94752                                                 NaN
# 94760    Company chooses not to provide a public response
# 99906    Company chooses not to provide a public response
# 101075                                                NaN
# 101087                                                NaN
# 101099                                                NaN
# 101108                                                NaN
# 101124                                                NaN
# 101133                                                NaN
# 101135                                                NaN
# 101157                                                NaN
# 101162                                                NaN
# 101165                                                NaN
# 101190                                                NaN
# 101196                                                NaN
# 105493                                                NaN
# 106142                                                NaN
# 106453                                                NaN
# 106590                                                NaN
# 109394                                                NaN
# 109465                                                NaN
# 115638                                                NaN
# 116479                                                NaN
# 116618  Company believes it acted appropriately as aut...
# 120778                                                NaN
# 121251   Company chooses not to provide a public response
# 125553   Company chooses not to provide a public response
#
#                                       Company State ZIP code  \
# 13                                      Ocwen    IL    627XX
# 19                       Ditech Financial LLC    CA    926XX
# 22                             Morgan Stanley    CA    944XX
# 25                      Wells Fargo & Company    TX    770XX
# 33           HSBC North America Holdings Inc.    NY    141XX
# 43                      Wells Fargo & Company    MT    598XX
# 44      Rushmore Loan Management Services LLC    CA    956XX
# 46              CIT Bank National Association    NJ    080XX
# 47                        Nationstar Mortgage    VA    230XX
# 48                        Nationstar Mortgage    CA    925XX
# 49            Select Portfolio Servicing, Inc    NJ    080XX
# 50             Citizens Financial Group, Inc.    MA    021XX
# 57             Specialized Loan Servicing LLC    NJ    074XX
# 58                       SunTrust Banks, Inc.    CO    804XX
# 64                       Ditech Financial LLC    MA    020XX
# 69                                   Citibank    MD    207XX
# 72                               U.S. Bancorp    CO    801XX
# 81                                      Ocwen    MA    017XX
# 87                        Nationstar Mortgage    TX    775XX
# 88                        Nationstar Mortgage    GA    300XX
# 101                              U.S. Bancorp    KS    664XX
# 102           Select Portfolio Servicing, Inc    FL    333XX
# 104                           Bank of America    CA    926XX
# 107                                     Ocwen    TX    770XX
# 121                     Wells Fargo & Company    AZ    853XX
# 122                   Caliber Home Loans, Inc    IN    463XX
# 127        Carrington Mortgage Holdings, LLC.    TX    755XX
# 131                           Bank of America    GA    309XX
# 139                                     Ocwen    KS    666XX
# 146                             Seterus, Inc.    FL    331XX
# ...                                       ...   ...      ...
# 88107          Specialized Loan Servicing LLC    NC    283XX
# 88316                         Bank of America    CA    921XX
# 92597                         Bank of America    MO    641XX
# 94752             The J. G. Wentworth Company    TX    774XX
# 94760             The J. G. Wentworth Company    DC    200XX
# 99906                   Wells Fargo & Company    VA    234XX
# 101075                                KeyCorp    NY    109XX
# 101087                                KeyCorp    OR    970XX
# 101099                                KeyCorp    OH    445XX
# 101108                                KeyCorp    UT    843XX
# 101124                                KeyCorp    PA    180XX
# 101133                                KeyCorp    TX    752XX
# 101135                                KeyCorp    UT    840XX
# 101157                                KeyCorp    NY    140XX
# 101162                                KeyCorp    CA    923XX
# 101165                                KeyCorp    ME    042XX
# 101190                                KeyCorp    UT    840XX
# 101196                                KeyCorp    OH    453XX
# 105493       Pacific Financial Group (Closed)    CA    945XX
# 106142                   JPMorgan Chase & Co.    MA    020XX
# 106453                   JPMorgan Chase & Co.    MA    020XX
# 106590                   JPMorgan Chase & Co.    MA    020XX
# 109394                     First Niagara Bank    PA    180XX
# 109465                     First Niagara Bank    NY    109XX
# 115638                     MLD Mortgage, Inc.    FL    329XX
# 116479                            Capital One    GA    300XX
# 116618                              LoanDepot    MA    024XX
# 120778                        i3 Lending, Inc    MI    495XX
# 121251                        Bank of America    NY    117XX
# 125553                  Wells Fargo & Company    CA    943XX
#
#               ...        Consumer consent provided? Date sent to company  \
# 13            ...                  Consent provided            3/23/2015
# 19            ...                  Consent provided            3/24/2015
# 22            ...                  Consent provided            3/24/2015
# 25            ...                  Consent provided            3/24/2015
# 33            ...                  Consent provided            3/24/2015
# 43            ...                  Consent provided            3/24/2015
# 44            ...                  Consent provided            3/19/2015
# 46            ...                  Consent provided            3/19/2015
# 47            ...                  Consent provided            3/19/2015
# 48            ...                  Consent provided            3/19/2015
# 49            ...                  Consent provided            3/19/2015
# 50            ...                  Consent provided            3/19/2015
# 57            ...                  Consent provided            3/19/2015
# 58            ...                  Consent provided            3/24/2015
# 64            ...                  Consent provided            3/24/2015
# 69            ...                  Consent provided            3/19/2015
# 72            ...                  Consent provided            3/27/2015
# 81            ...                  Consent provided             4/1/2015
# 87            ...                  Consent provided            3/19/2015
# 88            ...                  Consent provided            3/24/2015
# 101           ...                  Consent provided            3/27/2015
# 102           ...                  Consent provided            3/27/2015
# 104           ...                  Consent provided            3/19/2015
# 107           ...                  Consent provided            3/24/2015
# 121           ...                  Consent provided            3/19/2015
# 122           ...                  Consent provided            3/25/2015
# 127           ...                  Consent provided            3/19/2015
# 131           ...                  Consent provided             4/6/2015
# 139           ...                  Consent provided            3/19/2015
# 146           ...                  Consent provided            3/28/2015
# ...           ...                               ...                  ...
# 88107         ...                  Consent provided            3/31/2015
# 88316         ...                  Consent provided            7/17/2015
# 92597         ...                  Consent provided           11/24/2015
# 94752         ...                  Consent provided            7/30/2015
# 94760         ...                  Consent provided             7/6/2015
# 99906         ...                  Consent provided            9/23/2015
# 101075        ...                  Consent provided            5/28/2015
# 101087        ...                  Consent provided             5/1/2015
# 101099        ...                  Consent provided            6/25/2015
# 101108        ...                  Consent provided            6/23/2015
# 101124        ...                  Consent provided           11/16/2015
# 101133        ...                  Consent provided            5/12/2015
# 101135        ...                  Consent provided           10/21/2015
# 101157        ...                  Consent provided            8/27/2015
# 101162        ...                  Consent provided           10/13/2015
# 101165        ...                  Consent provided             4/2/2015
# 101190        ...                  Consent provided            4/30/2015
# 101196        ...                  Consent provided           12/15/2015
# 105493        ...                  Consent provided            9/24/2015
# 106142        ...                  Consent provided             7/7/2015
# 106453        ...                  Consent provided            7/29/2015
# 106590        ...                  Consent provided            8/19/2015
# 109394        ...                  Consent provided            9/25/2015
# 109465        ...                  Consent provided           10/14/2015
# 115638        ...                  Consent provided             8/3/2015
# 116479        ...                  Consent provided            4/24/2015
# 116618        ...                  Consent provided           12/12/2016
# 120778        ...                  Consent provided            9/10/2015
# 121251        ...                  Consent provided            7/11/2015
# 125553        ...                  Consent provided            6/30/2015
#
#            Company response to consumer Timely response? Consumer disputed?  \
# 13              Closed with explanation              Yes                 No
# 19      Closed with non-monetary relief              Yes                 No
# 22              Closed with explanation              Yes                 No
# 25              Closed with explanation              Yes                 No
# 33              Closed with explanation              Yes                 No
# 43      Closed with non-monetary relief              Yes                 No
# 44              Closed with explanation              Yes                Yes
# 46              Closed with explanation              Yes                 No
# 47              Closed with explanation              Yes                 No
# 48              Closed with explanation              Yes                 No
# 49              Closed with explanation              Yes                 No
# 50              Closed with explanation              Yes                Yes
# 57              Closed with explanation              Yes                Yes
# 58      Closed with non-monetary relief              Yes                 No
# 64      Closed with non-monetary relief              Yes                Yes
# 69              Closed with explanation              Yes                Yes
# 72              Closed with explanation              Yes                 No
# 81              Closed with explanation              Yes                 No
# 87              Closed with explanation              Yes                 No
# 88              Closed with explanation              Yes                Yes
# 101             Closed with explanation              Yes                Yes
# 102             Closed with explanation              Yes                 No
# 104         Closed with monetary relief              Yes                 No
# 107             Closed with explanation              Yes                 No
# 121             Closed with explanation              Yes                Yes
# 122             Closed with explanation              Yes                 No
# 127             Closed with explanation              Yes                 No
# 131             Closed with explanation              Yes                Yes
# 139             Closed with explanation              Yes                Yes
# 146             Closed with explanation              Yes                Yes
# ...                                 ...              ...                ...
# 88107           Closed with explanation              Yes                 No
# 88316           Closed with explanation              Yes                Yes
# 92597           Closed with explanation              Yes                Yes
# 94752           Closed with explanation              Yes                 No
# 94760           Closed with explanation              Yes                Yes
# 99906           Closed with explanation              Yes                 No
# 101075          Closed with explanation              Yes                 No
# 101087          Closed with explanation              Yes                 No
# 101099          Closed with explanation              Yes                 No
# 101108      Closed with monetary relief              Yes                 No
# 101124          Closed with explanation              Yes                 No
# 101133      Closed with monetary relief              Yes                 No
# 101135          Closed with explanation              Yes                 No
# 101157          Closed with explanation              Yes                 No
# 101162          Closed with explanation              Yes                 No
# 101165          Closed with explanation              Yes                 No
# 101190          Closed with explanation              Yes                 No
# 101196          Closed with explanation              Yes                 No
# 105493                Untimely response               No                NaN
# 106142          Closed with explanation              Yes                Yes
# 106453          Closed with explanation              Yes                Yes
# 106590          Closed with explanation              Yes                Yes
# 109394          Closed with explanation              Yes                Yes
# 109465          Closed with explanation              Yes                 No
# 115638          Closed with explanation               No                 No
# 116479          Closed with explanation              Yes                Yes
# 116618          Closed with explanation              Yes                Yes
# 120778  Closed with non-monetary relief               No                NaN
# 121251          Closed with explanation              Yes                 No
# 125553          Closed with explanation              Yes                 No
#
#        Complaint ID Consumer Claim Company Offer Amount Received  \
# 13          1296831         101341        182761          122579
# 19          1297594         103382        186433          110905
# 22          1297626         219860        153908         99746.4
# 25          1297644         153377        169318         79792.6
# 33          1299207         105941        123410         89578.6
# 43          1297874         234463        133848          104833
# 44          1292137         177586       57294.3         89278.8
# 46          1290543        71574.5       24275.9         65055.5
# 47          1292139        61228.8       80961.1         22089.4
# 48          1290545         180004        214541         29346.5
# 49          1292065         136855      -7012.71         70034.7
# 50          1290564         110769         85294          140951
# 57          1290644         171647        167269          115596
# 58          1298042        91360.4        161714         17758.7
# 64          1298116         186817        228401          134987
# 69          1290765         174172         79753          101711
# 72          1304648         183467        130951          141618
# 81          1304057        94292.8        136124          123227
# 87          1290871         213280        157676         79534.2
# 88          1298322         109029       74100.1         40478.8
# 101         1304971         182034        114693         67510.8
# 102         1304692         150719        165691          136517
# 104         1291084         127616       66064.1         77037.9
# 107         1298656         150701        167926         53600.1
# 121         1291277         166114       81243.7         26314.2
# 122         1298770         198869        127222          104428
# 127         1292613         249758        136787         71294.5
# 131         1305325         169980       91967.1         12702.5
# 139         1292075         200978        208274          140896
# 146         1305831         192776        176085         46461.8
# ...             ...            ...           ...             ...
# 88107       1309063         116107        145928          104116
# 88316       1473742         244570        126394         64244.9
# 92597       1670459         235520        144844        -8402.13
# 94752       1495583         116958        111223         93092.7
# 94760       1451533         193369        169920         58956.4
# 99906       1574939         132885        145971         87272.2
# 101075      1387582        97850.1       97956.2          128679
# 101087      1356103         144119       70607.8         95825.6
# 101099      1411163         174936         68985          133895
# 101108      1433280         111890        177223         43462.5
# 101124      1650592         118159        189332         68575.1
# 101133      1371897         161013       59633.3         35246.2
# 101135      1617229         177345        117303         57205.2
# 101157      1539524         239930       79838.3         6881.11
# 101162      1604404         196873        105557          132959
# 101165      1306077         221706        118488         69762.8
# 101190      1354175         190724        116709          113335
# 101196      1697825         110456        225628          140131
# 105493      1567606         118853        160066          161484
# 106142      1453980         193864        109148         20322.8
# 106453      1493323         167511       87399.3         73377.1
# 106590      1525497         165432        133992         33335.6
# 109394      1575699        99264.6        163700          133659
# 109465      1605919         166691        107072         87320.8
# 115638      1500004         105920        163155         85054.3
# 116479      1345410        83190.1       85096.3         75395.9
# 116618      1328746        32705.8        109451         73227.9
# 120778      1517500         235166        111091          149341
# 121251      1463527         176649        104050         74178.2
# 125553      1444123         152880        102194          173177
#
#                   Custom
# 13      Consent provided
# 19      Consent provided
# 22      Consent provided
# 25      Consent provided
# 33      Consent provided
# 43      Consent provided
# 44      Consent provided
# 46      Consent provided
# 47      Consent provided
# 48      Consent provided
# 49      Consent provided
# 50      Consent provided
# 57      Consent provided
# 58      Consent provided
# 64      Consent provided
# 69      Consent provided
# 72      Consent provided
# 81      Consent provided
# 87      Consent provided
# 88      Consent provided
# 101     Consent provided
# 102     Consent provided
# 104     Consent provided
# 107     Consent provided
# 121     Consent provided
# 122     Consent provided
# 127     Consent provided
# 131     Consent provided
# 139     Consent provided
# 146     Consent provided
# ...                  ...
# 88107   Consent provided
# 88316   Consent provided
# 92597   Consent provided
# 94752   Consent provided
# 94760   Consent provided
# 99906   Consent provided
# 101075  Consent provided
# 101087  Consent provided
# 101099  Consent provided
# 101108  Consent provided
# 101124  Consent provided
# 101133  Consent provided
# 101135  Consent provided
# 101157  Consent provided
# 101162  Consent provided
# 101165  Consent provided
# 101190  Consent provided
# 101196  Consent provided
# 105493  Consent provided
# 106142  Consent provided
# 106453  Consent provided
# 106590  Consent provided
# 109394  Consent provided
# 109465  Consent provided
# 115638  Consent provided
# 116479  Consent provided
# 116618  Consent provided
# 120778  Consent provided
# 121251  Consent provided
# 125553  Consent provided
#
# [12327 rows x 21 columns]

# %% [markdown]
# ## Next: [Pandas Munging](13_pandas_munging.ipynb)
