# %%
DOC = '''Supreme Court Oral Argument Predictor (SCOAP)

Creates models for predicting outcomes of Supreme Court oral
arguments. Pulls justice-specific phrases associated with
winning and losing arguments.

LICENSE:    MIT
AUTHOR:     theonaunheim@gmail.com
COPYRIGHT:  2017, Theo Naunheim
VERSION:    0.4.3
MODIFIED:   2017-03-26
DATA DIR:   .scoap
REQUIRES:   Jupyter Notebook and Xpdf/Poppler

WARNING:    THIS SCRIPT DOWNLOADS AND PROCESSES A LARGE
            VOLUME OF MATERIAL. IT IS COMPUTATIONALLY
            EXPENSIVE AND TAKES A NON-NEGLIGIBLE AMOUNT
            OF TIME AND BANDWIDTH.

'''

# %%
# Standard library imports
import asyncio
import copy
import itertools
import os
import re
import string
import sys
import zipfile

# Web/data imports
import bs4
import numpy as np
import pandas as pd
import requests

# Scikit learn imports
import sklearn
import sklearn.feature_extraction
import sklearn.metrics
import sklearn.model_selection
import sklearn.linear_model
import sklearn.naive_bayes
import sklearn.pipeline
import sklearn.svm
import sklearn.ensemble

# %%
# Constants and constant-ish things.

# Debug flag cuts down amount of data used.
DEBUG = False

# Website URLs for downloads
TRANSCRIPT_INFO = 'https://www.supremecourt.gov/oral_arguments/argument_transcript/'
TRANSCRIPT_DOWNLOADS = 'https://www.supremecourt.gov/oral_arguments/'
SCDB_CSV_DOWNLOAD_LINK = 'http://scdb.wustl.edu/_brickFiles/2016_01/SCDB_2016_01_justiceCentered_Docket.csv.zip'

# Transcript years for dynamic URL creation
START_YEAR = 2006
END_YEAR = 2017

# OS-specific path for PDF to text extraction utility.
if os.name == 'nt':
    PDF2TEXT_PATH = r'C:\Program Files\Xpdf\pdftotext.exe'
elif os.name == 'posix':
    PDF2TEXT_PATH = '/usr/bin/pdftotext'
else:
    raise Exception('This script requires Xpdf/Poppler utility pdftotext to run.')

# Paths for SCOAP specific data.
DATA_FOLDER = os.path.join(os.path.expanduser('~'), '.scoap')
SCDB_ZIP_NAME = SCDB_CSV_DOWNLOAD_LINK.rpartition('/')[2]
SCDB_CSV_NAME = SCDB_ZIP_NAME.rpartition('.')[0]
SCDB_ZIP_PATH = os.path.join(DATA_FOLDER, SCDB_ZIP_NAME)
SCDB_CSV_PATH = SCDB_ZIP_PATH.rpartition('.')[0]

# The current term justices and cases we wish to analyze.
CURRENT_JUSTICES = ['Roberts', 'Kennedy', 'Thomas', 'Ginsburg', 'Breyer', 'Alito', 'Sotomayor', 'Kagan']
CURRENT_CASES = ['15-214', '15-1031', '15-497', '15-1189', '16-369',
                 '16-254', '15-118', '15-1248', '16-32', '15-1194',
                 '16-54', '15-9260', '16-149', '16-1256', '15-1500',
                 '15-1391', '15-1406', '15-827', '15-1498', '16-348',
                 '15-1293', '15-1358', '15-8544', '15-797', '15-1204',
                 '15-680', '15-1262', '14-1538', '15-649', '15-866',
                 '15-513', '15-927', '15-423', '15-1251', '15-1111',
                 '14-1055', '15-1191', '15-537', '15-5991', '15-628', 
                 '15-8049', '14-9496', '15-777', '15-606', '15-7250',]

# Voting relationships for OT15, courtesy of http://www.scotusblog.com/statistics/
VOTING_RELATIONSHIPS = {"KENNEDY"  :{"KENNEDY":1.00,"SCALIA":0.82,"THOMAS":0.71,"KAGAN":0.95,"ROBERTS":0.88,"GINSBURG":0.84,"ALITO":0.82,"BREYER":0.91,"SOTOMAYOR":0.79},
                        "SCALIA"   :{"KENNEDY":0.82,"SCALIA":1.00,"THOMAS":0.88,"KAGAN":0.82,"ROBERTS":0.88,"GINSBURG":0.71,"ALITO":0.94,"BREYER":0.82,"SOTOMAYOR":0.65},
                        "THOMAS"   :{"KENNEDY":0.71,"SCALIA":0.88,"THOMAS":1.00,"KAGAN":0.67,"ROBERTS":0.75,"GINSBURG":0.62,"ALITO":0.78,"BREYER":0.67,"SOTOMAYOR":0.64},
                        "KAGAN"    :{"KENNEDY":0.95,"SCALIA":0.82,"THOMAS":0.67,"KAGAN":1.00,"ROBERTS":0.87,"GINSBURG":0.87,"ALITO":0.81,"BREYER":0.92,"SOTOMAYOR":0.81},
                        "ROBERTS"  :{"KENNEDY":0.88,"SCALIA":0.88,"THOMAS":0.75,"KAGAN":0.87,"ROBERTS":1.00,"GINSBURG":0.78,"ALITO":0.84,"BREYER":0.84,"SOTOMAYOR":0.77},
                        "GINSBURG" :{"KENNEDY":0.84,"SCALIA":0.71,"THOMAS":0.62,"KAGAN":0.87,"ROBERTS":0.78,"GINSBURG":1.00,"ALITO":0.73,"BREYER":0.86,"SOTOMAYOR":0.88},
                        "ALITO"    :{"KENNEDY":0.82,"SCALIA":0.94,"THOMAS":0.78,"KAGAN":0.81,"ROBERTS":0.84,"GINSBURG":0.73,"ALITO":1.00,"BREYER":0.77,"SOTOMAYOR":0.64},
                        "BREYER"   :{"KENNEDY":0.91,"SCALIA":0.82,"THOMAS":0.67,"KAGAN":0.92,"ROBERTS":0.84,"GINSBURG":0.86,"ALITO":0.77,"BREYER":1.00,"SOTOMAYOR":0.83},
                        "SOTOMAYOR":{"KENNEDY":0.79,"SCALIA":0.65,"THOMAS":0.64,"KAGAN":0.81,"ROBERTS":0.77,"GINSBURG":0.88,"ALITO":0.64,"BREYER":0.83,"SOTOMAYOR":1.00}}

# %%
# Define function.
def create_dataframe():
    '''Create a skeleton for our df.'''
    df = pd.DataFrame(columns=['CASE',
                               'DOCKET',
                               'ARGUMENT_YEAR',
                               'ARGUMENT_LINK',
                               'ARGUMENT_PATH',])
    return df


# Run function.
arg_df = create_dataframe()

# %%
# Define function.
def get_argument_metadata(df, start=START_YEAR - 1, end=END_YEAR + 1):
    '''This fetches oral argument location metadata.'''
    # For each year
    for year in range(start, end):
        # Create web address and download data 
        address = TRANSCRIPT_INFO + str(year)
        r = requests.get(address)
        # Parse data
        try:
            soup = bs4.BeautifulSoup(r.text, 'lxml')
            table = soup.find('table', 'table datatables')
            for row in table.findAll('tr'):
                link = row.find('a')
                case = row.find('span')
                # Write table info to dataframe.
                if link:
                    link_text = link.text[:-2].lower()
                    case_text = case.text
                    link_tail = link.attrs['href'].lstrip('../')
                    full_link = TRANSCRIPT_DOWNLOADS + link_tail
                    # Write to frame
                    path = os.path.join(DATA_FOLDER, link_text, 'argument.pdf')
                    df = df.append({'CASE': case_text,
                                    'DOCKET': link_text,
                                    'ARGUMENT_LINK': full_link,
                                    'ARGUMENT_PATH': path,
                                    'ARGUMENT_YEAR': str(year)}, ignore_index=True)
        except AttributeError:
            print('Attribute error. Probably an empty page.')
    return df


# Run function.
arg_df = get_argument_metadata(arg_df)
# Out:
# Attribute error. Probably an empty page.

# %%
# Show dataframe for clarity.
arg_df.head(3)
# Out:
#                                     CASE   DOCKET ARGUMENT_YEAR  \
# 0          Hudson v. Michigan (Reargued)  04-1360          2005
# 1                 Washington v. Recuenco    05-83          2005
# 2  Burlington N. & S. F. R. Co. v. White   05-259          2005
#
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH
# 0  /home/theo/.scoap/04-1360/argument.pdf
# 1    /home/theo/.scoap/05-83/argument.pdf
# 2   /home/theo/.scoap/05-259/argument.pdf

# %%
# Debug to shorten time during testing
if DEBUG:
    arg_df = arg_df.iloc[-10:].copy()

# %%
# Define function.
def make_directories(row):
    '''All cases get their own folder.'''
    try:
        path = os.path.join(DATA_FOLDER, row['DOCKET'])
        os.makedirs(path)
    except FileExistsError:
        pass

    
# Apply function. Output unnecessary.
_ = arg_df.apply(make_directories, axis=1)

# %%
# Define function.
def download_pdfs(row):
    '''Get PDFs and put in the folder if necessary.'''
    # If there's a link and no file, download.
    if row['ARGUMENT_LINK'] is not np.NaN:
        if os.path.exists(row['ARGUMENT_PATH']):
            return False
        r = requests.get(row['ARGUMENT_LINK'], stream=True)
        with open(row['ARGUMENT_PATH'], 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024): 
                if chunk:
                    f.write(chunk)

                    
# Apply function. No assinment required.
_ = arg_df.apply(download_pdfs, axis=1)

# %%
arg_df.head(3)
# Out:
#                                     CASE   DOCKET ARGUMENT_YEAR  \
# 0          Hudson v. Michigan (Reargued)  04-1360          2005
# 1                 Washington v. Recuenco    05-83          2005
# 2  Burlington N. & S. F. R. Co. v. White   05-259          2005
#
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH
# 0  /home/theo/.scoap/04-1360/argument.pdf
# 1    /home/theo/.scoap/05-83/argument.pdf
# 2   /home/theo/.scoap/05-259/argument.pdf

# %%
# Define functions.
async def get_text(pdf_path): 
    '''This function is a coroutine for a single pdf2text.py instance.'''
    # Create the subprocess, redirect the standard output into a pipe
    process = await asyncio.create_subprocess_exec(PDF2TEXT_PATH,
                                                   pdf_path,
                                                   '-',
                                                   stdout=asyncio.subprocess.PIPE,
                                                   stderr=asyncio.subprocess.PIPE) 
    # Read output
    data = await process.communicate() 
    # Have process exit and return data.
    await process.wait()
    # Decode cp1252 for windows
    try:
        decoded_data = data[0].decode('cp1252')
    # And UTF-8 for Linux.
    except:
        decoded_data = data[0].decode()
    return decoded_data


async def get_all_text(pdf_paths):
    '''This gathers the pdf2text.py results.'''
    # Create list for return results.
    result_list = []
    # Create a list of tasks
    input_len = len(pdf_paths)
    num_chunks = (input_len // 10) + 1
    chunked_input = np.array_split(pdf_paths, num_chunks)
    # Now run each of the chunks in parallel to speed things up.
    for chunk in chunked_input:
        # Create tasks
        tasks = [get_text(path) for path in chunk]
        # Run all the tasks in parallel
        results = await asyncio.gather(*tasks)
        # Put the zipped (path, results) in result list
        for path, result in zip(chunk, results):
            result_list.append((path, result))
    return result_list


def add_arguments(df):
    '''Adds argument text to df.'''
    # Get unique PDFs
    unique_pdfs = df['ARGUMENT_PATH'].unique()
    # Windows only supports proactorloop.
    if os.name == 'nt':
        loop = asyncio.ProactorEventLoop()
    elif os.name == 'posix':
        loop = asyncio.SelectorEventLoop()
    else:
        loop == None
    asyncio.set_event_loop(loop)
    # Run our coroutine to extract text.
    arg_data = loop.run_until_complete(get_all_text(unique_pdfs))
    # Loop no longer necessary.
    loop.close()
    # Create dataframe for data.
    tdf = pd.DataFrame.from_records(arg_data, columns=['ARGUMENT_PATH', 'TEXT'])
    # Join to input df and fill na.
    df = df.merge(tdf, how='left', on='ARGUMENT_PATH').fillna('')
    return df


# Run function
arg_df = add_arguments(arg_df)

# %%
# Show dataframe for clarity.
arg_df.head(3)
# Out:
#                                     CASE   DOCKET ARGUMENT_YEAR  \
# 0          Hudson v. Michigan (Reargued)  04-1360          2005
# 1                 Washington v. Recuenco    05-83          2005
# 2  Burlington N. & S. F. R. Co. v. White   05-259          2005
#
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH  \
# 0  /home/theo/.scoap/04-1360/argument.pdf
# 1    /home/theo/.scoap/05-83/argument.pdf
# 2   /home/theo/.scoap/05-259/argument.pdf
#
#                                                 TEXT
# 0  1\n\nIN THE SUPREME COURT OF THE UNITED STATES...
# 1  1\n\nIN THE SUPREME COURT OF THE UNITED STATES...
# 2  1\n\nIN THE SUPREME COURT OF THE UNITED STATES...

# %%
# Define function.
def cut_unnecessary_text(df):
    '''This function cuts low information text from transcript.'''
    # First chop off the caption ('PROCEEDINGS' or 'P R O C E E D I N G S')
    capture_string = r'P\s?R\s?O\s?C\s?E\s?E\s?D\s?I\s?N\s?G\s?S([\s\S]*\Z)'
    df['TEXT'] = df['TEXT'].str.extract(capture_string,
                                        expand=False,
                                        flags=re.MULTILINE)
    # First we specify the patterns we don't want
    patterns_to_cut = [

        # Cut carriage returns and form feeds because f*** those guys.
        r'[\r\f]',

        # Remove tables at end ##:## 4 within no more than 100 chars of Alderson
        (r'\s*' +
         r'Alderson Reporting Company' + 
         # period because a.m. messes it up.
         r'[\s\S.]{0,75}\d?\d:\d?\d' * 3 +
         r'[\s\S]*' +
         r'\Z'),
        
        # Remove [2004 - 2005] footer
        r'1111 14th[\s\S]{0,100}20005',
        
        # Remove [2006 - 2016] header/footer unofficial
        r'Alderson[\s\S]{0,100}Review',

        # Remove [2006 - 2016] header/footer official
        r'Alderson[\s\S]{0,100}[oO]fficial',
    
        # Remove Genric Alderson 
        r'Alderson Reporting Company',

        # Cut court reporter annotations
        r'[(\[][\s\S]{0,100}[)\]]',

        # Cut line numbers, page numbers, all other low-information numbers
        r'[0-9]',

        # Cut PAGE
        r'[Pp][Aa][Gg][Ee]',

    ]    

    # Replace above patterns with empty space.
    for pattern in patterns_to_cut:
        df['TEXT'] = df['TEXT'].str.replace(pat=pattern,
                                            repl='',
                                            flags=re.MULTILINE)
    return df


# Run function.
arg_df = cut_unnecessary_text(arg_df)

# %%
# Show df for clarity
arg_df.head(3)
# Out:
#                                     CASE   DOCKET ARGUMENT_YEAR  \
# 0          Hudson v. Michigan (Reargued)  04-1360          2005
# 1                 Washington v. Recuenco    05-83          2005
# 2  Burlington N. & S. F. R. Co. v. White   05-259          2005
#
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH  \
# 0  /home/theo/.scoap/04-1360/argument.pdf
# 1    /home/theo/.scoap/05-83/argument.pdf
# 2   /home/theo/.scoap/05-259/argument.pdf
#
#                                                 TEXT
# 0  \n\n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe...
# 1  \n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'l...
# 2  \n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'll he...

# %%
# Define function.
def create_heading_columns(df):
    '''This function finds the section headings for each case'''
    # Create Petitioner oral argument heading col
    pet_arg_pattern = ''.join([r'(',
                               r'ORAL ARGUMENT[\S\s]{,200}',
                               r'(?:PETITIONER|APPELLANT)S?',
                               # As appointed by this court optional
                               r'(?:[\S\s]{,50}THIS COURT)?',
                               r')'])
    df['PET_ARG_HEADING'] = df['TEXT'].str.extract(pet_arg_pattern,
                                                   expand=False,
                                                   flags=re.MULTILINE).fillna('')
        
    # Create Respondent oral argument heading col
    res_arg_pattern = ''.join([r'(ORAL ARGUMENT[\S\s]{,200}',
                               r'(?:RESPONDENT|APPELLEE)S?',
                               # As appointed by this court optional
                               r'(?:[\S\s]{,50}THIS COURT)?',
                               r')'])
    df['RES_ARG_HEADING'] = df['TEXT'].str.extract(res_arg_pattern,
                                                   expand=False,
                                                   flags=re.MULTILINE).fillna('')
    
    # Create Petitioner rebuttal heading col
    pet_reb_pattern = ''.join([r'(REBUTTAL ARGUMENT[\S\s]{,200}',
                               r'(?:PETITIONER|APPELLANT)S?',
                               # As appointed by this court optional
                               r'(?:[\S\s]{,50}THIS COURT)?',
                               r')'])
    df['PET_REB_HEADING'] = df['TEXT'].str.extract(pet_reb_pattern,
                                                   expand=False,
                                                   flags=re.MULTILINE).fillna('')
    
    return df


# TODO:
# IN ##-#### optional ... r'(?:[\S\s]{,10}IN[\S\s]{,5}-)?'

# Run function
arg_df = create_heading_columns(arg_df).fillna('')

# %%
# Define function.
def extract_petitioner_arg(df):
    '''Pulls out petitioner argument using section headers.'''

    # Create extraction (between pet arg heading and res arg heading)
    df['PET_ARG_REGEX'] = df.apply(lambda row: ''.join([row['PET_ARG_HEADING'],
                                                        r'([\S\s]*?)',
                                                        r'(?:ORAL)']),
                                   axis=1)
    
    # Extract and create petitioner argument column
    df['PETITIONER_ARGUMENT'] = df.apply(lambda row: re.findall(row['PET_ARG_REGEX'],
                                                                row['TEXT'],
                                                                flags=re.MULTILINE),
                                         axis=1)
    
    # If no match, empty string. Else, take match's.
    df['PETITIONER_ARGUMENT'] = df['PETITIONER_ARGUMENT'].map(lambda matches: ''.join(matches))
    
    return df


# Run function.
arg_df = extract_petitioner_arg(arg_df)

# %%
# Define function.
def extract_respondent_arg(df):
    '''Pulls out respondent argument using previously generated section heads.'''
    # Get respondent argument (between res arg heading and pet reb heading)
    df['RES_ARG_REGEX'] = df.apply(lambda row: ''.join([row['RES_ARG_HEADING'],
                                                        r'([\S\s]*?)',
                                                        r'(?:REBUTTAL)|(?:ORAL)']),
                                   axis=1)

    df['RESPONDENT_ARGUMENT'] = df.apply(lambda row: re.findall(row['RES_ARG_REGEX'],
                                                                row['TEXT'],
                                                                flags=re.MULTILINE),
                                         axis=1)
    
    # If no match, empty string. Else, take match's.
    df['RESPONDENT_ARGUMENT'] = df['RESPONDENT_ARGUMENT'].map(lambda matches: ''.join(matches))
    
    return df


# Run function.
arg_df = extract_respondent_arg(arg_df)

# %%
# Define function.
def extract_petitioner_reb(df):
    '''Pulls out petitioner rebuttal using previously generated section heads.'''
    # Get petitioner rebuttal (between pet reb heading and res reb heading)
    df['PET_REB_REGEX'] = df.apply(lambda row: ''.join([row['PET_REB_HEADING'],
                                                        r'([\S\s]*?)',
                                                        r'(?:\Z)']),
                                   axis=1)

    df['PETITIONER_REBUTTAL'] = df.apply(lambda row: re.search(row['PET_REB_REGEX'],
                                                               row['TEXT'],
                                                               flags=re.MULTILINE).group(1),
                                         axis=1)
    
    return df


# Run function.
arg_df = extract_petitioner_reb(arg_df)

# %%
# TODO. If transcript omits info (e.g. SAMSUNG/WAXMAN 15-777), no match.
len(arg_df)
# Out:
# 854

# %%
# Show dataframe for clarity
arg_df.head(3)
# Out:
#                                     CASE   DOCKET ARGUMENT_YEAR  \
# 0          Hudson v. Michigan (Reargued)  04-1360          2005
# 1                 Washington v. Recuenco    05-83          2005
# 2  Burlington N. & S. F. R. Co. v. White   05-259          2005
#
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH  \
# 0  /home/theo/.scoap/04-1360/argument.pdf
# 1    /home/theo/.scoap/05-83/argument.pdf
# 2   /home/theo/.scoap/05-259/argument.pdf
#
#                                                 TEXT  \
# 0  \n\n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe...
# 1  \n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'l...
# 2  \n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'll he...
#
#                                      PET_ARG_HEADING  \
# 0  ORAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON BEHA...
# 1  ORAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nON BE...
# 2  ORAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\nON ...
#
#                                      RES_ARG_HEADING  \
# 0  ORAL ARGUMENT OF TIMOTHY A. BAUGHMAN\n\n\n\nON...
# 1  ORAL ARGUMENT OF GREGORY C. LINK\n\n\n\nON BEH...
# 2  ORAL ARGUMENT OF DONALD A. DONATI\n\n\n\nON BE...
#
#                                      PET_REB_HEADING  \
# 0  REBUTTAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON ...
# 1  REBUTTAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nO...
# 2  REBUTTAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\...
#
#                                        PET_ARG_REGEX  \
# 0  ORAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON BEHA...
# 1  ORAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nON BE...
# 2  ORAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\nON ...
#
#                                  PETITIONER_ARGUMENT  \
# 0  \n\n\n\n\nMR. MORAN:\n\nMr. Chief Justice, and...
# 1  \n\n\n\n\n\nMR. WHISMAN:\n\nMr. Chief Justice,...
# 2  \n\n\n\n\n\nMR. PHILLIPS:\n\nThank you, Mr. Ch...
#
#                                        RES_ARG_REGEX  \
# 0  ORAL ARGUMENT OF TIMOTHY A. BAUGHMAN\n\n\n\nON...
# 1  ORAL ARGUMENT OF GREGORY C. LINK\n\n\n\nON BEH...
# 2  ORAL ARGUMENT OF DONALD A. DONATI\n\n\n\nON BE...
#
#                                  RESPONDENT_ARGUMENT  \
# 0  \n\n\n\n\n\nMR. BAUGHMAN:\n\nThank you, Mr. Mo...
# 1  \n\n\n\n\nAnd on\n\nMR. LINK:\n\nMr. Chief Jus...
# 2  \n\n\n\n\n\nMR. DONATI:\n\nMr. Chief Justice, ...
#
#                                        PET_REB_REGEX  \
# 0  REBUTTAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON ...
# 1  REBUTTAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nO...
# 2  REBUTTAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\...
#
#                                  PETITIONER_REBUTTAL
# 0  \n\n\n\nMR. MORAN:\n\n\n\nThank you --\n\nCHIE...
# 1  \n\n\n\nJUSTICE SCALIA:\n\nThank you, counsel....
# 2  \n\n\n\nMR. PHILLIPS:\n\nThank you, Mr. Chief ...

# %%
bak = arg_df.copy()

# %%
def split_arguments(df):
    '''Split argument into a series of comments.'''    
    # Must be double quote because raw string addressing ' for O'Connor
    comment_pattern = r"([A-Z.'\s]{5,25}:\s[\s\S]*?)(?=[A-Z'.\s]{5,25}[:\Z])"
    for column in ['PETITIONER_ARGUMENT',
                   'RESPONDENT_ARGUMENT',
                   'PETITIONER_REBUTTAL']:
        # We only want periods in the middle of names.
        df[column] = df[column].str.findall(comment_pattern)
    return df


# Run functions
arg_df = split_arguments(arg_df)

# %%
def tuplify_cell(cell_value):
    '''Helper function for tuplify_argument().'''
    return_value = []
    for comment in cell_value:
        justice, _, comment = comment.partition(':')
        return_value.append(tuple([justice.replace('.', '').strip(),
                                   comment.strip()]))
    return return_value


def tuplify_arguments(df):
    '''Turn question strings into (justice, text) tuples.'''
    for column in ['PETITIONER_ARGUMENT',
                   'RESPONDENT_ARGUMENT',
                   'PETITIONER_REBUTTAL']:
        df[column] = df[column].map(tuplify_cell)
    return df.fillna('')


# Run function
arg_df = tuplify_arguments(arg_df)

# %%
def condense_cell(cell_value):
    '''Helper function for condense_argument().'''
    return_dict = {}
    for input_tuple in cell_value:
        justice, comment = input_tuple
        try:
            return_dict[justice].append(comment)
        except KeyError:
            return_dict[justice] = [comment]
    return return_dict


def condense_arguments(df):
    '''Turn args into: {'justice': ['comment 1', 'comment 2']}'''
    for column in ['PETITIONER_ARGUMENT',
                   'RESPONDENT_ARGUMENT',
                   'PETITIONER_REBUTTAL']:
        df[column] = df[column].map(condense_cell)
    return df


arg_df = condense_arguments(arg_df)

# %%
arg_df.head(3)
# Out:
#                                     CASE   DOCKET ARGUMENT_YEAR  \
# 0          Hudson v. Michigan (Reargued)  04-1360          2005
# 1                 Washington v. Recuenco    05-83          2005
# 2  Burlington N. & S. F. R. Co. v. White   05-259          2005
#
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH  \
# 0  /home/theo/.scoap/04-1360/argument.pdf
# 1    /home/theo/.scoap/05-83/argument.pdf
# 2   /home/theo/.scoap/05-259/argument.pdf
#
#                                                 TEXT  \
# 0  \n\n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe...
# 1  \n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'l...
# 2  \n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'll he...
#
#                                      PET_ARG_HEADING  \
# 0  ORAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON BEHA...
# 1  ORAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nON BE...
# 2  ORAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\nON ...
#
#                                      RES_ARG_HEADING  \
# 0  ORAL ARGUMENT OF TIMOTHY A. BAUGHMAN\n\n\n\nON...
# 1  ORAL ARGUMENT OF GREGORY C. LINK\n\n\n\nON BEH...
# 2  ORAL ARGUMENT OF DONALD A. DONATI\n\n\n\nON BE...
#
#                                      PET_REB_HEADING  \
# 0  REBUTTAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON ...
# 1  REBUTTAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nO...
# 2  REBUTTAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\...
#
#                                        PET_ARG_REGEX  \
# 0  ORAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON BEHA...
# 1  ORAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nON BE...
# 2  ORAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\nON ...
#
#                                  PETITIONER_ARGUMENT  \
# 0  {'JUSTICE SCALIA': ['Counsel, what -- what do ...
# 1  {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 2  {'JUSTICE SCALIA': ['But  has the language and...
#
#                                        RES_ARG_REGEX  \
# 0  ORAL ARGUMENT OF TIMOTHY A. BAUGHMAN\n\n\n\nON...
# 1  ORAL ARGUMENT OF GREGORY C. LINK\n\n\n\nON BEH...
# 2  ORAL ARGUMENT OF DONALD A. DONATI\n\n\n\nON BE...
#
#                                  RESPONDENT_ARGUMENT  \
# 0  {'JUSTICE SCALIA': ['I'd be happy to argue tha...
# 1  {'JUSTICE SCALIA': ['It didn't
# It said the
#
# Ho...
# 2  {'JUSTICE SCALIA': ['I'm -- I'm a supervisor, ...
#
#                                        PET_REB_REGEX  \
# 0  REBUTTAL ARGUMENT OF DAVID A. MORAN\n\n\n\nON ...
# 1  REBUTTAL ARGUMENT OF JAMES M. WHISMAN\n\n\n\nO...
# 2  REBUTTAL ARGUMENT OF CARTER G. PHILLIPS\n\n\n\...
#
#                                  PETITIONER_REBUTTAL
# 0  {'CHIEF JUSTICE ROBERTS': ['You think there --...
# 1  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...
# 2  {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...

# %%
# Define function creating secondary df.
def create_scdb_df():
    '''Download data frome the SCDB and instantiate dataframe.'''

    # If we've already download database, just load.
    if os.path.exists(SCDB_CSV_PATH):
        pass
    else:
        # Get data
        r = requests.get(SCDB_CSV_DOWNLOAD_LINK, stream=True)
        with open(SCDB_ZIP_PATH, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024): 
                if chunk:
                    f.write(chunk)
        # Unzip context manager
        with zipfile.ZipFile(SCDB_ZIP_PATH) as zip_file:
            # Read data context manager
            with zip_file.open(SCDB_CSV_NAME) as pseudo_file:
                data = pseudo_file.read()
                # Write data with context manager and write to csv.
                with open(SCDB_CSV_PATH, 'wb+') as f:
                    f.write(data)
    
    # Now create dataframe from csv.
    case_df = pd.read_csv(SCDB_CSV_PATH, encoding='latin-1')

    return case_df


# Run df.
case_df = create_scdb_df()

# %%
# Show case dataframe for clarity
case_df.head(3)
# Out:
#      caseId     docketId    caseIssuesId                voteId dateDecision  \
# 0  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-01   11/18/1946
# 1  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-02   11/18/1946
# 2  1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01-03   11/18/1946
#
#    decisionType      usCite      sctCite      ledCite             lexisCite  \
# 0             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 1             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
# 2             1  329 U.S. 1  67 S. Ct. 6  91 L. Ed. 3  1946 U.S. LEXIS 1724
#
#         ...         majVotes  minVotes justice justiceName vote opinion  \
# 0       ...                8         1      86    HHBurton  2.0     1.0
# 1       ...                8         1      84   RHJackson  1.0     1.0
# 2       ...                8         1      81   WODouglas  1.0     1.0
#
#   direction  majority  firstAgreement  secondAgreement
# 0       1.0       1.0             NaN              NaN
# 1       2.0       2.0             NaN              NaN
# 2       2.0       2.0             NaN              NaN
#
# [3 rows x 61 columns]

# %%
cut_arg_df = arg_df[['DOCKET',
                     'CASE', 
                     'PETITIONER_ARGUMENT',
                     #'RESPONDENT_ARGUMENT',
                     'PETITIONER_REBUTTAL']]

cut_arg_df.head(3)
# Out:
#     DOCKET                                   CASE  \
# 0  04-1360          Hudson v. Michigan (Reargued)
# 1    05-83                 Washington v. Recuenco
# 2   05-259  Burlington N. & S. F. R. Co. v. White
#
#                                  PETITIONER_ARGUMENT  \
# 0  {'JUSTICE SCALIA': ['Counsel, what -- what do ...
# 1  {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 2  {'JUSTICE SCALIA': ['But  has the language and...
#
#                                  PETITIONER_REBUTTAL
# 0  {'CHIEF JUSTICE ROBERTS': ['You think there --...
# 1  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...
# 2  {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...

# %%
cut_case_df = case_df[['docket', 'majority', 'partyWinning', 'justiceName']]
cut_case_df.columns = ['DOCKET', 'majority', 'partyWinning', 'JUSTICE']

cut_case_df.head(3)
# Out:
#   DOCKET  majority  partyWinning    JUSTICE
# 0     24       1.0           1.0   HHBurton
# 1     24       2.0           1.0  RHJackson
# 2     24       2.0           1.0  WODouglas

# %%
# Join case_df and arg_df to create joint dataframe jdf.
jdf = pd.merge(cut_arg_df,
               cut_case_df,
               how='left',
               on='DOCKET')

# Drop (Reargued) because it creates dupes.
contains_reargue = jdf['CASE'].str.contains('Reargue')
jdf = jdf[~contains_reargue]

# %%
# Show joint dataframe for clarity (all tail end will be np.NaN)
jdf.head(3)
# Out:
#    DOCKET                    CASE  \
# 9   05-83  Washington v. Recuenco
# 10  05-83  Washington v. Recuenco
# 11  05-83  Washington v. Recuenco
#
#                                   PETITIONER_ARGUMENT  \
# 9   {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 10  {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 11  {'JUSTICE SCALIA': ['Was deadly weapon still a...
#
#                                   PETITIONER_REBUTTAL  majority  partyWinning  \
# 9   {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0           1.0
# 10  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       1.0           1.0
# 11  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0           1.0
#
#       JUSTICE
# 9   JGRoberts
# 10  JPStevens
# 11    AScalia

# %%
'''

From documentation on 'partyWinning' column:

http://scdb.wustl.edu/documentation.php?var=partyWinning

0: no favorable disposition for petitioning party apparent
1: petitioning party received a favorable disposition
2: favorable disposition for petitioning party unclear 

We want to be able to separate those who won from those who did not
win. Consequently, we drop all cases where the decision was
ambiguous, or the winner was not apparent.

We then convert the 0 to False and the 1 to True, which gives
us a True/False 'PETITIONER_WINS' column.

PETITIONER_WINS
0 -> False
1 -> True

If the petitioner wins, it is because it was the decision of the
majority of the court. We can accurately describe the nature of this
column as 'PETITIONER_WINS_MAJORITY'.

'''

jdf = jdf[jdf['partyWinning'] != 2.0].copy()
jdf['PETITIONER_WINS_MAJORITY'] = jdf['partyWinning'].astype(bool)

# %%
'''

From documentation on 'majority' columns:

http://scdb.wustl.edu/documentation.php?var=majority

1: dissent
2: majority 

We want to convert this into a 'VOTED_WITH_MAJORITY' column.
To do this we subtract one from each and every value so that
dissent becomes 0 and majority becomes 1.

majority
0: dissent (result 1 - 1)
1: majority (result from 2 - 1)

Then we convert the 0 to False and 1 to True, so that we have a
'VOTED_WITH_MAJORITY' column.

VOTED_WITH_MAJORITY
0 -> False
1 -> True

'''

jdf['majority_minus_one'] = jdf['majority'] - 1
jdf['VOTED_WITH_MAJORITY'] = jdf['majority_minus_one'].astype(bool)
jdf
# Out:
#        DOCKET                                               CASE  \
# 9       05-83                             Washington v. Recuenco
# 10      05-83                             Washington v. Recuenco
# 11      05-83                             Washington v. Recuenco
# 12      05-83                             Washington v. Recuenco
# 13      05-83                             Washington v. Recuenco
# 14      05-83                             Washington v. Recuenco
# 15      05-83                             Washington v. Recuenco
# 16      05-83                             Washington v. Recuenco
# 17      05-83                             Washington v. Recuenco
# 18     05-259              Burlington N. & S. F. R. Co. v. White
# 19     05-259              Burlington N. & S. F. R. Co. v. White
# 20     05-259              Burlington N. & S. F. R. Co. v. White
# 21     05-259              Burlington N. & S. F. R. Co. v. White
# 22     05-259              Burlington N. & S. F. R. Co. v. White
# 23     05-259              Burlington N. & S. F. R. Co. v. White
# 24     05-259              Burlington N. & S. F. R. Co. v. White
# 25     05-259              Burlington N. & S. F. R. Co. v. White
# 26     05-259              Burlington N. & S. F. R. Co. v. White
# 27     05-352                    United States v. Gonzalez-Lopez
# 28     05-352                    United States v. Gonzalez-Lopez
# 29     05-352                    United States v. Gonzalez-Lopez
# 30     05-352                    United States v. Gonzalez-Lopez
# 31     05-352                    United States v. Gonzalez-Lopez
# 32     05-352                    United States v. Gonzalez-Lopez
# 33     05-352                    United States v. Gonzalez-Lopez
# 34     05-352                    United States v. Gonzalez-Lopez
# 35     05-352                    United States v. Gonzalez-Lopez
# 36    05-5992                            Zedner v. United States
# 37    05-5992                            Zedner v. United States
# 38    05-5992                            Zedner v. United States
# ...       ...                                                ...
# 7147  15-1406               Goodyear Tire & Rubber Co. v. Haeger
# 7148   15-827      Endrew F. v. Douglas County School Dist. RE-1
# 7149  15-1498                                    Lynch v. Dimaya
# 7150   16-348                    Midland Funding, LLC v. Johnson
# 7151  15-1293                                         Lee v. Tam
# 7152  15-1358                                   Ziglar v. Abbasi
# 7153  15-8544                           Beckles v. United States
# 7154   15-797                                     Moore v. Texas
# 7155  15-1204                              Jennings v. Rodriguez
# 7156   15-680    Bethune-Hill v. Virginia State Bd. of Elections
# 7157  15-1262                                  McCrory v. Harris
# 7158  14-1538           Life Technologies Corp. v. Promega Corp.
# 7159   15-649                   Czyzewski v. Jevic Holding Corp.
# 7160   15-497                  Fry v. Napoleon Community Schools
# 7161   15-866     Star Athletica, L.L.C. v. Varsity Brands, Inc.
# 7162   15-513  State Farm Fire & Casualty Co. v. United State...
# 7163   15-927  SCA Hygiene Products Aktiebolag v. First Quali...
# 7164   15-423  Bolivarian Republic of Venezuela v. Helmerich ...
# 7165  15-1251                           NLRB v. SW General, Inc.
# 7166  15-1111                     Bank of America Corp. v. Miami
# 7167  14-1055                      Lightfoot v. Cendant Mortgage
# 7168  15-1191                           Lynch v. Morales-Santana
# 7169   15-537                   Bravo-Fernandez v. United States
# 7170  15-5991                              Shaw v. United States
# 7171   15-628                            Salman v. United States
# 7172  15-8049                                      Buck v. Davis
# 7173  14-9496                                   Manuel v. Joliet
# 7174   15-777             Samsung Electronics Co., v. Apple Inc.
# 7175   15-606                         Pena-Rodriguez v. Colorado
# 7176  15-7250                          Manrique v. United States
#
#                                     PETITIONER_ARGUMENT  \
# 9     {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 10    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 11    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 12    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 13    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 14    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 15    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 16    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 17    {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 18    {'JUSTICE SCALIA': ['But  has the language and...
# 19    {'JUSTICE SCALIA': ['But  has the language and...
# 20    {'JUSTICE SCALIA': ['But  has the language and...
# 21    {'JUSTICE SCALIA': ['But  has the language and...
# 22    {'JUSTICE SCALIA': ['But  has the language and...
# 23    {'JUSTICE SCALIA': ['But  has the language and...
# 24    {'JUSTICE SCALIA': ['But  has the language and...
# 25    {'JUSTICE SCALIA': ['But  has the language and...
# 26    {'JUSTICE SCALIA': ['But  has the language and...
# 27    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 28    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 29    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 30    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 31    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 32    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 33    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 34    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 35    {'JUSTICE SCALIA': ['When did -- when did we
#
# ...
# 36    {'JUSTICE SCALIA': ['If the
#
# The delay -- the ...
# 37    {'JUSTICE SCALIA': ['If the
#
# The delay -- the ...
# 38    {'JUSTICE SCALIA': ['If the
#
# The delay -- the ...
# ...                                                 ...
# 7147  {'JUSTICE KAGAN': ['And,
#
# Mr. Bergeron, could ...
# 7148  {'MR FISHER': ['Mr. Chief Justice, and may it
# ...
# 7149  {'MR KNEEDLER': ['Mr. Chief Justice, and may i...
# 7150  {'JUSTICE KAGAN': ['Before you get to that
#
#
#
# ...
# 7151  {'MR STEWART': ['Thank you, Mr. Chief Justice,...
# 7152  {'GENERAL GERSHENGORN': ['Mr. Chief Justice, a...
# 7153  {'CHIEF JUSTICE ROBERTS': ['right?
#
#
#
# of depar...
# 7154  {'JUSTICE KAGAN': ['', 'We wouldn't need that,...
# 7155  {'JUSTICE KAGAN': ['sorry', 'I was going to sh...
# 7156  {'JUSTICE KAGAN': ['Mr. Elias, could I make su...
# 7157  {'JUSTICE KAGAN': ['Mr. Clement, that passage
# ...
# 7158  {'JUSTICE KAGAN': ['that from?
#
# Where -- where...
# 7159  {'JUSTICE KAGAN': ['', 'isn't mentioned somepl...
# 7160  {'JUSTICE KAGAN': ['Could -- could I ask about...
# 7161  {'JUSTICE KAGAN': ['How is your argument
#
#
#
# di...
# 7162  {'JUSTICE KAGAN': ['', '', 'couple of times --...
# 7163  {'JUSTICE SOTOMAYOR': ['They have some cases
#
# ...
# 7164  {'JUSTICE KAGAN': ['In the last provision of
#
# ...
# 7165  {'GENERAL GERSHENGORN': ['Mr. Chief Justice, a...
# 7166  {'MR KATYAL': ['Thank you, Mr. Chief Justice,
# ...
# 7167  {'CHIEF JUSTICE ROBERTS': ['So a dozen
#
# You do...
# 7168  {'MR KNEEDLER': ['Mr. Chief Justice, and may i...
# 7169  {'JUSTICE KAGAN': ['Ms. Blatt, it does seem to...
# 7170  {'JUSTICE KAGAN': ['So, Ms. Bell, I guess -- I...
# 7171  {'JUSTICE KAGAN': ['The only case
#
# Ms. Shapiro...
# 7172  {'JUSTICE KAGAN': ['But, for example, last yea...
# 7173  {'JUSTICE KAGAN': ['Mr. Eisenhammer, why shoul...
# 7174  {'JUSTICE KAGAN': ['Could I really quickly mak...
# 7175  {'MR FISHER': ['Mr. Chief Justice, and may it
# ...
# 7176  {'JUSTICE KAGAN': ['Mr. Rashkind --', 'Mr. Ras...
#
#                                     PETITIONER_REBUTTAL  majority  \
# 9     {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 10    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       1.0
# 11    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 12    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 13    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 14    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 15    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       1.0
# 16    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 17    {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0
# 18    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 19    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 20    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 21    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 22    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 23    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 24    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 25    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 26    {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       2.0
# 27    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       2.0
# 28    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       2.0
# 29    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       1.0
# 30    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       2.0
# 31    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       1.0
# 32    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       2.0
# 33    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       2.0
# 34    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       1.0
# 35    {'JUSTICE STEVENS': ['Well, Mr. Dreeben, do yo...       1.0
# 36    {'JUSTICE SCALIA': ['People can't
#
# And the
#
# I ...       2.0
# 37    {'JUSTICE SCALIA': ['People can't
#
# And the
#
# I ...       2.0
# 38    {'JUSTICE SCALIA': ['People can't
#
# And the
#
# I ...       2.0
# ...                                                 ...       ...
# 7147  {'JUSTICE SOTOMAYOR': ['There is something --
# ...       NaN
# 7148  {'MR FISHER': ['Three points, Your Honors.
#
# Tw...       NaN
# 7149  {'MR KNEEDLER': ['First, we explained in our o...       NaN
# 7150  {'MR SHANMUGAM': ['Thank you,
#
#
#
#
#
#
# Mr. Chief ...       NaN
# 7151  {'MR STEWART': ['Let make three quick points.
# ...       NaN
# 7152  {'GENERAL GERSHENGORN': ['But if
#
# Thank you, M...       NaN
# 7153  {'MS BERGMANN': ['I'd like to make -- start
#
# w...       NaN
# 7154  {'CHIEF JUSTICE ROBERTS': [''], 'MR SLOAN': ['...       NaN
# 7155  {'GENERAL GERSHENGORN': ['Justice.
#
# Thank you,...       NaN
# 7156  {'MR ELIAS': ['Mr. Chief Justice, and may it
#
# ...       NaN
# 7157  {'MR CLEMENT': ['A few points in rebuttal.
#
#
#
# ...       NaN
# 7158  {'MR PHILLIPS': ['Thank you, Mr. Chief Justice...       NaN
# 7159  {'MS SPINELLI': ['Respondents' position fails
# ...       NaN
# 7160  {'MR BAGENSTOS': ['Thank you, Mr. Chief
#
# Justi...       NaN
# 7161  {'JUSTICE KAGAN': ['Well, can't the school jus...       NaN
# 7162  {'MS SULLIVAN': ['When you write the opinion
#
# ...       NaN
# 7163  {'JUSTICE KAGAN': ['Well, Mr. Black, I take it...       NaN
# 7164  {'MS STETSON': ['Ms. Carroll describes this
#
# c...       NaN
# 7165  {'GENERAL GERSHENGORN': ['Justice.
#
# Thank you,...       NaN
# 7166  {'MR KATYAL': ['Four points, Your Honor.
#
#
#
# Fi...       NaN
# 7167  {'JUSTICE KAGAN': ['personal jurisdiction.
#
#
#
# ...       NaN
# 7168  {'MR KNEEDLER': ['Thank you, Mr. Chief Justice...       NaN
# 7169  {'MS BLATT': ['Thanks.
#
# Thank you, Mr. Chief
#
# ...       NaN
# 7170  {'MS BELL': ['Thank you, Mr. Chief Justice.
#
#
# ...       NaN
# 7171  {'CHIEF JUSTICE ROBERTS': ['Finish your
#
# sente...       NaN
# 7172  {'MS SWARNS': ['This Court has long recognized...       NaN
# 7173  {'MR EISENHAMMER': ['Thank you.
#
#
#
# Just to ans...       NaN
# 7174  {'JUSTICE BREYER': ['The problem, of course, i...       NaN
# 7175  {'MR FISHER': ['Thank you.
#
# I'd like to make
#
# ...       NaN
# 7176  {'MR RASHKIND': ['Thank you, Your Honor.
#
#
#
# If...       NaN
#
#       partyWinning     JUSTICE PETITIONER_WINS_MAJORITY  majority_minus_one  \
# 9              1.0   JGRoberts                     True                 1.0
# 10             1.0   JPStevens                     True                 0.0
# 11             1.0     AScalia                     True                 1.0
# 12             1.0   AMKennedy                     True                 1.0
# 13             1.0    DHSouter                     True                 1.0
# 14             1.0     CThomas                     True                 1.0
# 15             1.0  RBGinsburg                     True                 0.0
# 16             1.0    SGBreyer                     True                 1.0
# 17             1.0     SAAlito                     True                 1.0
# 18             0.0   JGRoberts                    False                 1.0
# 19             0.0   JPStevens                    False                 1.0
# 20             0.0     AScalia                    False                 1.0
# 21             0.0   AMKennedy                    False                 1.0
# 22             0.0    DHSouter                    False                 1.0
# 23             0.0     CThomas                    False                 1.0
# 24             0.0  RBGinsburg                    False                 1.0
# 25             0.0    SGBreyer                    False                 1.0
# 26             0.0     SAAlito                    False                 1.0
# 27             0.0   JPStevens                    False                 1.0
# 28             0.0     AScalia                    False                 1.0
# 29             0.0   AMKennedy                    False                 0.0
# 30             0.0    DHSouter                    False                 1.0
# 31             0.0     CThomas                    False                 0.0
# 32             0.0  RBGinsburg                    False                 1.0
# 33             0.0    SGBreyer                    False                 1.0
# 34             0.0   JGRoberts                    False                 0.0
# 35             0.0     SAAlito                    False                 0.0
# 36             1.0   JPStevens                     True                 1.0
# 37             1.0     AScalia                     True                 1.0
# 38             1.0   AMKennedy                     True                 1.0
# ...            ...         ...                      ...                 ...
# 7147           NaN         NaN                     True                 NaN
# 7148           NaN         NaN                     True                 NaN
# 7149           NaN         NaN                     True                 NaN
# 7150           NaN         NaN                     True                 NaN
# 7151           NaN         NaN                     True                 NaN
# 7152           NaN         NaN                     True                 NaN
# 7153           NaN         NaN                     True                 NaN
# 7154           NaN         NaN                     True                 NaN
# 7155           NaN         NaN                     True                 NaN
# 7156           NaN         NaN                     True                 NaN
# 7157           NaN         NaN                     True                 NaN
# 7158           NaN         NaN                     True                 NaN
# 7159           NaN         NaN                     True                 NaN
# 7160           NaN         NaN                     True                 NaN
# 7161           NaN         NaN                     True                 NaN
# 7162           NaN         NaN                     True                 NaN
# 7163           NaN         NaN                     True                 NaN
# 7164           NaN         NaN                     True                 NaN
# 7165           NaN         NaN                     True                 NaN
# 7166           NaN         NaN                     True                 NaN
# 7167           NaN         NaN                     True                 NaN
# 7168           NaN         NaN                     True                 NaN
# 7169           NaN         NaN                     True                 NaN
# 7170           NaN         NaN                     True                 NaN
# 7171           NaN         NaN                     True                 NaN
# 7172           NaN         NaN                     True                 NaN
# 7173           NaN         NaN                     True                 NaN
# 7174           NaN         NaN                     True                 NaN
# 7175           NaN         NaN                     True                 NaN
# 7176           NaN         NaN                     True                 NaN
#
#      VOTED_WITH_MAJORITY
# 9                   True
# 10                 False
# 11                  True
# 12                  True
# 13                  True
# 14                  True
# 15                 False
# 16                  True
# 17                  True
# 18                  True
# 19                  True
# 20                  True
# 21                  True
# 22                  True
# 23                  True
# 24                  True
# 25                  True
# 26                  True
# 27                  True
# 28                  True
# 29                 False
# 30                  True
# 31                 False
# 32                  True
# 33                  True
# 34                 False
# 35                 False
# 36                  True
# 37                  True
# 38                  True
# ...                  ...
# 7147                True
# 7148                True
# 7149                True
# 7150                True
# 7151                True
# 7152                True
# 7153                True
# 7154                True
# 7155                True
# 7156                True
# 7157                True
# 7158                True
# 7159                True
# 7160                True
# 7161                True
# 7162                True
# 7163                True
# 7164                True
# 7165                True
# 7166                True
# 7167                True
# 7168                True
# 7169                True
# 7170                True
# 7171                True
# 7172                True
# 7173                True
# 7174                True
# 7175                True
# 7176                True
#
# [7132 rows x 10 columns]

# %%
'''

We can determine whether a petitioner won over a specific justice based on:

1. Whether the petitioner won over a majority, and
2. Whether the specific justice was a part of that majority.

If the answer to both of these questions is the same (that is, either
both the answers are Yes or both the answers are no), then the
petitioner won over the justice.

Logically:

    P_WINS_MAJ,  J_VOTES_MAJ = P_WINS_J
    
        If petitioner wins majority and justice voted with majority, the petitioner won over the justice

    P_WINS_MAJ, ~J_VOTES_MAJ = P_LOSES_J
    
        If petitioner wins majority and justice NOT a part of the majority, petitioner did not win justice

   ~P_WINS_MAJ,  J_VOTES_MAJ = P_LOSES_J
   
        If petitioner does NOT win majority and justice voted in majority, petitioner did not win justice

   ~P_WINS_MAJ,  ~J_VOTES_MAJ = P_WINS_J
   
        If petitioner does NOT win majority and justice voted NOT in majority, petitioner won justice


'''

def determine_vote(row):
    # If petitioner wins majority
    if row['PETITIONER_WINS_MAJORITY']:
        # Pet wins majority AND justice voted with majority
        if row['VOTED_WITH_MAJORITY']:
            return True
        # Pet wins majority AND justice voted against majority
        else:
            return False
    # If petitioner loses majority
    else:
        # Pet loses majority AND justice voted with majority
        if row['VOTED_WITH_MAJORITY']:
            return False
        # Pet loses majority AND justice voted against majority
        else:
            return True

# Voted with majority
jdf['VOTED_FOR_PETITIONER'] = jdf.apply(determine_vote, axis=1)

# %%
jdf.head(3)
# Out:
#    DOCKET                    CASE  \
# 9   05-83  Washington v. Recuenco
# 10  05-83  Washington v. Recuenco
# 11  05-83  Washington v. Recuenco
#
#                                   PETITIONER_ARGUMENT  \
# 9   {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 10  {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 11  {'JUSTICE SCALIA': ['Was deadly weapon still a...
#
#                                   PETITIONER_REBUTTAL  majority  partyWinning  \
# 9   {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0           1.0
# 10  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       1.0           1.0
# 11  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...       2.0           1.0
#
#       JUSTICE PETITIONER_WINS_MAJORITY  majority_minus_one  \
# 9   JGRoberts                     True                 1.0
# 10  JPStevens                     True                 0.0
# 11    AScalia                     True                 1.0
#
#    VOTED_WITH_MAJORITY VOTED_FOR_PETITIONER
# 9                 True                 True
# 10               False                False
# 11                True                 True

# %%
# Demonstration dataframe
pd.DataFrame(data={'Justice Votes With Majority': ['Petitioner Wins Justice',
                                                   'Petitioner Loses Justice'], 
                   'Justice Votes Againt  Majority': ['Petitioner Loses Justice',
                                                      'Petitioner Wins Justice']},
             index=['Petitioner Wins Majority',
                    'Petitioner Loses Majority'])
# Out:
#                           Justice Votes Againt  Majority  \
# Petitioner Wins Majority        Petitioner Loses Justice
# Petitioner Loses Majority        Petitioner Wins Justice
#
#                           Justice Votes With Majority
# Petitioner Wins Majority      Petitioner Wins Justice
# Petitioner Loses Majority    Petitioner Loses Justice

# %%
jdf[['CASE', 'JUSTICE', 'VOTED_FOR_PETITIONER']].dropna().head(9)
# Out:
#                       CASE     JUSTICE VOTED_FOR_PETITIONER
# 9   Washington v. Recuenco   JGRoberts                 True
# 10  Washington v. Recuenco   JPStevens                False
# 11  Washington v. Recuenco     AScalia                 True
# 12  Washington v. Recuenco   AMKennedy                 True
# 13  Washington v. Recuenco    DHSouter                 True
# 14  Washington v. Recuenco     CThomas                 True
# 15  Washington v. Recuenco  RBGinsburg                False
# 16  Washington v. Recuenco    SGBreyer                 True
# 17  Washington v. Recuenco     SAAlito                 True

# %%
# Define function.
def trim_columns(df):

    # Trim columns
    df = df[['DOCKET',
             'CASE',
             'JUSTICE',
             'PETITIONER_ARGUMENT',
             #'RESPONDENT_ARGUMENT',
             'PETITIONER_REBUTTAL',
             'VOTED_FOR_PETITIONER']]
    
    return df
    
    
# Run function.
jdf = trim_columns(jdf)

# %%
# Show joint dataframe for clarity.
jdf.head(3)
# Out:
#    DOCKET                    CASE    JUSTICE  \
# 9   05-83  Washington v. Recuenco  JGRoberts
# 10  05-83  Washington v. Recuenco  JPStevens
# 11  05-83  Washington v. Recuenco    AScalia
#
#                                   PETITIONER_ARGUMENT  \
# 9   {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 10  {'JUSTICE SCALIA': ['Was deadly weapon still a...
# 11  {'JUSTICE SCALIA': ['Was deadly weapon still a...
#
#                                   PETITIONER_REBUTTAL VOTED_FOR_PETITIONER
# 9   {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...                 True
# 10  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...                False
# 11  {'JUSTICE SCALIA': ['Thank you, counsel.
#
# Mr. ...                 True

# %%
# Define filter function.
def filter_justice_data(row):
    '''Converts SCDB: RHJackson to JACKSON, which can be pulled from JUSTICE JACKSON.
    
       Then for JACKSON:
             {'JUSTICE JACKSON': [1, 2],
              'JUSTICE ROBERTS': [2, 3]}

       Becomes [1,2] for JACKSON's row.
    
    '''
    
    # Handle SCDB justice names. Based on capitalization
    # which messes up SDOConnor -> Connor
    # SDOConner should be OCONNER, not CONNER.
    if row['JUSTICE'] == 'SDOConnor':
        row['JUSTICE'] = 'SDOconnor'
    # Pick first lower case letter and start name one previous
    lower_mask = [letter.islower() for letter in row['JUSTICE']]
    first_lower = lower_mask.index(True)
    one_prior = first_lower - 1
    row['JUSTICE'] = row['JUSTICE'][one_prior:].upper()
            
    # Handle text columns
    for index in ['PETITIONER_ARGUMENT',
                  #'RESPONDENT_ARGUMENT',
                  'PETITIONER_REBUTTAL',]:
        # Find if justice name is in any of the keys.
        # 1 if found in string, 0 if not.
        # [1, 0, 0] -> True
        justice_represented = any([key.count(row['JUSTICE']) for key in row[index].keys()])
        # If represented, fill with value.
        if justice_represented:
            for key in row[index].keys():
                if row['JUSTICE'] in key and 'JUSTICE' in key:
                    try:
                        row[index] = row[index][key]
                    except TypeError:
                        # Fallback to edit distance?
                        pass
            # If a number has not been placed in the cell, place zero.
            if type(row[index]) == dict:
                row[index] = []
        # If not represented
        else:
            row[index] = []

    return row


# Apply function. If justice is NA ... not yet decided
jdf = (jdf.dropna(subset=['JUSTICE'])
          .apply(filter_justice_data, axis=1))

# %%
# Show joint dataframe for clarity
jdf.head(3)
# Out:
#    DOCKET                    CASE  JUSTICE  \
# 9   05-83  Washington v. Recuenco  ROBERTS
# 10  05-83  Washington v. Recuenco  STEVENS
# 11  05-83  Washington v. Recuenco   SCALIA
#
#                                   PETITIONER_ARGUMENT  \
# 9   [Is the jury given a\n\ncopy of the information?]
# 10  [Could you -- could you\n\n\n\nclarify one thi...
# 11  [Was deadly weapon still an\n\n\n\nenhancement...
#
#                                   PETITIONER_REBUTTAL VOTED_FOR_PETITIONER
# 9   [Although under\n\nAnd those are the\n\n\n\nso...                 True
# 10  [But then we'd have Justice\n\n\n\nScalia's ca...                False
# 11  [Thank you, counsel.\n\nMr. Whisman, can I -- ...                 True

# %%
# Write argument data df to csv
arg_data_csv_path = os.path.join(os.path.expanduser('~'),
                                 '.scoap',
                                 'argument_data.csv')
jdf.to_csv(arg_data_csv_path, encoding='utf-8')

# %%
# Create text_df
text_df = pd.melt(jdf,
                  id_vars=['JUSTICE',
                           'DOCKET',
                           'VOTED_FOR_PETITIONER'],
                  value_vars=['PETITIONER_ARGUMENT',
                              #'RESPONDENT_ARGUMENT',
                              'PETITIONER_REBUTTAL'],
                  var_name='ARG_TYPE',
                  value_name='TEXT')

text_df.head(3)
# Out:
#    JUSTICE DOCKET VOTED_FOR_PETITIONER             ARG_TYPE  \
# 0  ROBERTS  05-83                 True  PETITIONER_ARGUMENT
# 1  STEVENS  05-83                False  PETITIONER_ARGUMENT
# 2   SCALIA  05-83                 True  PETITIONER_ARGUMENT
#
#                                                 TEXT
# 0  [Is the jury given a\n\ncopy of the information?]
# 1  [Could you -- could you\n\n\n\nclarify one thi...
# 2  [Was deadly weapon still an\n\n\n\nenhancement...

# %%
# Define function
def reorient_args(row):
    '''Apply function to make respondent arguments useful.
        
    WARNING: HAND-WAVY, UNSCIENTIFIC FEATURE ENGINEERING BELOW.
    THIS ACTUALLY DECREASES ACCURACY AT PRESENT.
    
    We hamfistedly force the petitioner argument, respondent
    argument, and petitioner rebuttal into a single type of
    entry. Where before we had:
    
    JUSTICE, PET_ARG, PETITIONER_WINS
    JUSTICE, RES_ARG, PETITIONER_WINS
    JUSTICE, PET_REB, PETITIONER_WINS
    
    We will now have:
    
    JUSTICE, PET_ARG, QUESTIONEE_WON
    JUSTICE, RES_ARG, QUESTIONEE_WON
    JUSTICE, PET_REB, QUESTIONEE_WON
    
    The first notable change is that we transform PETITIONER_WINS
    to QUESTIONEE_WON. Previously, we could see what text is
    associated with petitioner wins because target PET_WINS was
    framed in terms of the petitioner. It was previously useless
    for respondent comments. We can get around this by reframing
    the target in terms of "Did the party to whom the justice
    directed the comment win?" instead of "Did the petitioner
    win?".
    
    This requires a big assumption: namely that petitioner
    arguments, respondent arguments, and petitioner rebuttals
    are roughly interchangable. In other words, we are presuming
    that justices will use similar terms i.e. "Your argument is
    bad and you should feel bad" whether it's the petitioner or
    it's the respondent.
    
    This theoretically results in some loss of prediction quality:
    negative words directed at a respondent may be markedly
    different in quality from those directed at a petitioner.
    However, this trades off with the fact that we have uroughly
    doubled the number of samples.
    '''

    vote_pet = row['VOTED_FOR_PETITIONER']
    arg_type = row['ARG_TYPE']
    
    if arg_type in ['RESPONDENT_ARGUMENT']:
        if vote_pet is True:
            voted_for_speaker = False
        else:
            voted_for_speaker = True

    if arg_type in ['PETITIONER_ARGUMENT', 'PETITIONER_REBUTTAL']:
        if vote_pet is True:
            voted_for_speaker = True
        else:
            voted_for_speaker = False

    return voted_for_speaker


# Run function
text_df['QUESTIONEE_WON'] = text_df.apply(reorient_args, axis=1)
text_df
# Out:
#          JUSTICE   DOCKET VOTED_FOR_PETITIONER             ARG_TYPE  \
# 0        ROBERTS    05-83                 True  PETITIONER_ARGUMENT
# 1        STEVENS    05-83                False  PETITIONER_ARGUMENT
# 2         SCALIA    05-83                 True  PETITIONER_ARGUMENT
# 3        KENNEDY    05-83                 True  PETITIONER_ARGUMENT
# 4         SOUTER    05-83                 True  PETITIONER_ARGUMENT
# 5         THOMAS    05-83                 True  PETITIONER_ARGUMENT
# 6       GINSBURG    05-83                False  PETITIONER_ARGUMENT
# 7         BREYER    05-83                 True  PETITIONER_ARGUMENT
# 8          ALITO    05-83                 True  PETITIONER_ARGUMENT
# 9        ROBERTS   05-259                False  PETITIONER_ARGUMENT
# 10       STEVENS   05-259                False  PETITIONER_ARGUMENT
# 11        SCALIA   05-259                False  PETITIONER_ARGUMENT
# 12       KENNEDY   05-259                False  PETITIONER_ARGUMENT
# 13        SOUTER   05-259                False  PETITIONER_ARGUMENT
# 14        THOMAS   05-259                False  PETITIONER_ARGUMENT
# 15      GINSBURG   05-259                False  PETITIONER_ARGUMENT
# 16        BREYER   05-259                False  PETITIONER_ARGUMENT
# 17         ALITO   05-259                False  PETITIONER_ARGUMENT
# 18       STEVENS   05-352                False  PETITIONER_ARGUMENT
# 19        SCALIA   05-352                False  PETITIONER_ARGUMENT
# 20       KENNEDY   05-352                 True  PETITIONER_ARGUMENT
# 21        SOUTER   05-352                False  PETITIONER_ARGUMENT
# 22        THOMAS   05-352                 True  PETITIONER_ARGUMENT
# 23      GINSBURG   05-352                False  PETITIONER_ARGUMENT
# 24        BREYER   05-352                False  PETITIONER_ARGUMENT
# 25       ROBERTS   05-352                 True  PETITIONER_ARGUMENT
# 26         ALITO   05-352                 True  PETITIONER_ARGUMENT
# 27       STEVENS  05-5992                 True  PETITIONER_ARGUMENT
# 28        SCALIA  05-5992                 True  PETITIONER_ARGUMENT
# 29       KENNEDY  05-5992                 True  PETITIONER_ARGUMENT
# ...          ...      ...                  ...                  ...
# 14116      ALITO   14-280                False  PETITIONER_REBUTTAL
# 14117  SOTOMAYOR   14-280                 True  PETITIONER_REBUTTAL
# 14118      KAGAN   14-280                 True  PETITIONER_REBUTTAL
# 14119    ROBERTS  14-7505                 True  PETITIONER_REBUTTAL
# 14120     SCALIA  14-7505                 True  PETITIONER_REBUTTAL
# 14121    KENNEDY  14-7505                 True  PETITIONER_REBUTTAL
# 14122     THOMAS  14-7505                 True  PETITIONER_REBUTTAL
# 14123   GINSBURG  14-7505                 True  PETITIONER_REBUTTAL
# 14124     BREYER  14-7505                 True  PETITIONER_REBUTTAL
# 14125      ALITO  14-7505                False  PETITIONER_REBUTTAL
# 14126  SOTOMAYOR  14-7505                 True  PETITIONER_REBUTTAL
# 14127      KAGAN  14-7505                 True  PETITIONER_REBUTTAL
# 14128    ROBERTS   14-857                 True  PETITIONER_REBUTTAL
# 14129     SCALIA   14-857                 True  PETITIONER_REBUTTAL
# 14130    KENNEDY   14-857                False  PETITIONER_REBUTTAL
# 14131     THOMAS   14-857                False  PETITIONER_REBUTTAL
# 14132   GINSBURG   14-857                False  PETITIONER_REBUTTAL
# 14133     BREYER   14-857                False  PETITIONER_REBUTTAL
# 14134      ALITO   14-857                 True  PETITIONER_REBUTTAL
# 14135  SOTOMAYOR   14-857                False  PETITIONER_REBUTTAL
# 14136      KAGAN   14-857                False  PETITIONER_REBUTTAL
# 14137    ROBERTS   14-840                 True  PETITIONER_REBUTTAL
# 14138     SCALIA   14-840                False  PETITIONER_REBUTTAL
# 14139    KENNEDY   14-840                 True  PETITIONER_REBUTTAL
# 14140     THOMAS   14-840                False  PETITIONER_REBUTTAL
# 14141   GINSBURG   14-840                 True  PETITIONER_REBUTTAL
# 14142     BREYER   14-840                 True  PETITIONER_REBUTTAL
# 14143      ALITO   14-840                 True  PETITIONER_REBUTTAL
# 14144  SOTOMAYOR   14-840                 True  PETITIONER_REBUTTAL
# 14145      KAGAN   14-840                 True  PETITIONER_REBUTTAL
#
#                                                     TEXT QUESTIONEE_WON
# 0      [Is the jury given a\n\ncopy of the information?]           True
# 1      [Could you -- could you\n\n\n\nclarify one thi...          False
# 2      [Was deadly weapon still an\n\n\n\nenhancement...           True
# 3      [On -- on that point, I have\n\n\n\n-- I have ...           True
# 4      [, Now, did you have to prove\n\n\n\nthat beca...           True
# 5                                                     []           True
# 6      [I thought the deadly weapon\n\n\n\n-- the def...          False
# 7                                                     []           True
# 8                                                     []           True
# 9          [It has been endorsed\n\nby the EEOC, though]          False
# 10     [May I ask you this\n\n\n\nhypothetical?\n\n\n...          False
# 11     [But  has the language and\n\n\n\n doesn't.\n\...          False
# 12     [from the forklift forever or a year?\n\n\n\nt...          False
# 13     [Okay, but if that argument\n\nis sound -, Yes...          False
# 14                                                    []          False
# 15     [They say one lunch, but\n\n\n\nnot if there's...          False
# 16     [Well, the answer would be\n\n\n\nbecause Cong...          False
# 17     [But he says, you know, as you\n\nIsn't a chan...          False
# 18     [How do you reconcile your\n\n\n\nposition wit...          False
# 19     [When did -- when did we\n\n\n\nfirst hold tha...          False
# 20     [But, of\n\nWell, that was my -- even\n\n\n\ni...           True
# 21     [It's a\n\nThe only issue in that case\n\n\n\n...          False
# 22                                                    []           True
# 23     [But in this -- in this\n\n\n\ncase, Mr. Dreeb...          False
# 24                                                    []          False
# 25     [Well, but what if --\n\n\n\njust to take an e...           True
# 26     [It's actually easier than\n\nWell, why would ...           True
# 27                                                    []           True
# 28     [If the\n\nThe delay -- the delay was\n\n\n\nn...           True
# 29     [Prior to that time,\nIt couldn't\n\nYou're no...           True
# ...                                                  ...            ...
# 14116                                                 []          False
# 14117                                                 []           True
# 14118                                                 []           True
# 14119                                                 []           True
# 14120                                                 []           True
# 14121                                                 []           True
# 14122                                                 []           True
# 14123                                                 []           True
# 14124                                                 []           True
# 14125                                                 []          False
# 14126                                                 []           True
# 14127                                                 []           True
# 14128                                                 []           True
# 14129                                                 []           True
# 14130                                                 []          False
# 14131                                                 []          False
# 14132                                                 []          False
# 14133                                                 []          False
# 14134                                                 []           True
# 14135                                                 []          False
# 14136                                                 []          False
# 14137                                                 []           True
# 14138                                                 []          False
# 14139                                                 []           True
# 14140                                                 []          False
# 14141                                                 []           True
# 14142                                                 []           True
# 14143                                                 []           True
# 14144                                                 []           True
# 14145                                                 []           True
#
# [14146 rows x 6 columns]

# %%
# Define function
def create_text_df(df):
    '''Clean up text.'''
    
    # ' '.join[question_1, question_2, question_3] so single string
    df['TEXT'] = df['TEXT'].map(lambda item: ' '.join(item))

    # Create string of punctuation chars to remove (but not '-')
    punctuation = string.punctuation.replace('-', '').replace('/', '')
        
    # Remove punctuation via [.!?,;:] regex
    df['TEXT'] = df['TEXT'].str.replace('[' +
                                        punctuation +
                                        ']',
                                        # Replacement value
                                        '')

    # Remove double dash pattern
    df['TEXT'] = df['TEXT'].str.replace('--',
                                        # Replacement value
                                        '')
    
    # Get rid of all items without text.
    df = df.loc[df['TEXT'].str.strip().str.len() > 0,:]

    return df


# Run function
text_df = create_text_df(text_df)
text_df
# Out:
#          JUSTICE   DOCKET VOTED_FOR_PETITIONER             ARG_TYPE  \
# 0        ROBERTS    05-83                 True  PETITIONER_ARGUMENT
# 1        STEVENS    05-83                False  PETITIONER_ARGUMENT
# 2         SCALIA    05-83                 True  PETITIONER_ARGUMENT
# 3        KENNEDY    05-83                 True  PETITIONER_ARGUMENT
# 4         SOUTER    05-83                 True  PETITIONER_ARGUMENT
# 6       GINSBURG    05-83                False  PETITIONER_ARGUMENT
# 9        ROBERTS   05-259                False  PETITIONER_ARGUMENT
# 10       STEVENS   05-259                False  PETITIONER_ARGUMENT
# 11        SCALIA   05-259                False  PETITIONER_ARGUMENT
# 12       KENNEDY   05-259                False  PETITIONER_ARGUMENT
# 13        SOUTER   05-259                False  PETITIONER_ARGUMENT
# 15      GINSBURG   05-259                False  PETITIONER_ARGUMENT
# 16        BREYER   05-259                False  PETITIONER_ARGUMENT
# 17         ALITO   05-259                False  PETITIONER_ARGUMENT
# 18       STEVENS   05-352                False  PETITIONER_ARGUMENT
# 19        SCALIA   05-352                False  PETITIONER_ARGUMENT
# 20       KENNEDY   05-352                 True  PETITIONER_ARGUMENT
# 21        SOUTER   05-352                False  PETITIONER_ARGUMENT
# 23      GINSBURG   05-352                False  PETITIONER_ARGUMENT
# 25       ROBERTS   05-352                 True  PETITIONER_ARGUMENT
# 26         ALITO   05-352                 True  PETITIONER_ARGUMENT
# 28        SCALIA  05-5992                 True  PETITIONER_ARGUMENT
# 29       KENNEDY  05-5992                 True  PETITIONER_ARGUMENT
# 30        SOUTER  05-5992                 True  PETITIONER_ARGUMENT
# 32      GINSBURG  05-5992                 True  PETITIONER_ARGUMENT
# 33        BREYER  05-5992                 True  PETITIONER_ARGUMENT
# 34       ROBERTS  05-5992                 True  PETITIONER_ARGUMENT
# 36       STEVENS    05-18                False  PETITIONER_ARGUMENT
# 37        SCALIA    05-18                 True  PETITIONER_ARGUMENT
# 38       KENNEDY    05-18                 True  PETITIONER_ARGUMENT
# ...          ...      ...                  ...                  ...
# 13149     SCALIA   13-550                 True  PETITIONER_REBUTTAL
# 13150    KENNEDY   13-550                 True  PETITIONER_REBUTTAL
# 13152   GINSBURG   13-550                 True  PETITIONER_REBUTTAL
# 13153     BREYER   13-550                 True  PETITIONER_REBUTTAL
# 13154      ALITO   13-550                 True  PETITIONER_REBUTTAL
# 13155  SOTOMAYOR   13-550                 True  PETITIONER_REBUTTAL
# 13156      KAGAN   13-550                 True  PETITIONER_REBUTTAL
# 13382    ROBERTS  13-1174                 True  PETITIONER_REBUTTAL
# 13383     SCALIA  13-1174                 True  PETITIONER_REBUTTAL
# 13384    KENNEDY  13-1174                 True  PETITIONER_REBUTTAL
# 13386   GINSBURG  13-1174                 True  PETITIONER_REBUTTAL
# 13387     BREYER  13-1174                 True  PETITIONER_REBUTTAL
# 13388      ALITO  13-1174                 True  PETITIONER_REBUTTAL
# 13389  SOTOMAYOR  13-1174                 True  PETITIONER_REBUTTAL
# 13390      KAGAN  13-1174                 True  PETITIONER_REBUTTAL
# 13409    ROBERTS  13-1075                 True  PETITIONER_REBUTTAL
# 13410     SCALIA  13-1075                 True  PETITIONER_REBUTTAL
# 13411    KENNEDY  13-1075                False  PETITIONER_REBUTTAL
# 13413   GINSBURG  13-1075                False  PETITIONER_REBUTTAL
# 13414     BREYER  13-1075                False  PETITIONER_REBUTTAL
# 13416  SOTOMAYOR  13-1075                False  PETITIONER_REBUTTAL
# 13417      KAGAN  13-1075                False  PETITIONER_REBUTTAL
# 13427    ROBERTS   13-435                 True  PETITIONER_REBUTTAL
# 13428     SCALIA   13-435                 True  PETITIONER_REBUTTAL
# 13429    KENNEDY   13-435                 True  PETITIONER_REBUTTAL
# 13431   GINSBURG   13-435                 True  PETITIONER_REBUTTAL
# 13432     BREYER   13-435                 True  PETITIONER_REBUTTAL
# 13433      ALITO   13-435                 True  PETITIONER_REBUTTAL
# 13434  SOTOMAYOR   13-435                 True  PETITIONER_REBUTTAL
# 13435      KAGAN   13-435                 True  PETITIONER_REBUTTAL
#
#                                                     TEXT QUESTIONEE_WON
# 0         Is the jury given a\n\ncopy of the information           True
# 1      Could you  could you\n\n\n\nclarify one thing ...          False
# 2      Was deadly weapon still an\n\n\n\nenhancement ...           True
# 3      On  on that point I have\n\n\n\n I have one qu...           True
# 4       Now did you have to prove\n\n\n\nthat because...           True
# 6      I thought the deadly weapon\n\n\n\n the defini...          False
# 9             It has been endorsed\n\nby the EEOC though          False
# 10     May I ask you this\n\n\n\nhypothetical\n\n\n\n...          False
# 11     But  has the language and\n\n\n\n doesnt\n\n\n...          False
# 12     from the forklift forever or a year\n\n\n\nthe...          False
# 13     Okay but if that argument\n\nis sound - Yes bu...          False
# 15     They say one lunch but\n\n\n\nnot if theres a ...          False
# 16     Well the answer would be\n\n\n\nbecause Congre...          False
# 17     But he says you know as you\n\nIsnt a change i...          False
# 18     How do you reconcile your\n\n\n\nposition with...          False
# 19     When did  when did we\n\n\n\nfirst hold that t...          False
# 20     But of\n\nWell that was my  even\n\n\n\nin the...           True
# 21     Its a\n\nThe only issue in that case\n\n\n\nis...          False
# 23     But in this  in this\n\n\n\ncase Mr Dreeben we...          False
# 25     Well but what if \n\n\n\njust to take an examp...           True
# 26     Its actually easier than\n\nWell why would it ...           True
# 28     If the\n\nThe delay  the delay was\n\n\n\nnot ...           True
# 29     Prior to that time\nIt couldnt\n\nYoure not qu...           True
# 30     And it makes very clear\n\nNo but isnt  isnt t...           True
# 32     For\n\nWhat about Mr Zas that\n\n\n\nthe court...           True
# 33     Yes but on  on that one\n\n\n\nthe  the Second...           True
# 34     of justice finding for all time\n\n\n\nbeginni...           True
# 36     Do you think the right\n\n\n\nincludes any cos...          False
# 37     I thought the GAO study\n\n\n\nincluded not ju...           True
# 38     But\n\nI  I would have thought\n\n\n\nthat you...           True
# ...                                                  ...            ...
# 13149  But if ­­ if we agree that \n\nthere had to be...           True
# 13150  Where ­­ where are you \n\nreading from Well y...           True
# 13152  You also said did you \n\n\n\nnot that ­­ that...           True
# 13153  Do you think both parties \n\n\n\nagree that t...           True
# 13154  If we forget what happened \n\n\n\nat earlier ...           True
# 13155  One of the things that I \n\n\n\nwas looking f...           True
# 13156  And if I could just ask \n\n\n\nagain Mr Frede...           True
# 13382  Well hear argument \n\n\n\nfirst this morning ...           True
# 13383  But these statutes do not \n\n\n\nspeak of con...           True
# 13384  But ­­ but your ­­ your \n\n\n\nanswer is that...           True
# 13386  Doesnt Rule  say \n\nunless otherwise provided...           True
# 13387  How do you do that \n\nBecause not ­­ not all ...           True
# 13388   Well but that ­­\nAnd that is Petitioners bri...           True
# 13389  Could you tell me \n\n\n\nfirst what differenc...           True
# 13390  Are you then saying that \n\n\n\ntheres no pra...           True
# 13409  We will hear \n\n\n\nargument next this mornin...           True
# 13410   Didnt ­­ didnt the \n\n\n\nprivate right of a...           True
# 13411   Were ­­ were those ­­\nDidnt our cases ­­\n­­...          False
# 13413  I thought at least if a \n\n\n\nstatute passed...          False
# 13414  Well if that ­­ if thats \n\nall ­­ If in fact...          False
# 13416  You are equating \n\n\n\nreasonable cause or ­...          False
# 13417   Ms ­­ Ms Prelogar Im \n\n\n\nwondering what y...          False
# 13427  Well hear argument \n\n\n\nnext this morning i...           True
# 13428  Do you think that ­­ Justice Scalia \nDo you t...           True
# 13429  If we adopt your position \n\n\n\nwhich I take...           True
# 13431  So youre saying that \n\nthis evidence what we...           True
# 13432  But suppose it is actually \n\n\n\ndisputed an...           True
# 13433  Well that may be true but \n\n\n\ndo you deny ...           True
# 13434  Whats wrong with that \n\n\n\nTheres an assump...           True
# 13435  Well Mr Shanmugam \n\nsuppose ­­ Mr Shanmugam ...           True
#
# [5225 rows x 6 columns]

# %%
# Create test/train split for text data
split = sklearn.model_selection.train_test_split

# Split test and train.
train_text_df, test_text_df = split(text_df, test_size = 0.2)
train_text_df = train_text_df.copy()
test_text_df = test_text_df.copy()

# %%
train_text_df.head(3)
# Out:
#         JUSTICE    DOCKET VOTED_FOR_PETITIONER             ARG_TYPE  \
# 4984  SOTOMAYOR   11-1351                 True  PETITIONER_ARGUMENT
# 4969     SCALIA   11-9953                False  PETITIONER_ARGUMENT
# 7278    ROBERTS  04-10566                False  PETITIONER_REBUTTAL
#
#                                                    TEXT QUESTIONEE_WON
# 4984  Well one of the\n\n\n\nstrongest arguments by ...           True
# 4969  Mr Bourke was  was it\n\nwithin the control of...          False
# 7278  Where you have a treaty that becomes part of\n...          False

# %%
train_text_df['JUSTICE'].unique()
# Out:
# array(['SOTOMAYOR', 'SCALIA', 'ROBERTS', 'GINSBURG', 'ALITO', 'STEVENS',
#        'KENNEDY', 'BREYER', 'KAGAN', 'SOUTER', 'THOMAS'], dtype=object)

# %%
# Define function
def create_pipelines(df):
    '''Creates pipelines for each justice.'''
    # Basic setup.
    gb = text_df.groupby('JUSTICE')
    justices = df['JUSTICE'].unique()
    dataframes = [gb.get_group(justice) for justice in justices]
    nb_pipelines = []
    sgd_pipelines = []
    rf_pipelines = []
    
    # Probably a vectorized way to do this.
    for justice, dataframe in zip(justices, dataframes):

        # Make aliases
        Pipe = sklearn.pipeline.Pipeline
        Vectorizer = sklearn.feature_extraction.text.CountVectorizer
        Transformer = sklearn.feature_extraction.text.TfidfTransformer
        MultiNB = sklearn.naive_bayes.MultinomialNB
        SGD = sklearn.linear_model.SGDClassifier
        RF = sklearn.ensemble.RandomForestClassifier

        # Reuseable arguments.
        vectorizer_params = {'ngram_range': (3, 5),
                             'min_df': 10}
        
        transformer_params = {'use_idf': True}

        ############# Multinomial Naive Bayes classifier
        nb_pipeline = Pipe([('vectorizer', Vectorizer(**vectorizer_params)),
                            ('transformer', Transformer(**transformer_params)),
                            ('classifier', MultiNB()),])
        try:
            nb_pipeline = nb_pipeline.fit(dataframe['TEXT'],
                                          dataframe['QUESTIONEE_WON'])
        except (ValueError, AttributeError):
            nb_pipeline = None
        nb_pipelines.append(nb_pipeline)

        ############ Gradient descent SGD
        sgd_pipeline = Pipe([('vectorizer', Vectorizer(**vectorizer_params)),
                             ('transformer', Transformer(**transformer_params)),
                             ('classifier', SGD(loss='log', penalty='l2')),])    
        try:
            sgd_pipeline = sgd_pipeline.fit(dataframe['TEXT'],
                                            dataframe['QUESTIONEE_WON'])
        except (ValueError, AttributeError):
            sgd_pipeline = None
        sgd_pipelines.append(sgd_pipeline)
        
        ############ RF
        rf_pipeline = Pipe([('vectorizer', Vectorizer(**vectorizer_params)),
                            ('transformer', Transformer(**transformer_params)),
                            ('classifier', RF(n_estimators=100))])    
        try:
            rf_pipeline = rf_pipeline.fit(dataframe['TEXT'],
                                          dataframe['QUESTIONEE_WON'])
        except (ValueError, AttributeError):
            rf_pipeline = None
        rf_pipelines.append(rf_pipeline)
    
    return [item for item in zip(justices,
                                 nb_pipelines, 
                                 sgd_pipelines, 
                                 rf_pipelines)]


# Create test and train pipelines
pipelines = create_pipelines(train_text_df)

# %%
pipelines[0][1]
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=10,
#         ngram_range=(3, 5), preprocessor=None, stop_words=None,
#       ...f=False, use_idf=True)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
# Define function for creating an argument for add_predictions()
def create_model_dict(model_pipelines):
    '''For convenience we create an associative array of models.'''
    model_dict = {}
    for justice, nb_pipe, sgd_pipe, rf_pipe in model_pipelines:
        # Nested dicts
        model_dict[justice] = {}
        model_dict[justice]['SGD'] = sgd_pipe
        model_dict[justice]['NB'] = nb_pipe
        model_dict[justice]['RF'] = rf_pipe 
    return model_dict


# Run function
model_dict = create_model_dict(pipelines)

# %%
# Define function to add predictions to test frame
def add_predictions(row, model_dict, model_type):
    '''Apply() function for adding predictions'''
    justice_name = row['JUSTICE']
    try:
        model = model_dict[justice_name][model_type]
        prediction = model.predict([row['TEXT']])[0]
    # If no model, predict will not be an attribute.
    # No justice, no peace (also no model).
    except (KeyError, AttributeError):
        return np.NaN
    return prediction


test_text_df['NB_PREDICTION'] = test_text_df.apply(add_predictions,
                                                   args=(model_dict, 'NB'),
                                                   axis=1).astype(bool)

test_text_df['SGD_PREDICTION'] = test_text_df.apply(add_predictions,
                                                    args=(model_dict, 'SGD'),
                                                    axis=1).astype(bool)

test_text_df['RF_PREDICTION'] = test_text_df.apply(add_predictions,
                                                   args=(model_dict, 'RF'),
                                                   axis=1).astype(bool)

# %%
test_text_df.head(3)
# Out:
#       JUSTICE    DOCKET VOTED_FOR_PETITIONER             ARG_TYPE  \
# 8900  STEVENS    06-666                 True  PETITIONER_REBUTTAL
# 8551  KENNEDY  06-11429                False  PETITIONER_REBUTTAL
# 4644  ROBERTS    11-798                 True  PETITIONER_ARGUMENT
#
#                                                    TEXT QUESTIONEE_WON  \
# 8900  We are\n\nWe are talking about not\n\njust a d...           True
# 8551  It is simply our\n\nWell but there has to be\n...          False
# 4644  That matters  that\n\n\n\nmatters in your view...           True
#
#      NB_PREDICTION SGD_PREDICTION RF_PREDICTION
# 8900         False          False         False
# 8551          True           True         False
# 4644          True           True          True

# %%
# Check output for clarity
test_text_df.head(3)

# Assess accuracy
score = sklearn.metrics.accuracy_score
test_text_df = test_text_df.dropna()

# Conduct scoring
nb_score = score(test_text_df['QUESTIONEE_WON'],
                 test_text_df['NB_PREDICTION'])
sgd_score = score(test_text_df['QUESTIONEE_WON'],
                  test_text_df['SGD_PREDICTION'])
rf_score = score(test_text_df['QUESTIONEE_WON'],
                 test_text_df['RF_PREDICTION'])

# Format as string
base_string = '''
\n
The Naive Bayes model scored {:.1%}.\n\n
The Stochastic Gradient Decent model scored {:.1%}.\n\n
The Random Forest model scored {:.1%}.\n\n

This can't be real. TODO.
'''

print(base_string.format(nb_score, sgd_score, rf_score))
# Out:
# The Naive Bayes model scored 72.9%.
#
#
# The Stochastic Gradient Decent model scored 83.7%.
#
#
# The Random Forest model scored 94.6%.
#
#
#
# This can't be real. TODO.

# %%
score = sklearn.metrics.roc_auc_score(test_text_df['QUESTIONEE_WON'].values,
                                      test_text_df['RF_PREDICTION'].values)

score
# Out:
# 0.94360588874499463

# %%
# Define function
def get_nb_phrases(nb_pipeline, number):
    '''Pull relevant phrases from model'''
    nb_vec = nb_pipeline.named_steps['vectorizer']
    nb_clf = nb_pipeline.named_steps['classifier']
    nb_names = nb_vec.get_feature_names()
    # nb_clf.feature_log_prob_[0] is for False (voted against party)
    # nb_clf.feature_log_prob_[1] is for True (voted for party)
    nb_probs = nb_clf.feature_log_prob_[1]
    nb_series = pd.Series({name: prob
                           for name, prob
                           in zip(nb_names, nb_probs)})
    # Turn into series
    top_values_nb = nb_series.sort_values(ascending=False).head(number).copy()
    top_values_nb.name = 'Top Naive Bayes Log Prob'
    bottom_values_nb = nb_series.sort_values(ascending=True).head(number).copy()
    bottom_values_nb.name = 'Bottom Naive Bayes Log Prob'
    return (top_values_nb, bottom_values_nb)


# Define function
def get_sgd_phrases(sgd_pipeline, number):
    '''Pull phrases from model.'''
    sgd_clf = sgd_pipeline.named_steps['classifier']
    sgd_vec = sgd_pipeline.named_steps['vectorizer']
    sgd_names = sgd_vec.get_feature_names()
    # sgd_clf.coef_[0] is for False (voted against party)
    sgd_probs = sgd_clf.coef_[0]
    sgd_series = pd.Series({name: prob
                            for name, prob
                            in zip(sgd_names, sgd_probs)})
    # Turn into series.
    top_values_sgd = sgd_series.sort_values(ascending=False).head(number).copy()
    top_values_sgd.name = 'Top SGD Log Prob'
    bottom_values_sgd = sgd_series.sort_values(ascending=True).head(number).copy()
    bottom_values_sgd.name = 'Bottom SGD Log Prob'
    return(top_values_sgd, bottom_values_sgd)


# Define function
def get_rf_phrases(rf_pipeline, number):
    '''Pull phrases from model. Importances are both top and bottom items.'''
    rf_clf = rf_pipeline.named_steps['classifier']
    rf_vec = rf_pipeline.named_steps['vectorizer']
    rf_names = rf_vec.get_feature_names()
    # rf_clf.geature_importances
    rf_probs = rf_clf.feature_importances_
    rf_series = pd.Series({name: prob
                           for name, prob
                           in zip(rf_names, rf_probs)})
    # Turn into series.
    top_values_rf = rf_series.sort_values(ascending=False).head(number).copy()
    top_values_rf.name = 'Top RF Feature Imp'
    bottom_values_rf = rf_series.sort_values(ascending=True).head(number).copy()
    bottom_values_rf.name = 'Bottom RF Feature Imp'
    return(top_values_rf, bottom_values_rf)

# %%
# Define function
def create_phrase_series(pipelines, number=500):
    '''Top and bottom phrase DFs. Two columns per justice in each (SGD & NB models).'''
    
    # Create data holding dicts
    return_value = []
    
    # Iterate through pipelines to get data we need.
    for justice, nb_pipeline, sgd_pipeline, rf_pipeline in pipelines:
        
        # Skip any empty pipelines (insufficient comments)
        if any([nb_pipeline is None, 
                sgd_pipeline is None,
                rf_pipeline is None]):
            continue

        # Get actual phrases
        top_values_nb, bottom_values_nb = get_nb_phrases(nb_pipeline,
                                                         number)
        top_values_sgd, bottom_values_sgd = get_sgd_phrases(sgd_pipeline,
                                                            number)
        top_values_rf, bottom_values_rf = get_rf_phrases(rf_pipeline,
                                                         number)

        # Add to return value
        return_value.append({'justice': justice,
                             'TOP_NB': top_values_nb,
                             'BOTTOM_NB': bottom_values_nb,
                             'TOP_SGD': top_values_sgd,
                             'BOTTOM_SGD': bottom_values_sgd,
                             'TOP_RF': top_values_rf,
                             'BOTTOM_RF': bottom_values_rf})

    # Return list of dicts.
    return return_value
        
    
# Run function
justice_data = create_phrase_series(pipelines)

# %%
# Show sample data for clarity
pd.DataFrame(justice_data[6]['BOTTOM_RF']).head(3)
# Out:
#                    Bottom RF Feature Imp
# would have to                   0.000326
# to make the                     0.000343
# are talking about               0.000351

# %%
# Define function
def create_frequency_dfs(justice_data, text_df):
    '''This function takes bottom phrases and computes frequency.'''
        
    # Results
    bottom_phrase_results = []
    
    for data_dict in justice_data:
        
        # Get justice name
        justice = data_dict['justice']

        # Get bottom values
        bottom_nb_phrases = data_dict['BOTTOM_NB']
        bottom_sgd_phrases = data_dict['BOTTOM_SGD']
        bottom_rf_phrases = data_dict['BOTTOM_RF']
        bottom_phrases = (bottom_nb_phrases.append(bottom_sgd_phrases)
                                           .append(bottom_rf_phrases)
                                           .drop_duplicates()
                                           .index.values)
        
        # Create won and lost dataframes.
        won_df = text_df[(text_df['JUSTICE'] == justice) &
                         (text_df['QUESTIONEE_WON'] == True)]
        lost_df = text_df[(text_df['JUSTICE'] == justice) &
                          (text_df['QUESTIONEE_WON'] == False)]
        
        # To string
        won_string = won_df['TEXT'].str.lower().str.cat(sep=' ')
        lost_string = lost_df['TEXT'].str.lower().str.cat(sep=' ')

   
        # Calculate bottom phrases
        for phrase in bottom_phrases:
            won_count = 0
            lost_count = 0
            
            # Get counts
            won_count += won_string.count(phrase)
            lost_count += lost_string.count(phrase)
            all_count = won_count + lost_count
            if all_count == 0:
                percentage = np.NaN
            else:
                percentage = won_count / all_count
            # Stick in results (list of dicts)
            bottom_phrase_results.append({'JUSTICE': justice,
                                          'PHRASE': phrase,
                                          'AT_WINNER_COUNT': won_count,
                                          'AT_LOSER_COUNT': lost_count,
                                          'AT_WINNER_PERCENT': percentage})

    # Create bottom dataframe
    bottom_df = pd.DataFrame(bottom_phrase_results)
    bottom_df = bottom_df.set_index(['JUSTICE', 'PHRASE'])
    bottom_df = bottom_df[['AT_WINNER_COUNT', 'AT_LOSER_COUNT', 'AT_WINNER_PERCENT']]
    bottom_df['AT_LOSER_PERCENT'] = 1 - bottom_df['AT_WINNER_PERCENT']

    return bottom_df


# Run function
bottom_freq_df = create_frequency_dfs(justice_data, text_df)
bottom_freq_df.head(5).dropna()
# Out:
#                                   AT_WINNER_COUNT  AT_LOSER_COUNT  \
# JUSTICE   PHRASE
# SOTOMAYOR why should we                         2              10
#           could you tell me what                3               5
#           that there are                        2               6
#           are you suggesting                    2               7
#           between the two                       2               5
#
#                                   AT_WINNER_PERCENT  AT_LOSER_PERCENT
# JUSTICE   PHRASE
# SOTOMAYOR why should we                    0.166667          0.833333
#           could you tell me what           0.375000          0.625000
#           that there are                   0.250000          0.750000
#           are you suggesting               0.222222          0.777778
#           between the two                  0.285714          0.714286

# %%
# Write bottom_freq_df to file
bottom_csv_path = os.path.join(DATA_FOLDER, 'bottom_phrases.csv')
bottom_freq_df.to_csv(bottom_csv_path, encoding='utf-8')

# %%
# Define function
def create_tabulation_df():
    '''(Case, justice, arg_vect) x  model.'''
    
    # Make justice/model multiindex for columns
    cases = CURRENT_CASES
    # Really should have standardized this earlier
    justices = [justice.upper() for justice in CURRENT_JUSTICES]
    arg_types = ['PETITIONER_ARGUMENT',
                 'RESPONDENT_ARGUMENT',
                 'PETITIONER_REBUTTAL']
    models = ['NB', 'SGD', 'RF']
    cja_index = pd.MultiIndex.from_product([cases, justices, arg_types])

    # Make dataframe
    tabulation_df = pd.DataFrame(index=cja_index, columns=models, data=np.NaN)
    return tabulation_df


# Run function
tabulation_df = create_tabulation_df()

# %%
# Demo for clarity ... should be empty.
tabulation_df.head(3)
# Out:
#                                     NB  SGD  RF
# 15-214 ROBERTS PETITIONER_ARGUMENT NaN  NaN NaN
#                RESPONDENT_ARGUMENT NaN  NaN NaN
#                PETITIONER_REBUTTAL NaN  NaN NaN

# %%
def make_current_df(arg_df):
    # Create a lookup dataframe.
    lookup_df = arg_df[arg_df['DOCKET'].isin(CURRENT_CASES)]
    output_rows = []
    input_rows = [row.to_dict() for index, row in lookup_df.iterrows()]
    for justice in CURRENT_JUSTICES:
        for row_dict in input_rows:
            dict_copy = copy.deepcopy(row_dict)
            dict_copy['JUSTICE'] = justice
            output_rows.append(dict_copy)
    return pd.DataFrame.from_dict(output_rows)

# Create new df
current_df = make_current_df(arg_df)
# Run previous functions
current_df = current_df.apply(filter_justice_data, axis=1)
current_df.head(3)
# Out:
#                                        ARGUMENT_LINK  \
# 0  https://www.supremecourt.gov/oral_arguments/ar...
# 1  https://www.supremecourt.gov/oral_arguments/ar...
# 2  https://www.supremecourt.gov/oral_arguments/ar...
#
#                             ARGUMENT_PATH ARGUMENT_YEAR  \
# 0   /home/theo/.scoap/15-214/argument.pdf          2016
# 1  /home/theo/.scoap/15-1031/argument.pdf          2016
# 2  /home/theo/.scoap/15-1189/argument.pdf          2016
#
#                                                 CASE   DOCKET  JUSTICE  \
# 0                                  Murr v. Wisconsin   15-214  ROBERTS
# 1                                   Howell v. Howell  15-1031  ROBERTS
# 2  Impressions Products, Inc. v. Lexmark Int'l, Inc.  15-1189  ROBERTS
#
#                                  PETITIONER_ARGUMENT PETITIONER_REBUTTAL  \
# 0  [, , , And those would\n\nI thought your\n\n\n...                  []
# 1  [This -- this is a\n\n\n\npretty basic questio...                  []
# 2  [I'm sorry to\n\n\n\ninterrupt you, but that l...                  []
#
#                                      PET_ARG_HEADING  \
# 0  ORAL ARGUMENT OF JOHN M. GROEN\n\n\n\nON BEHAL...
# 1  ORAL ARGUMENT OF ADAM G. UNIKOWSKY\n\n\n\nON B...
# 2  ORAL ARGUMENT OF ANDREW J. PINCUS\n\n\n\nON BE...
#
#                                        PET_ARG_REGEX  \
# 0  ORAL ARGUMENT OF JOHN M. GROEN\n\n\n\nON BEHAL...
# 1  ORAL ARGUMENT OF ADAM G. UNIKOWSKY\n\n\n\nON B...
# 2  ORAL ARGUMENT OF ANDREW J. PINCUS\n\n\n\nON BE...
#
#                                      PET_REB_HEADING  \
# 0  REBUTTAL ARGUMENT OF JOHN M. GROEN\n\n\n\nON B...
# 1  REBUTTAL ARGUMENT OF ADAM G. UNIKOWSKI\n\n\n\n...
# 2  REBUTTAL ARGUMENT OF ANDREW J. PINCUS\n\n\n\nO...
#
#                                        PET_REB_REGEX  \
# 0  REBUTTAL ARGUMENT OF JOHN M. GROEN\n\n\n\nON B...
# 1  REBUTTAL ARGUMENT OF ADAM G. UNIKOWSKI\n\n\n\n...
# 2  REBUTTAL ARGUMENT OF ANDREW J. PINCUS\n\n\n\nO...
#
#                                  RESPONDENT_ARGUMENT  \
# 0  {'CHIEF JUSTICE ROBERTS': ['Well, that's -- an...
# 1  {'CHIEF JUSTICE ROBERTS': ['', 'I think -What ...
# 2  {'CHIEF JUSTICE ROBERTS': ['Why -- why is norm...
#
#                                      RES_ARG_HEADING  \
# 0  ORAL ARGUMENT OF RICHARD J. LAZARUS\nON BEHALF...
# 1  ORAL ARGUMENT OF CHARLES W. WIRKEN\n\n\n\nON B...
# 2  ORAL ARGUMENT OF CONSTANTINE L. TRELA, JR.\n\n...
#
#                                        RES_ARG_REGEX  \
# 0  ORAL ARGUMENT OF RICHARD J. LAZARUS\nON BEHALF...
# 1  ORAL ARGUMENT OF CHARLES W. WIRKEN\n\n\n\nON B...
# 2  ORAL ARGUMENT OF CONSTANTINE L. TRELA, JR.\n\n...
#
#                                                 TEXT
# 0  \n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe w...
# 1  \n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'l...
# 2  \n\n\n\n\n\n\n\nCHIEF JUSTICE ROBERTS:\n\nWe'l...

# %%
# Define function
def create_lookup_series(current_df):
    '''Place text in df for processing. Each justice gets same data.'''
    # Flatten and reindex
    lookup_df = current_df[['DOCKET',
                            'JUSTICE',
                            'PETITIONER_ARGUMENT',
                            #'RESPONDENT_ARGUMENT',
                            'PETITIONER_REBUTTAL']]
    lookup_df = lookup_df.set_index(['DOCKET', 'JUSTICE'])
    # Flatten lists
    lookup_df = lookup_df.applymap(lambda x: ' '.join(x))
    # Make lookup series
    lookup_series = lookup_df.stack()
    # Sort and dedupe (where do dupes come from?)
    lookup_series.sort_index(inplace=True)
    lookup_series.drop_duplicates(inplace=True)
    return lookup_series


# Run
lookup_series = create_lookup_series(current_df)

# %%
lookup_series.head(3)
# Out:
# DOCKET   JUSTICE
# 14-1055  ALITO     PETITIONER_ARGUMENT
#          BREYER    PETITIONER_ARGUMENT    It's tough.\n\nI mean, I find\n\n\n\nthis pret...
#          GINSBURG  PETITIONER_ARGUMENT    Does that include --\n\n\n\nyou -- you said su...
# dtype: object

# %%
# Define function
def populate_tabulation_df(row, lookup_series):
    '''Fill in the dataframe. Meant to be applied.'''
    try:
        case, justice, arg_type = row.name
        # Make this not chained indexing
        value = lookup_series[case][justice][arg_type]
        row[['NB', 'SGD', 'RF']] = value, value, value
    except KeyError:
        row[['NB', 'SGD', 'RF']] = np.NaN, np.NaN, np.NaN
    return row


# Run function
tabulation_df = tabulation_df.apply(populate_tabulation_df,
                                    args=(lookup_series,),
                                    axis=1)

# %%
tabulation_df.head(3)
# Out:
#                                                                                    NB  \
# 15-214 ROBERTS PETITIONER_ARGUMENT     And those would\n\nI thought your\n\n\n\nar...
#                RESPONDENT_ARGUMENT                                                NaN
#                PETITIONER_REBUTTAL                                                NaN
#
#                                                                                   SGD  \
# 15-214 ROBERTS PETITIONER_ARGUMENT     And those would\n\nI thought your\n\n\n\nar...
#                RESPONDENT_ARGUMENT                                                NaN
#                PETITIONER_REBUTTAL                                                NaN
#
#                                                                                    RF
# 15-214 ROBERTS PETITIONER_ARGUMENT     And those would\n\nI thought your\n\n\n\nar...
#                RESPONDENT_ARGUMENT                                                NaN
#                PETITIONER_REBUTTAL                                                NaN

# %%
# Define function
def run_predictions(column, model_dict, tabulation_df):
    '''This applied function adds results to the result series.
    
    It is initially framed in terms of "QUESTIONEE_WINS", which is
    the output of the model.predict(). It is then converted to 
    "PLAINTIFF_WINS", by flipping the respondent argument (e.g.
    if questionee is plaintiff because plaintiff arg or
    plaintiff rebuttal, QUESTIONEE_WINS == PLAINTIFF_WINS ...
    if respondent argument, QUESTOINEE_WINS != PLAINTIFF_WINS).
    
    '''

    # There has to be a better way to vectorize with groupby.
    model_name = column.name
    
    # Need copy so we can iterrate and change "in place"
    column_copy = column.copy()
    
    # iterate through items
    for index, text in column_copy.iteritems():
        case, justice, arg_type = index
        # Get text
        try:
            model = model_dict[justice][model_name]
            # Cannot comapre np.NaN
            if model is None or pd.isnull(text):
                column.loc[index] = np.NaN
                continue
            # If you've already gone over it, it's bool. Therefore skip.
            if type(text) is np.bool_ or type(text) is bool:
                continue
            # Predict
            prediction = model.predict([text])[0]
            # Flip prediction because speaker -> party flip recorrect.
            if arg_type == 'RESPONDENT_ARGUMENT':
                prediction = not prediction
            # Write back to clolumn
            column.loc[index] = prediction
        except KeyError:
            column.loc[index] = np.NaN
    
    return column


# Run function
tabulation_df = tabulation_df.apply(run_predictions,
                                    axis=0,
                                    args=(model_dict, tabulation_df))

# %%
# Demo for clarity
tabulation_df.head(3)
# Out:
#                                       NB   SGD    RF
# 15-214 ROBERTS PETITIONER_ARGUMENT  True  True  True
#                RESPONDENT_ARGUMENT   NaN   NaN   NaN
#                PETITIONER_REBUTTAL   NaN   NaN   NaN

# %%
def modified_sum(row):
    if row['RESPONDENT_VOTES'] < row['PETITIONER_VOTES']:
        return 'Petitioner'
    if row['RESPONDENT_VOTES'] > row['PETITIONER_VOTES']:
        return 'Respondent'
    else:
        return None

#### Define function
def calculate_votes(tabulation_df):
    # Consensus vector ... vectorize this.
    consensus = pd.Series(index=tabulation_df.index
                                             .droplevel(2)
                                             .copy(),
                          dtype='object')
    consensus.name = 'VOTES'
    # Iterate through tabulation
    tdf = tabulation_df.unstack()
    tdf = tdf.apply(lambda row: pd.value_counts(row.values), axis=1)
    tdf.columns = ['RESPONDENT_VOTES', 'PETITIONER_VOTES']
    tdf = tdf.fillna(0)
    tdf['VOTE'] = tdf.apply(modified_sum, axis=1)
    return tdf

# Run function
votes = calculate_votes(tabulation_df)
votes.head(8)
# Out:
#                    RESPONDENT_VOTES  PETITIONER_VOTES        VOTE
# 14-1055 ALITO                   0.0               3.0  Petitioner
#         BREYER                  2.0               1.0  Respondent
#         GINSBURG                0.0               3.0  Petitioner
#         KAGAN                   0.0               3.0  Petitioner
#         KENNEDY                 0.0               0.0        None
#         ROBERTS                 0.0               3.0  Petitioner
#         SOTOMAYOR               0.0               6.0  Petitioner
#         THOMAS                  0.0               0.0        None

# %%
def harmonize_empty(votes, VOTING_RELATIONSHIPS):
    '''If null, make this justice copy another similarly-minded justice.'''

    voting_df = pd.DataFrame(VOTING_RELATIONSHIPS)
    # Don't want our inputed picks affecting other imputed picks.
    imputed_probabilities = []
        
    for index, row in votes.iterrows():
        # Parse
        case, justice = index
        if row['VOTE'] is None:
            # Get similarity rankings: ALITO: 7, BREYER: 2, KAGAN: 3
            similarity_ranks = voting_df.loc[justice].argsort()
            # Then rank so we have BREYER: 2, KAGAN: 3, ALITO: 7
            similarity_order = similarity_ranks.sort_values()
            # Similar justice list: [BREYER, KAGAN, ALITO]
            most_similar = similarity_order.index.values

            # Go through justice list to get closest.
            for sim_justice in most_similar:
                if sim_justice == 'SCALIA':
                    continue
                other_justice_prob = votes.loc[(case, sim_justice)]['VOTE']
                if other_justice_prob is None:
                    continue
                else:
                    imputed_probabilities.append({'case': case,
                                                  'justice': justice,
                                                  'prob': other_justice_prob})
                    
    # Now all imputed_probs are complete. Add back in.
    for prob in imputed_probabilities:
        index_tuple = tuple([prob['case'], prob['justice']])
        votes.loc[index_tuple, 'VOTE'] = prob['prob']
    return None


harmonize_empty(votes, VOTING_RELATIONSHIPS)
votes.head(8)
# Out:
#                    RESPONDENT_VOTES  PETITIONER_VOTES        VOTE
# 14-1055 ALITO                   0.0               3.0  Petitioner
#         BREYER                  2.0               1.0  Respondent
#         GINSBURG                0.0               3.0  Petitioner
#         KAGAN                   0.0               3.0  Petitioner
#         KENNEDY                 0.0               0.0  Petitioner
#         ROBERTS                 0.0               3.0  Petitioner
#         SOTOMAYOR               0.0               6.0  Petitioner
#         THOMAS                  0.0               0.0  Respondent

# %%
def get_petitioner_votes(row):
    '''Helper function for apply.'''
    vc = row.value_counts()
    try:
        petitioner_count = vc['Petitioner']
    except KeyError:
        petitioner_count = 0
    return petitioner_count


def get_respondent_votes(row):
    '''Helper function for apply.'''
    vc = row.value_counts()
    try:
        respondent_count = vc['Respondent']
    except KeyError:
        respondent_count = 0
    return respondent_count


def process_votes(votes):
    '''Apply function for results.'''
    # Get rid of superfluous columns
    result = votes[['VOTE']]
    # Turn into dataframe.
    result = result.unstack()
    # Get rid of superfluous multiindex
    result.columns = result.columns.droplevel(0)
    # Add winner and loser counts.
    result['PET_VOTES'] = result.apply(get_petitioner_votes, axis=1)
    result['RES_VOTES'] = result.apply(get_respondent_votes, axis=1)
    # Arbitrary
    result['VICTOR'] = result['PET_VOTES'] > result['RES_VOTES']
    result['VICTOR'] = result['VICTOR'].map({True: 'Petitioner',
                                             False: 'Respondent'})
    return result


result = process_votes(votes)

try:
    result = result.drop('15-1112')
except Exception:
    pass

result
# Out:
#               ALITO      BREYER    GINSBURG       KAGAN     KENNEDY  \
# 14-1055  Petitioner  Respondent  Petitioner  Petitioner  Petitioner
# 14-1538  Respondent  Petitioner  Petitioner  Respondent  Respondent
# 14-9496  Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-1031  Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-1111  Respondent  Respondent  Petitioner  Respondent  Petitioner
# 15-118   Respondent  Petitioner  Petitioner  Respondent  Petitioner
# 15-1189  Respondent  Petitioner  Respondent  Respondent  Petitioner
# 15-1191  Respondent  Respondent  Petitioner  Petitioner  Petitioner
# 15-1194  Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-1204  Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-1248  Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-1251  Respondent  Respondent  Petitioner  Petitioner  Petitioner
# 15-1262  Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-1293  Petitioner  Petitioner  Petitioner  Respondent  Petitioner
# 15-1358  Petitioner  Respondent  Petitioner  Petitioner  Petitioner
# 15-1391  Respondent  Respondent  Petitioner  Respondent  Respondent
# 15-1406  Petitioner  Respondent  Petitioner  Petitioner  Petitioner
# 15-1498  Petitioner  Petitioner  Petitioner  Petitioner  Respondent
# 15-1500  Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-214   Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-423   Petitioner  Petitioner  Respondent  Petitioner  Respondent
# 15-497   Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-513   Respondent  Petitioner  Petitioner  Petitioner  Petitioner
# 15-537   Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-5991  Petitioner  Respondent  Respondent  Respondent  Petitioner
# 15-606   Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-628   Respondent  Petitioner  Respondent  Respondent  Petitioner
# 15-649   Respondent  Respondent  Respondent  Respondent  Petitioner
# 15-680   Petitioner  Petitioner  Respondent  Petitioner  Petitioner
# 15-7250  Respondent  Petitioner  Petitioner  Respondent  Petitioner
# 15-777   Petitioner  Respondent  Petitioner  Respondent  Petitioner
# 15-797   Respondent  Respondent  Petitioner  Respondent  Petitioner
# 15-8049  Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-827   Respondent  Petitioner  Respondent  Petitioner  Petitioner
# 15-8544  Respondent  Respondent  Petitioner  Respondent  Petitioner
# 15-866   Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 15-9260  Petitioner  Respondent  Petitioner  Petitioner  Petitioner
# 15-927   Respondent  Respondent  Petitioner  Respondent  Respondent
# 16-1256        None        None        None        None        None
# 16-149   Petitioner  Respondent  Petitioner  Petitioner  Petitioner
# 16-254   Respondent  Petitioner  Petitioner  Petitioner  Petitioner
# 16-32    Respondent  Petitioner  Petitioner  Petitioner  Respondent
# 16-348   Petitioner  Petitioner  Petitioner  Petitioner  Petitioner
# 16-369   Petitioner  Respondent  Respondent  Petitioner  Petitioner
# 16-54    Respondent  Petitioner  Petitioner  Petitioner  Petitioner
#
#             ROBERTS   SOTOMAYOR      THOMAS  PET_VOTES  RES_VOTES      VICTOR
# 14-1055  Petitioner  Petitioner  Respondent          6          2  Petitioner
# 14-1538  Petitioner  Respondent  Petitioner          4          4  Respondent
# 14-9496  Petitioner  Petitioner  Petitioner          7          1  Petitioner
# 15-1031  Respondent  Respondent  Petitioner          6          2  Petitioner
# 15-1111  Petitioner  Petitioner  Petitioner          5          3  Petitioner
# 15-118   Respondent  Petitioner  Petitioner          5          3  Petitioner
# 15-1189  Petitioner  Respondent  Petitioner          4          4  Respondent
# 15-1191  Petitioner  Petitioner  Respondent          5          3  Petitioner
# 15-1194  Petitioner  Petitioner  Petitioner          7          1  Petitioner
# 15-1204  Petitioner  Petitioner  Petitioner          8          0  Petitioner
# 15-1248  Petitioner  Petitioner  Petitioner          8          0  Petitioner
# 15-1251  Respondent  Petitioner  Respondent          4          4  Respondent
# 15-1262  Petitioner  Respondent  Petitioner          7          1  Petitioner
# 15-1293  Petitioner  Petitioner  Petitioner          7          1  Petitioner
# 15-1358  Petitioner  Respondent  Respondent          5          3  Petitioner
# 15-1391  Respondent  Petitioner  Respondent          2          6  Respondent
# 15-1406  Petitioner  Petitioner  Respondent          6          2  Petitioner
# 15-1498  Petitioner  Respondent  Petitioner          6          2  Petitioner
# 15-1500  Petitioner  Petitioner  Petitioner          7          1  Petitioner
# 15-214   Petitioner  Petitioner  Petitioner          8          0  Petitioner
# 15-423   Petitioner  Petitioner  Petitioner          6          2  Petitioner
# 15-497   Petitioner  Petitioner  Petitioner          7          1  Petitioner
# 15-513   Respondent  Respondent  Petitioner          5          3  Petitioner
# 15-537   Petitioner  Respondent  Respondent          5          3  Petitioner
# 15-5991  Petitioner  Respondent  Respondent          3          5  Respondent
# 15-606   Petitioner  Respondent  Petitioner          6          2  Petitioner
# 15-628   Petitioner  Petitioner  Petitioner          5          3  Petitioner
# 15-649   Petitioner  Petitioner  Respondent          3          5  Respondent
# 15-680   Petitioner  Respondent  Petitioner          6          2  Petitioner
# 15-7250  Petitioner  Petitioner  Petitioner          6          2  Petitioner
# 15-777   Petitioner  Respondent  Respondent          4          4  Respondent
# 15-797   Petitioner  Petitioner  Respondent          4          4  Respondent
# 15-8049  Petitioner  Respondent  Respondent          6          2  Petitioner
# 15-827   Petitioner  Petitioner  Petitioner          6          2  Petitioner
# 15-8544  Petitioner  Petitioner  Respondent          4          4  Respondent
# 15-866   Petitioner  Petitioner  Petitioner          8          0  Petitioner
# 15-9260  Petitioner  Petitioner  Respondent          6          2  Petitioner
# 15-927   Petitioner  Respondent  Respondent          2          6  Respondent
# 16-1256        None        None        None          0          0  Respondent
# 16-149   Petitioner  Respondent  Respondent          5          3  Petitioner
# 16-254   Petitioner  Petitioner  Petitioner          7          1  Petitioner
# 16-32    Respondent  Petitioner  Petitioner          5          3  Petitioner
# 16-348   Petitioner  Petitioner  Petitioner          8          0  Petitioner
# 16-369   Respondent  Respondent  Respondent          3          5  Respondent
# 16-54    Respondent  Petitioner  Petitioner          6          2  Petitioner

# %%
# Write results to file.
result_csv_path = os.path.join(DATA_FOLDER, 'case_results.csv')
result.to_csv(result_csv_path, encoding='utf-8')

# %%
result['VICTOR'].value_counts()
# Out:
# Petitioner    33
# Respondent    12
# Name: VICTOR, dtype: int64
